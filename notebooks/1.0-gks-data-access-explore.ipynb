# %%
# %run ./0.0-gks-utility-functions.ipynb

# %%
pwd
# Out:
# '/usr/local/git/kaggle-covid-19/notebooks'

# %%
PARENT = "/usr/local/git/kaggle-covid-19/"
DATA_RAW = PARENT + "data/raw/CORD-19-research-challenge/"

# %%
import os

files = os.listdir(DATA_RAW)

# %%
files
# Out:
# ['custom_license',
#  'metadata.readme',
#  'json_schema.txt',
#  'noncomm_use_subset',
#  'cord_19_embeddings_4_17',
#  'metadata.csv',
#  'biorxiv_medrxiv',
#  'COVID.DATA.LIC.AGMT.pdf',
#  'comm_use_subset']

# %%
os.listdir(DATA_RAW + "custom_license/custom_license")
# Out:
# ['pmc_json', 'pdf_json']

# %%
os.listdir(DATA_RAW + "custom_license/custom_license/pmc_json")
# Out:
# ['PMC2750777.xml.json',
#  'PMC7109766.xml.json',
#  'PMC7107989.xml.json',
#  'PMC7121640.xml.json',
#  'PMC7094896.xml.json',
#  'PMC3320336.xml.json',
#  'PMC1383626.xml.json',
#  'PMC5572875.xml.json',
#  'PMC7103717.xml.json',
#  'PMC7089083.xml.json',
#  'PMC3539796.xml.json',
#  'PMC3167587.xml.json',
#  'PMC3111970.xml.json',
#  'PMC7090608.xml.json',
#  'PMC7109991.xml.json',
#  'PMC7123520.xml.json',
#  'PMC7159459.xml.json',
#  'PMC7109767.xml.json',
#  'PMC7107988.xml.json',
#  'PMC7121641.xml.json',
#  'PMC7120819.xml.json',
#  'PMC7101611.xml.json',
#  'PMC7089082.xml.json',
#  'PMC3310652.xml.json',
#  'PMC7153428.xml.json',
#  'PMC7162385.xml.json',
#  'PMC7167125.xml.json',
#  'PMC7100270.xml.json',
#  'PMC7166722.xml.json',
#  'PMC7088685.xml.json',
#  'PMC7161815.xml.json',
#  'PMC4639395.xml.json',
#  'PMC7095066.xml.json',
#  'PMC7108160.xml.json',
#  'PMC7122327.xml.json',
#  'PMC7122141.xml.json',
#  'PMC7166545.xml.json',
#  'PMC7166723.xml.json',
# ...

# %%
os.listdir(DATA_RAW + "custom_license/custom_license/pdf_json")
# Out:
# ['86d4262de73cf81b5ea6aafb91630853248bff5f.json',
#  '9ec0b1175992879d5b8d3351ef40a28bb48f18ce.json',
#  '86a998617c077f4fe2ab26214995a3548fbc0fc5.json',
#  '948aaeb2e0be11ad90562bf10d462531a1f00eac.json',
#  '4ed70c27f14b7f9e6219fe605eae2b21a229f23c.json',
#  '306ef95a3a91e13a93bcc37fb2c509b67c0b5640.json',
#  'ab680d5dbc4f51252da3473109a7885dd6b5eb6f.json',
#  '6599ebbef3d868afac9daa4f80fa075675cf03bc.json',
#  'eb5c7f3ff921ad6469b79cc8a3c122648204ece4.json',
#  '44290ff75bad8ffaf5d3028420739ce7b08dc2a9.json',
#  'b87b790c96c75faa22a085cb560f7b3d8e018b24.json',
#  '3c395c76b3d97ab269aed5e6c02d0f0184df7f9f.json',
#  '5ad06be75e9c306aa10fea704f93d4ba90623a15.json',
#  '032207023bce7ab4550c38283ac7e2964d3c6561.json',
#  '6c9a692eb00e9563f550ab57838c7b29d6731e54.json',
#  '45e7c863c8a0bf2f373a64c3d7ba1546ca26d672.json',
#  '7f1d647d43af4ed96625ed113f8bf0ab737e2f0c.json',
#  '11ef1846bb816e2884da201195b43ff8f4520cbb.json',
#  '453985e02d2419abce4d5626b093a888187cfc7a.json',
# ...

# %%
print(read_textual_file(DATA_RAW + "metadata.readme"))
# Out:
# (1) Metadata for papers from these sources are combined: CZI, PMC, BioRxiv/MedRxiv. (total records 29500)
# 	- CZI 1236 records
# 	- PMC 27337
# 	- bioRxiv 566
# 	- medRxiv 361
# (2) 17K of the paper records have PDFs and the hash of the PDFs are in 'sha'
# (3) For PMC sourced papers, one paper's metadata can be associated with one or more PDFs/shas under that paper - a PDF/sha correponding to the main article, and possibly additional PDF/shas corresponding to supporting materials for the article.
# (4)	13K of the PDFs were processed with fulltext ('has_full_text'=True)
# (5) Various 'keys' are populated with the metadata:
# 	- 'pmcid': populated for all PMC paper records (27337 non null)
# 	- 'doi': populated for all BioRxiv/MedRxiv paper records and most of the other records (26357 non null)
# 	- 'WHO #Covidence': populated for all CZI records and none of the other records (1236 non null)
# 	- 'pubmed_id': populated for some of the records
# ...

# %%
print(read_textual_file(DATA_RAW + 'json_schema.txt'))
# Out:
# # JSON schema of full text documents
#
#
# {
#     "paper_id": <str>,                      # 40-character sha1 of the PDF
#     "metadata": {
#         "title": <str>,
#         "authors": [                        # list of author dicts, in order
#             {
#                 "first": <str>,
#                 "middle": <list of str>,
#                 "last": <str>,
#                 "suffix": <str>,
#                 "affiliation": <dict>,
#                 "email": <str>
#             },
#             ...
#         ],
#         "abstract": [                       # list of paragraphs in the abstract
#             {
#                 "text": <str>,
#                 "cite_spans": [             # list of character indices of inline citations
#                                             # e.g. citation "[7]" occurs at positions 151-154 in "text"
#                                             #      linked to bibliography entry BIBREF3
#                     {
# ...

# %%
os.listdir(DATA_RAW + "noncomm_use_subset/noncomm_use_subset/pmc_json/")
# Out:
# ['PMC4834006.xml.json',
#  'PMC6780997.xml.json',
#  'PMC4142007.xml.json',
#  'PMC5508335.xml.json',
#  'PMC4706628.xml.json',
#  'PMC4761681.xml.json',
#  'PMC2195581.xml.json',
#  'PMC7142029.xml.json',
#  'PMC5172448.xml.json',
#  'PMC4763971.xml.json',
#  'PMC6830658.xml.json',
#  'PMC6500855.xml.json',
#  'PMC5533572.xml.json',
#  'PMC3572670.xml.json',
#  'PMC2529389.xml.json',
#  'PMC4751110.xml.json',
#  'PMC4810350.xml.json',
#  'PMC6850639.xml.json',
#  'PMC5441328.xml.json',
#  'PMC6430903.xml.json',
#  'PMC4676647.xml.json',
#  'PMC5354050.xml.json',
#  'PMC4512435.xml.json',
#  'PMC3975787.xml.json',
#  'PMC4512434.xml.json',
#  'PMC6695009.xml.json',
#  'PMC5799402.xml.json',
#  'PMC5592169.xml.json',
#  'PMC3342036.xml.json',
#  'PMC5380771.xml.json',
#  'PMC5339507.xml.json',
#  'PMC7149470.xml.json',
#  'PMC5321322.xml.json',
#  'PMC6831848.xml.json',
#  'PMC5669506.xml.json',
#  'PMC6363154.xml.json',
#  'PMC6883198.xml.json',
#  'PMC5866964.xml.json',
# ...

# %%
os.listdir(DATA_RAW + "noncomm_use_subset/noncomm_use_subset/pdf_json/")
# Out:
# ['b2f67d533f2749807f2537f3775b39da3b186051.json',
#  'ad98979eada6e333a276d39efdce21779d538625.json',
#  '464f7d3a460eb51dbc25bd12639b22079a73f85a.json',
#  'c436139975d97ef929b5d8452595de40bda0c11c.json',
#  '634128ea7d7736750e1c3cd0a48bb37843d06dac.json',
#  'f3cb4102ee8c1aeb8e68595843292801a08effe3.json',
#  '5f52ac4738312fdb215ad06e5a2e886a6fb63efd.json',
#  'fef0bb9eaac69559d0ff2f92ff83e0affd4435f0.json',
#  '6485112a971484dfa041b32b35b25707954807db.json',
#  '65648f466638ba2c4b63d49a1c46e834719890a5.json',
#  '0f782ff530afb913a3996a51fa2acb38c34d37f5.json',
#  '2a5b2e11c10d35b22cb2965f62ccc79e61eeb77b.json',
#  '601d3c7ae4ebcd2d835e9cf8d7427ebd0b5db83f.json',
#  '09d9038625c7a2e0aa27f9f04cd7f4b2d7ec6f11.json',
#  '246f59ddffedd4a166b9317dee38bdf6077b2f3f.json',
#  '57a30fc4f036048830b77fa87c64358c48c946d6.json',
#  'e67d4c945d10fe5783c1289f45611cec25143564.json',
#  '9cda860c97d430aea207a063d13e8612e023320c.json',
#  'b66704a03a688c4065abff41c4977c4c9939c230.json',
# ...

# %%
read_json_file(DATA_RAW + "noncomm_use_subset/noncomm_use_subset/pdf_json/" 
               + 'b2f67d533f2749807f2537f3775b39da3b186051.json')
# Out:
# {'paper_id': 'b2f67d533f2749807f2537f3775b39da3b186051',
#  'metadata': {'title': 'Caring for persons in detention suffering with mental illness during the Covid-19 outbreak',
#   'authors': [{'first': 'Michael',
#     'middle': [],
#     'last': 'Liebrenz',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
#      'institution': 'University of Bern',
#      'location': {'settlement': 'Bern', 'country': 'Switzerland'}},
#     'email': ''},
#    {'first': 'Dinesh',
#     'middle': [],
#     'last': 'Bhugra',
#     'suffix': '',
#     'affiliation': {},
#     'email': ''},
#    {'first': 'Anna',
#     'middle': [],
#     'last': 'Buadze',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
#      'institution': 'University of Zurich',
#      'location': {'settlement': 'Zurich', 'country': 'Switzerland'}},
#     'email': ''},
#    {'first': 'Roman',
#     'middle': [],
#     'last': 'Schleifer',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
# ...

# %%
# %run 0.0-gks-utility-functions.ipynb

# %%
detail_csv_file(file_path = DATA_RAW + "cord_19_embeddings_4_17/cord_19_embeddings_4_17.csv").head()
# Out:
# Kwargs:  {}
# DataFrame Size: (52397, 769)
# DataFrame Columns: Index(['xqhn0vbp', '0.2771094739437103', '-2.9749464988708496',
#        '1.10358726978302', '9.312440872192383', '1.3013277053833008',
#        '-4.281131267547607', '-0.5318851470947266', '-4.497644424438477',
#        '-0.6967141628265381',
#        ...
#        '-0.31924888491630554', '4.262275695800781', '2.845273971557617',
#        '-1.656341552734375', '-2.5844340324401855', '-4.678825855255127',
#        '3.175534248352051', '4.8904242515563965', '-1.488284707069397',
#        '-1.3013025522232056'],
#       dtype='object', length=769)
#    xqhn0vbp  0.2771094739437103  -2.9749464988708496  1.10358726978302  \
# 0  gi6uaa83           -0.344760            -4.762074          3.647769
# 1  le0ogx1s           -3.257521            -1.720686          1.438893
# 2  fy4w7xz8            0.920366            -3.546179         -2.537739
# 3  0qaoam29           -1.145982            -5.231421         -1.958305
# ...

# %%
os.listdir(DATA_RAW + "biorxiv_medrxiv/biorxiv_medrxiv/pdf_json/")
# Out:
# ['f6b29be971089bfe0916c64ab9fbddcec38a7436.json',
#  '005d189d5bd7ac01aee65e934fd3d5186a3f7b27.json',
#  'f905f78b32f63c6d14a79984dfb33f1b358b8ab4.json',
#  '607e0074d8ff40c272b958c2fe48793fedfc785e.json',
#  '72e25b728c6c62fb3a4e2c59c8ee48de4b5ee452.json',
#  'abcfffafab399149d4adadd6bb458c4994e2025d.json',
#  'e21a63c59ebf691e9a24a6bb24add31dbec1f5c9.json',
#  '0cb9c296684ca5e71462d825cab2827854a01544.json',
#  '9bbfd3d34ee18ea1b9f4669331a6cee9c5992893.json',
#  '1218f278a4f8d83dac14b23c8f698062812ef9d5.json',
#  '8695528795dd02723afd17afba6e768d08372aba.json',
#  'a59906b732bf4a489e282c3e4f499d4166c622e7.json',
#  'e3d6b0147b16ad21ae546062001eba8cc7f8b5e1.json',
#  'baabfb35a321ea12028160e0d2c1552a2fda2dd5.json',
#  'ede6d3dd00106ea18dddda868694b414c7ed1872.json',
#  '5ec284329dfa97be65ed5e598c40426f03499186.json',
#  '78ab35770cc98632c434523df48c6ba290182d37.json',
#  'da3014104863a5bb44aef3ed816a61682c8b1ab1.json',
#  '21100aba41a4bfb48d7dc37f1bf5dbb38bf3867a.json',
# ...

# %%
# 'COVID.DATA.LIC.AGMT.pdf'

# %%
os.listdir(DATA_RAW + "comm_use_subset/comm_use_subset/pmc_json/")
# Out:
# ['PMC5396510.xml.json',
#  'PMC5678581.xml.json',
#  'PMC3795028.xml.json',
#  'PMC2860491.xml.json',
#  'PMC3256159.xml.json',
#  'PMC4776189.xml.json',
#  'PMC4455164.xml.json',
#  'PMC6465995.xml.json',
#  'PMC3524174.xml.json',
#  'PMC5441046.xml.json',
#  'PMC4804562.xml.json',
#  'PMC7029759.xml.json',
#  'PMC3997935.xml.json',
#  'PMC4776188.xml.json',
#  'PMC3227431.xml.json',
#  'PMC4687304.xml.json',
#  'PMC5979762.xml.json',
#  'PMC4000993.xml.json',
#  'PMC6925039.xml.json',
#  'PMC2761414.xml.json',
#  'PMC5869239.xml.json',
#  'PMC4984648.xml.json',
#  'PMC6542035.xml.json',
#  'PMC2440799.xml.json',
#  'PMC2741444.xml.json',
#  'PMC4830830.xml.json',
#  'PMC3350496.xml.json',
#  'PMC5661933.xml.json',
#  'PMC4581119.xml.json',
#  'PMC6385038.xml.json',
#  'PMC4420464.xml.json',
#  'PMC3721661.xml.json',
#  'PMC6850198.xml.json',
#  'PMC6474636.xml.json',
#  'PMC5382482.xml.json',
#  'PMC5635493.xml.json',
#  'PMC3473018.xml.json',
#  'PMC6185886.xml.json',
# ...

# %%
os.listdir(DATA_RAW + "comm_use_subset/comm_use_subset/pdf_json/")
# Out:
# ['5e0c586f047ff909c8ed3fe171c8975a90608d08.json',
#  '1579fbff7af9b156c6f49fee0526e48f852ea460.json',
#  'e0668c4b793d0cad26639b070819334a94648123.json',
#  '38aa050ad79d8a1d7022c33535255ce9d47914e5.json',
#  '61722c462b054f36461375e96e502cbf22648c04.json',
#  '7107f088cbed45d8a06a026276ccf4d602d50f10.json',
#  '2188208efc7ac8e7721dfc5cbea787d5b62c3537.json',
#  'dd74c8f2961dc716ec9d0c412206c88e0cb9b314.json',
#  'e4df800c7ec3d4e38f9609049d8d934edae25ae1.json',
#  '2530bf775255e8026438e91645aba95d0506928e.json',
#  '48bd5f768f3464ac253a120d2eddeb89c323f324.json',
#  '2f38704ef0009750d4c48d1cd7ac81e898023527.json',
#  '207885268ef61365fc89820ecb7c854a3dc23d9a.json',
#  '6810812121d66ad44b45c388c3744a4b5f3bb001.json',
#  '1d39fce3c09c95c13c9b8e18c1ab9a85c24ff7c6.json',
#  'a4ac0a556416712bc053f001c5bc6931c908bfd1.json',
#  '2106f8105f3cb30bf479fdcb6d78e4891a204080.json',
#  '62a87de16c26fdb905173879c56ec19a2879921f.json',
#  'd933299806fcd4e9e8a61e7760267154926c05ee.json',
# ...
