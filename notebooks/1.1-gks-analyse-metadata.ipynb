# %%
# %run ./0.0-gks-utility-functions.ipynb
# %run ./0.1-gks-matplotlib-plots.ipynb

# %%
PARENT = "/usr/local/git/kaggle-covid-19/"
DATA_RAW = PARENT + "data/raw/CORD-19-research-challenge/"
DATA_INTERIM = PARENT + "data/interim/"

# %%
METADATA = DATA_RAW + "metadata.csv"

# %%
df = detail_csv_file(METADATA, usecols=['cord_uid', 'source_x', 'title', 'authors', 'authors', 'abstract',
                                        'has_pdf_parse', 'has_pmc_xml_parse', 'full_text_file'])
# Out:
# Kwargs:  {'usecols': ['cord_uid', 'source_x', 'title', 'authors', 'authors', 'abstract', 'has_pdf_parse', 'has_pmc_xml_parse', 'full_text_file']}
# DataFrame Size: (57366, 8)
# DataFrame Columns: Index(['cord_uid', 'source_x', 'title', 'abstract', 'authors', 'has_pdf_parse',
#        'has_pmc_xml_parse', 'full_text_file'],
#       dtype='object')

# %%
df.head()
# Out:
#    cord_uid source_x                                              title  \
# 0  zjufx4fo      PMC  Sequence requirements for RNA strand transfer ...
# 1  ymceytj3      PMC  Crystal structure of murine sCEACAM1a[1,4]: a ...
# 2  wzj2glte      PMC  Synthesis of a novel hepatitis C virus protein...
# 3  2sfqsfm1      PMC  Structure of coronavirus main proteinase revea...
# 4  i0zym7iq      PMC  Discontinuous and non-discontinuous subgenomic...
#
#                                             abstract  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...
# 1  CEACAM1 is a member of the carcinoembryonic an...
# 2  Hepatitis C virus (HCV) is an important human ...
# 3  The key enzyme in coronavirus polyprotein proc...
# 4  Arteri-, corona-, toro- and roniviruses are ev...
#
#                                              authors  has_pdf_parse  \
# 0  Pasternak, Alexander O.; van den Born, Erwin; ...           True
# 1  Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...           True
# 2  Xu, Zhenming; Choi, Jinah; Yen, T.S.Benedict; ...           True
# 3  Anand, Kanchan; Palm, Gottfried J.; Mesters, J...           True
# 4  van Vliet, A.L.W.; Smits, S.L.; Rottier, P.J.M...           True
#
#    has_pmc_xml_parse  full_text_file
# 0               True  custom_license
# 1               True  custom_license
# 2               True  custom_license
# 3               True  custom_license
# 4               True  custom_license

# %%
df.source_x.unique()
# Out:
# array(['PMC', 'Elsevier', 'CZI', 'WHO', 'biorxiv', 'medrxiv'],
#       dtype=object)

# %%
df.has_pdf_parse.sum()
# Out:
# 43540

# %%
df.has_pmc_xml_parse.sum()
# Out:
# 22263

# %%
df.full_text_file.unique()
# Out:
# array(['custom_license', 'comm_use_subset', nan, 'noncomm_use_subset',
#        'biorxiv_medrxiv'], dtype=object)

# %% [markdown]
# ## metadata analysis

# %%
# author analysis

author_publication_distribution = dict()


for i, row in df.iterrows():
    if isinstance(row["authors"], str):
        authors = row['authors'].split(";")

        for pos, author in enumerate(authors):
            author = author.strip()
            if author_publication_distribution.get(author):
                if author_publication_distribution[author].get(pos):
                    author_publication_distribution[author][pos] += 1
                else:
                    author_publication_distribution[author][pos] = 1
            else:
                author_publication_distribution[author] = {pos: 1}

# %%
author_publication_distribution
# Out:
# {'Pasternak, Alexander O.': {0: 4},
#  'van den Born, Erwin': {1: 3, 6: 1, 2: 1, 5: 1},
#  'Spaan, Willy J.M.': {2: 1, 3: 5, 6: 2, 0: 1, 4: 3, 1: 2, 8: 1, 5: 1},
#  'Snijder, Eric J.': {3: 20,
#   5: 12,
#   4: 18,
#   2: 11,
#   6: 14,
#   11: 3,
#   9: 5,
#   7: 4,
#   10: 4,
#   14: 2,
#   12: 3,
#   1: 11,
#   0: 5,
#   8: 3},
#  'Tan, Kemin': {0: 1},
#  'Zelus, Bruce D.': {1: 3, 0: 2},
#  'Meijers, Rob': {2: 1},
#  'Liu, Jin-huan': {3: 1},
#  'Bergelson, Jeffrey M.': {4: 1, 1: 1},
#  'Duke, Norma': {5: 1},
#  'Zhang, Rongguang': {6: 2, 17: 1, 10: 1, 4: 2, 8: 3, 13: 1, 18: 1, 5: 1},
#  'Joachimiak, Andrzej': {7: 2, 10: 1, 4: 1, 6: 1, 5: 1},
#  'Holmes, Kathryn V.': {8: 3,
#   6: 9,
#   21: 1,
#   3: 8,
#   1: 7,
#   2: 9,
#   9: 2,
#   22: 1,
#   0: 6,
#   5: 7,
#   4: 8,
#   13: 3,
#   7: 4,
#   10: 3},
#  'Wang, Jia-huai': {9: 1},
#  'Xu, Zhenming': {0: 1},
#  'Choi, Jinah': {1: 1, 2: 1},
#  'Yen, T.S.Benedict': {2: 1},
#  'Lu, Wen': {3: 1, 0: 1},
#  'Strohecker, Anne': {4: 1},
#  'Govindarajan, Sugantha': {5: 1},
#  'Chien, David': {6: 1},
#  'Selby, Mark J.': {7: 1},
#  'Ou, Jing‐hsiung': {8: 1},
#  'Anand, Kanchan': {0: 2, 1: 1, 11: 1, 2: 1},
#  'Palm, Gottfried J.': {1: 1},
#  'Mesters, Jeroen R.': {2: 3, 7: 1, 1: 3, 5: 1, 4: 1, 9: 1, 3: 1},
#  'Siddell, Stuart G.': {3: 4,
#   2: 6,
#   8: 2,
#   6: 2,
#   4: 3,
#   13: 1,
#   9: 1,
#   5: 6,
#   1: 4,
#   7: 1,
#   0: 1,
#   10: 1},
#  'Ziebuhr, John': {4: 8,
#   9: 5,
#   8: 4,
#   5: 9,
#   1: 2,
#   21: 1,
#   2: 7,
#   7: 4,
#   0: 6,
#   17: 1,
#   6: 3,
#   3: 4,
#   16: 1,
#   11: 1},
#  'Hilgenfeld, Rolf': {5: 9,
#   1: 4,
#   10: 3,
#   9: 2,
#   15: 2,
#   6: 4,
#   13: 3,
#   4: 5,
#   0: 4,
#   8: 1,
#   11: 2,
#   7: 2,
#   3: 1,
#   2: 6,
#   18: 1},
#  'van Vliet, A.L.W.': {0: 1},
#  'Smits, S.L.': {1: 1, 6: 2, 4: 1, 3: 1, 2: 1, 11: 1},
#  'Rottier, P.J.M.': {2: 1, 5: 2, 6: 3, 4: 1},
#  'de Groot, R.J.': {3: 1, 0: 1, 7: 1, 2: 1},
#  'Myatt, Theodore A': {0: 2},
#  'Johnston, Sebastian L': {1: 3, 8: 1, 3: 2, 4: 2, 2: 1, 0: 1, 5: 1},
#  'Rudnick, Stephen': {2: 1},
#  'Milton, Donald K': {3: 1},
#  'Disotell, Todd R': {0: 1},
#  'Napthine, Sawsan': {0: 6, 2: 2, 4: 1, 1: 3},
#  'Vidakovic, Marijana': {1: 2, 2: 2},
#  'Girnary, Roseanne': {2: 1},
#  'Namy, Olivier': {3: 1, 4: 1, 0: 1, 2: 2, 1: 1},
#  'Brierley, Ian': {4: 7, 2: 7, 5: 6, 1: 2, 8: 1, 7: 1, 0: 8, 11: 1, 3: 2},
#  'Petsko, Gregory A': {0: 1},
#  'Salcedo, Suzana P.': {0: 1, 1: 1},
#  'Holden, David W.': {1: 2},
#  'Lin, Marie': {0: 1},
#  'Tseng, Hsiang-Kuang': {1: 1},
#  'Trejaut, Jean A': {2: 1},
#  'Lee, Hui-Lin': {3: 1},
#  'Loo, Jun-Hun': {4: 1},
#  'Chu, Chen-Chung': {5: 1, 4: 1},
#  'Chen, Pei-Jan': {6: 1, 4: 1, 3: 2, 1: 1},
#  'Su, Ying-Wen': {7: 1},
#  'Lim, Ken Hong': {8: 1},
#  'Tsai, Zen-Uong': {9: 1},
#  'Lin, Ruey-Yi': {10: 1},
#  'Lin, Ruey-Shiung': {11: 1, 3: 1},
#  'Huang, Chun-Hsiung': {12: 1, 2: 1},
#  'Ng, Tuen Wai': {0: 1},
#  'Turinici, Gabriel': {1: 1},
#  'Danchin, Antoine': {2: 2, 8: 1, 0: 3, 54: 1},
#  'Kliger, Yossef': {0: 3},
#  'Levanon, Erez Y': {1: 1},
#  'Yap, Yee Leng': {0: 1, 1: 5},
#  'Zhang, Xue Wu': {1: 1, 0: 6},
#  'Wang, David': {0: 4,
#   5: 3,
#   9: 1,
#   6: 3,
#   8: 2,
#   7: 2,
#   2: 2,
#   3: 2,
#   1: 2,
#   4: 2,
#   10: 1},
#  'Urisman, Anatoly': {1: 2, 0: 1, 3: 1},
#  'Liu, Yu-Tsueng': {2: 1, 7: 1, 0: 2, 9: 1},
#  'Springer, Michael': {3: 1},
#  'Ksiazek, Thomas G': {4: 1, 5: 1},
#  'Erdman, Dean D': {5: 1, 17: 1, 20: 1},
#  'Mardis, Elaine R': {6: 1},
#  'Hickenbotham, Matthew': {7: 1},
#  'Magrini, Vincent': {8: 1},
#  'Eldred, James': {9: 1},
#  'Latreille, J. Phillipe': {10: 1},
#  'Wilson, Richard K': {11: 1},
#  'Ganem, Don': {12: 3, 13: 2, 7: 1, 5: 1, 8: 1, 11: 1},
#  'DeRisi, Joseph L': {13: 1, 6: 1, 14: 1, 8: 1, 20: 1},
#  'Wlodawer, Alexander': {0: 1, 3: 1, 10: 1, 7: 2, 5: 1, 8: 1},
#  'Durell, Stewart R': {1: 1},
#  'Li, Mi': {2: 2},
#  'Oyama, Hiroshi': {3: 1},
#  'Oda, Kohei': {4: 1},
#  'Dunn, Ben M': {5: 1},
#  'Cui, Yan': {0: 1, 3: 1},
#  'Zhang, Zuo-Feng': {1: 1, 3: 1},
#  'Froines, John': {2: 1},
#  'Zhao, Jinkou': {3: 1},
#  'Wang, Hua': {4: 3,
#   5: 4,
#   14: 2,
#   9: 3,
#   6: 1,
#   8: 5,
#   2: 3,
#   10: 2,
#   3: 1,
#   0: 1,
#   13: 1},
#  'Yu, Shun-Zhang': {5: 1},
#  'Detels, Roger': {6: 1, 2: 1, 4: 1},
#  'Poh Ng, Lisa Fong': {0: 1},
#  'Shi, Stephanie T.': {0: 3},
#  'Huang, Peiyong': {1: 2, 0: 2},
#  'Li, Hsin-Pai': {2: 2, 0: 2, 4: 1},
#  'Lai, Michael M.C.': {3: 10, 2: 9, 0: 2, 1: 3, 5: 3, 4: 7, 7: 1},
#  'Pridgeon, Julia W.': {0: 2, 1: 1},
#  'Geetha, Thangiah': {1: 1},
#  'Wooten, Marie W.': {2: 1},
#  'Ploubidou, Aspasia': {0: 2},
#  'Moreau, Violaine': {1: 1},
#  'Ashman, Keith': {2: 1},
#  'Reckmann, Inge': {3: 1},
#  'González, Cayetano': {4: 1},
#  'Way, Michael': {5: 1, 1: 1},
#  'Boulos, Maged N Kamel': {0: 4},
#  'Gomersall, Charles D': {0: 2, 9: 1},
#  'Kargel, Marcus J': {1: 1},
#  'Lapinsky, Stephen E': {2: 1, 0: 1, 1: 1},
#  'Granton, Jeff': {0: 1},
#  'Granton, John': {1: 1, 16: 1},
#  'Ball, Jonathan': {0: 2},
#  'McMahon, James M': {0: 1},
#  'Simm, Malgorzata': {1: 1},
#  'Milano, Danielle': {2: 1},
#  'Clatts, Michael': {3: 1},
#  'Pavlović-Lažetić, Gordana M': {0: 1},
#  'Mitić, Nenad S': {1: 1},
#  'Beljanski, Miloš V': {2: 1},
#  'Kiemer, Lars': {0: 1},
#  'Lund, Ole': {1: 3, 2: 2, 15: 1, 8: 1, 17: 1, 3: 1, 5: 1},
#  'Brunak, Søren': {2: 1, 20: 1, 3: 1},
#  'Blom, Nikolaj': {3: 1},
#  'Zhao, Zhongming': {0: 2},
#  'Li, Haipeng': {1: 1},
#  'Wu, Xiaozhuang': {2: 1},
#  'Zhong, Yixi': {3: 1},
#  'Zhang, Keqin': {4: 1},
#  'Zhang, Ya-Ping': {5: 2, 9: 1},
#  'Boerwinkle, Eric': {6: 1},
#  'Fu, Yun-Xin': {7: 1},
#  'Farr, Barry M': {0: 2},
#  'Bellingan, Geoffrey': {1: 1},
#  'Brodie, Ryan': {0: 1},
#  'Smith, Alex J': {1: 1},
#  'Roper, Rachel L': {2: 1, 0: 1},
#  'Tcherepanov, Vasily': {3: 2, 0: 1},
#  'Upton, Chris': {4: 2, 2: 1, 1: 1},
#  'Lu, Hongchao': {0: 1, 6: 1},
#  'Zhao, Yi': {1: 1, 5: 1, 8: 1},
#  'Zhang, Jingfen': {2: 1, 7: 1},
#  'Wang, Yuelan': {3: 1},
#  'Li, Wei': {4: 8,
#   0: 4,
#   5: 4,
#   2: 4,
#   3: 9,
#   10: 1,
#   7: 1,
#   1: 7,
#   18: 1,
#   21: 1,
#   13: 1,
#   9: 1,
#   1196: 1,
#   1197: 1,
#   6: 3,
#   22: 1,
#   14: 1,
#   8: 1},
#  'Zhu, Xiaopeng': {5: 1},
#  'Sun, Shiwei': {6: 1, 2: 1, 5: 1},
#  'Xu, Jingyi': {7: 1},
#  'Ling, Lunjiang': {8: 1, 9: 1},
#  'Cai, Lun': {9: 1},
#  'Bu, Dongbo': {10: 2, 8: 1},
#  'Chen, Runsheng': {11: 1, 10: 1, 5: 1},
#  'Sheng, Jinsong': {0: 1, 3: 1, 1: 1},
#  'Organ, Edward L': {1: 1},
#  'Hao, Chuanming': {2: 1},
#  'Wells, K Sam': {3: 1},
#  'Ruley, H Earl': {4: 1},
#  'Rubin, Donald H': {5: 2},
#  'Vega, Vinsensius B': {0: 1, 7: 1, 3: 1},
#  'Ruan, Yijun': {1: 1, 2: 1, 9: 1, 0: 1},
#  'Liu, Jianjun': {2: 1, 0: 1, 1: 1},
#  'Lee, Wah Heng': {3: 1, 2: 1, 0: 1},
#  'Wei, Chia Lin': {4: 2, 1: 1},
#  'Se-Thoe, Su Yun': {5: 1, 4: 1},
#  'Tang, Kin Fai': {6: 1, 2: 1},
#  'Zhang, Tao': {7: 2, 0: 4, 3: 2, 10: 2, 2: 1, 5: 1, 4: 2},
#  'Kolatkar, Prasanna R': {8: 1},
#  'Ooi, Eng Eong': {9: 1, 0: 1, 8: 2, 1: 1, 2: 2, 3: 4, 5: 1, 6: 2, 16: 1},
#  'Ling, Ai Ee': {10: 3, 3: 1, 2: 2, 8: 1, 4: 2, 5: 1},
#  'Stanton, Lawrence W': {11: 1, 7: 1, 17: 1},
#  'Long, Philip M': {12: 1, 18: 1},
#  'Liu, Edison T': {13: 1, 9: 1, 6: 1, 7: 1, 19: 1},
#  'Ng, Lisa FP': {0: 2, 15: 1},
#  'Hibberd, Martin L': {1: 1, 8: 1, 6: 2},
#  'Ooi, Eng-Eong': {2: 2, 7: 1, 1: 1, 4: 1, 6: 1, 3: 1},
#  'Tang, Kin-Fai': {3: 1},
#  'Neo, Soek-Ying': {4: 1},
#  'Tan, Jenny': {5: 1, 8: 1},
#  'Krishna Murthy, Karuturi R': {6: 1},
#  'Chia, Jer-Ming': {8: 1, 6: 1},
#  'Ren, Ee-Chee': {10: 3},
#  'Porco, Travis C': {0: 1},
#  'Holbrook, Karen A': {1: 1},
#  'Fernyak, Susan E': {2: 1, 1: 1},
#  'Portnoy, Diane L': {3: 1},
#  'Reiter, Randy': {4: 1},
#  'Aragón, Tomás J': {5: 1, 0: 1},
#  'Garry, Robert F': {0: 1, 1: 5, 2: 1},
#  'Coyle, Peter V': {0: 1},
#  'Ong, Grace M': {1: 1},
#  "O'Neill, Hugh J": {2: 1},
#  'McCaughey, Conall': {3: 2},
#  'De Ornellas, Dennis': {4: 1},
#  'Mitchell, Frederick': {5: 1},
#  'Mitchell, Suzanne J': {6: 1},
#  'Feeney, Susan A': {7: 1},
#  'Wyatt, Dorothy E': {8: 1},
#  'Forde, Marian': {9: 1},
#  'Stockton, Joanne': {10: 1},
#  'Chidwick, Paula': {0: 1},
#  'Faith, Karen': {1: 1},
#  'Godkin, Dianne': {2: 1},
#  'Hardingham, Laurie': {3: 1},
#  'Meadows, Emily': {0: 1},
#  'Le Saux, Nicole': {1: 1},
#  'Garry, Courtney E': {0: 3},
#  'Pyrc, Krzysztof': {0: 9,
#   6: 3,
#   4: 3,
#   3: 5,
#   14: 1,
#   8: 2,
#   7: 3,
#   9: 5,
#   5: 3,
#   1: 5,
#   2: 1,
#   11: 1,
#   10: 1},
#  'Jebbink, Maarten F': {1: 2, 5: 1, 4: 1, 3: 1, 2: 1},
#  'Berkhout, Ben': {2: 7,
#   7: 5,
#   8: 2,
#   3: 5,
#   1: 6,
#   4: 3,
#   9: 1,
#   5: 6,
#   6: 1,
#   0: 4,
#   145: 1},
#  'van der Hoek, Lia': {3: 3,
#   8: 6,
#   0: 5,
#   9: 4,
#   4: 5,
#   1: 6,
#   19: 1,
#   7: 6,
#   12: 3,
#   14: 3,
#   6: 4,
#   13: 1,
#   10: 1,
#   24: 1,
#   5: 3,
#   110: 1,
#   2: 3},
#  'Robertson, Michael P': {0: 1},
#  'Igel, Haller': {1: 1},
#  'Baertsch, Robert': {2: 1},
#  'Haussler, David': {3: 1, 11: 1},
#  'Ares, Manuel': {4: 1},
#  'Scott, William G': {5: 1},
#  'Bell, Jennifer AH': {0: 1},
#  'Hyland, Sylvia': {1: 1},
#  'DePellegrin, Tania': {2: 1},
#  'Upshur, Ross EG': {3: 1, 6: 1, 2: 1, 1: 1},
#  'Bernstein, Mark': {4: 1, 3: 1, 0: 2, 2: 2},
#  'Martin, Douglas K': {5: 1, 4: 1},
#  'Cooray, Samantha': {0: 2},
#  'Jin, Li': {1: 2, 3: 1, 2: 1},
#  'Best, Jennifer M': {2: 1},
#  'Bratlie, Marit S': {0: 1},
#  'Drabløs, Finn': {1: 1, 2: 2},
#  'Xie, Lixin': {0: 2, 3: 1},
#  'Liu, Youning': {1: 2},
#  'Fan, Baoxing': {2: 1, 5: 1, 8: 1, 4: 1},
#  'Xiao, Yueyong': {3: 1, 2: 1},
#  'Tian, Qing': {4: 1, 3: 1},
#  'Chen, Liangan': {5: 1},
#  'Zhao, Hong': {6: 1, 2: 1, 27: 1, 1: 2, 3: 1, 4: 1, 5: 1},
#  'Chen, Weijun': {7: 1, 9: 1, 16: 1, 0: 2, 14: 1, 27: 1, 37: 1, 6: 1, 32: 1},
#  'Le Loir, Yves': {0: 1, 3: 2},
#  'Azevedo, Vasco': {1: 1, 6: 2, 12: 1, 16: 1},
#  'Oliveira, Sergio C': {2: 1},
#  'Freitas, Daniela A': {3: 1},
#  'Miyoshi, Anderson': {4: 1, 0: 1, 14: 1},
#  'Bermúdez-Humarán, Luis G': {5: 1, 1: 1, 0: 1},
#  'Nouaille, Sébastien': {6: 1},
#  'Ribeiro, Luciana A': {7: 1, 2: 1},
#  'Leclercq, Sophie': {8: 1},
#  'Gabriel, Jane E': {9: 1},
#  'Guimaraes, Valeria D': {10: 1},
#  'Oliveira, Maricê N': {11: 1},
#  'Charlier, Cathy': {12: 1},
#  'Gautier, Michel': {13: 1},
#  'Langella, Philippe': {14: 1, 5: 1, 3: 1, 1: 2, 7: 1, 4: 1},
#  'Robinson, Joan L': {0: 1},
#  'Jou, Hsing': {1: 1},
#  'Spady, Donald W': {2: 1},
#  'Lee, Kelley': {0: 5, 1: 4, 13: 1},
#  'Koivusalo, Meri': {1: 1},
#  'Elmén, Joacim': {0: 1},
#  'Thonberg, Håkan': {1: 1},
#  'Ljungberg, Karl': {2: 1},
#  'Frieden, Miriam': {3: 1},
#  'Westergaard, Majken': {4: 1},
#  'Xu, Yunhe': {5: 1},
#  'Wahren, Britta': {6: 1, 12: 1},
#  'Liang, Zicai': {7: 1, 10: 1},
#  'Ørum, Henrik': {8: 1, 6: 1},
#  'Koch, Troels': {9: 1},
#  'Wahlestedt, Claes': {10: 1},
#  'Dufraigne, Christine': {0: 1},
#  'Fertil, Bernard': {1: 2, 0: 1},
#  'Lespinats, Sylvain': {2: 2, 0: 1},
#  'Giron, Alain': {3: 1, 5: 1},
#  'Deschavanne, Patrick': {4: 1},
#  'Reghunathan, Renji': {0: 1, 2: 1, 3: 1},
#  'Jayapal, Manikandan': {1: 2, 0: 1},
#  'Hsu, Li-Yang': {2: 1, 0: 2, 1: 1},
#  'Chng, Hiok-Hee': {3: 1},
#  'Tai, Dessmon': {4: 1},
#  'Leung, Bernard P': {5: 1},
#  'Melendez, Alirio J': {6: 2},
#  'Groneberg, David A': {0: 2, 6: 1},
#  'Zabel, Peter': {2: 1, 5: 1},
#  'Horejsh, Douglas': {0: 1, 4: 1, 5: 1},
#  'Martini, Federico': {1: 1, 3: 1, 12: 1, 7: 1, 2: 2},
#  'Poccia, Fabrizio': {2: 1, 11: 1, 0: 4, 10: 1, 4: 1},
#  'Ippolito, Giuseppe': {3: 5,
#   8: 4,
#   10: 4,
#   15: 2,
#   9: 3,
#   12: 1,
#   32: 1,
#   6: 1,
#   2: 3,
#   0: 2,
#   4: 3,
#   29: 1,
#   13: 2,
#   54: 1,
#   5: 2,
#   1: 1,
#   16: 2,
#   18: 1},
#  'Di Caro, Antonino': {4: 2, 11: 2, 7: 1, 2: 1, 0: 2, 3: 1},
#  'Capobianchi, Maria R.': {5: 1, 10: 1, 1: 1, 11: 1, 7: 1, 9: 1},
#  'Radonić, Aleksandar': {0: 1, 3: 1},
#  'Thulke, Stefanie': {1: 1},
#  'Bae, Hi-Gung': {2: 1},
#  'Müller, Marcel A': {3: 1, 2: 2, 0: 3, 1: 1, 17: 1, 7: 1, 5: 2, 10: 1},
#  'Siegert, Wolfgang': {4: 1},
#  'Nitsche, Andreas': {5: 3, 4: 3, 0: 1, 1: 1, 6: 2, 2: 1, 9: 1},
#  'Moës, Elien': {0: 1, 1: 1, 2: 2, 3: 1},
#  'Vijgen, Leen': {1: 6, 2: 3, 0: 7},
#  'Keyaerts, Els': {2: 4, 1: 7, 0: 6, 3: 1},
#  'Zlateva, Kalina': {3: 1, 2: 1},
#  'Li, Sandra': {4: 2, 3: 1, 1: 2},
#  'Maes, Piet': {5: 2, 7: 3, 8: 1, 3: 4, 6: 2, 1: 1, 0: 1, 2: 3},
#  'Van Ranst, Marc': {9: 2,
#   8: 3,
#   7: 8,
#   35: 2,
#   1: 1,
#   4: 1,
#   5: 7,
#   6: 4,
#   0: 1,
#   3: 2},
#  'Karaman, Mazen W.': {0: 1},
#  'Groshen, Susan': {1: 1},
#  'Lee, Chi-Chiang': {2: 1},
#  'Pike, Brian L.': {3: 1, 0: 1},
#  'Hacia, Joseph G.': {4: 1},
#  'Tan, Yee-Joo': {0: 7,
#   7: 4,
#   2: 8,
#   3: 6,
#   12: 1,
#   5: 4,
#   1: 5,
#   4: 1,
#   10: 2,
#   2064: 1,
#   8: 3,
#   16: 1,
#   13: 1,
#   6: 3,
#   9: 1},
#  'Dentico, Nicoletta': {0: 1},
#  'Ford, Nathan': {1: 1, 0: 1, 2: 1},
#  'Lim, Siew Lan': {1: 1},
#  'Ng, Lisa F. P': {4: 1},
#  'Drosten, Christian': {5: 14,
#   4: 13,
#   11: 14,
#   1: 6,
#   2: 7,
#   7: 9,
#   9: 9,
#   3: 14,
#   8: 12,
#   10: 3,
#   26: 1,
#   0: 7,
#   33: 1,
#   18: 3,
#   20: 2,
#   36: 1,
#   6: 10,
#   16: 6,
#   12: 4,
#   13: 5,
#   17: 7,
#   14: 3,
#   19: 2,
#   15: 5,
#   27: 2,
#   30: 1,
#   21: 1,
#   23: 2,
#   22: 1},
#  'Zhu, Hu': {0: 1},
#  'Chang Chan, Hsiao': {1: 1},
#  'Zhou, Zuoming': {2: 1},
#  'Li, Jianming': {3: 1, 8: 1},
#  'Zhu, Hui': {4: 1, 8: 1, 6: 1},
#  'Yin, Lanlan': {5: 1},
#  'Xu, Ming': {6: 1},
#  'Cheng, Lijun': {7: 1},
#  'Sha, Jiahao': {8: 1},
#  'Plyusnina, Angelina': {0: 1, 5: 1},
#  'Plyusnin, Alexander': {1: 1, 8: 1, 9: 1},
#  'Barraclough, Simon': {0: 2},
#  'Sainz, Bruno': {0: 5, 1: 2},
#  'LaMarca, Heather L': {1: 1},
#  'Morris, Cindy A': {3: 1, 2: 1},
#  'Saad, Ali Samir': {0: 1},
#  'Froissart, Remy': {0: 1},
#  'Roze, Denis': {1: 1},
#  'Uzest, Marilyne': {2: 1},
#  'Galibert, Lionel': {3: 1},
#  'Blanc, Stephane': {4: 1},
#  'Michalakis, Yannis': {5: 1},
#  'Rogers, Sharon': {0: 1},
#  'Wax, Randy': {1: 1},
#  'Showalter, Randy': {2: 1},
#  'Martinez-Motta, J Carlos': {3: 1},
#  'Hallett, David': {4: 1},
#  'Mehta, Sangeeta': {5: 1, 7: 1, 8: 1, 2: 1},
#  'Burry, Lisa': {6: 1},
#  'Stewart, Thomas E': {7: 1, 2: 1, 1: 1},
#  'Suntharalingam, Ganesh': {0: 1},
#  'Cousins, Jonathan': {1: 1},
#  'Gattas, David': {2: 1},
#  'Chapman, Martin': {3: 1, 4: 1},
#  'Manktelow, Emily': {0: 1, 1: 1},
#  'Shigemoto, Kazuhiro': {1: 1},
#  'Binkowski, Brock F.': {0: 1},
#  'Richmond, Kathryn E.': {1: 1},
#  'Kaysen, James': {2: 1},
#  'Sussman, Michael R.': {3: 1},
#  'Belshaw, Peter J.': {4: 1},
#  'Endoh, Daiji': {0: 1, 5: 1, 1: 1, 10: 1, 24: 1},
#  'Mizutani, Tetsuya': {1: 5,
#   10: 2,
#   8: 3,
#   0: 10,
#   12: 2,
#   4: 3,
#   23: 1,
#   9: 2,
#   21: 1,
#   3: 4,
#   17: 5,
#   6: 1,
#   22: 1,
#   2: 1,
#   5: 1,
#   25: 1},
#  'Kirisawa, Rikio': {2: 1},
#  'Maki, Yoshiyuki': {3: 1},
#  'Saito, Hidetoshi': {4: 1},
#  'Kon, Yasuhiro': {5: 1, 2: 1},
#  'Morikawa, Shigeru': {6: 5,
#   7: 3,
#   15: 1,
#   9: 6,
#   1: 2,
#   3: 2,
#   21: 1,
#   4: 11,
#   14: 2,
#   32: 1,
#   2: 4,
#   13: 2,
#   8: 4,
#   48: 1,
#   26: 1,
#   5: 3,
#   10: 1,
#   0: 1,
#   25: 1,
#   23: 1},
#  'Hayashi, Masanobu': {7: 1},
#  'Jackson, William T': {0: 1, 2: 1, 905: 1},
#  'Giddings, Thomas H': {1: 1},
#  'Taylor, Matthew P': {2: 1},
#  'Mulinyawe, Sara': {3: 1},
#  'Rabinovitch, Marlene': {4: 1},
#  'Kopito, Ron R': {5: 1},
#  'Kirkegaard, Karla': {6: 1, 2: 2, 4: 1, 0: 3, 8: 1, 1: 2, 1037: 1, 3: 2},
#  'Lee, Cheng-Hua': {0: 1, 2: 1},
#  'Huang, Nicole': {1: 3},
#  'Chang, Hong-Jen': {2: 2, 0: 2},
#  'Hsu, Yea-Jen': {3: 2},
#  'Wang, Mei-Chu': {4: 1},
#  'Chou, Yiing-Jenq': {5: 2, 2: 1, 1: 1},
#  'Stark, Caren J': {0: 1},
#  'Atreya, CD': {1: 1},
#  'Gibbs, Mark J': {0: 1, 6: 1},
#  'Armstrong, John S': {1: 1},
#  'Gibbs, Adrian J': {2: 1},
#  'Chan, KC Allen': {0: 1, 2: 2},
#  'Tang, Nelson LS': {1: 2},
#  'Hui, David SC': {2: 1, 15: 1, 1: 1},
#  'Chung, Grace TY': {3: 1, 0: 1, 2: 1},
#  'Wu, Alan KL': {4: 1},
#  'Chim, Stephen SC': {5: 1, 4: 2, 7: 1, 6: 1},
#  'Chiu, Rossa WK': {6: 1, 1: 1, 0: 1, 4: 2},
#  'Lee, Nelson': {7: 3,
#   5: 5,
#   0: 11,
#   11: 1,
#   1: 10,
#   8: 1,
#   4: 2,
#   3: 3,
#   2: 1,
#   6: 1},
#  'Choi, KW': {8: 1},
#  'Sung, YM': {9: 1},
#  'Chan, Paul KS': {10: 2, 5: 1, 2: 1, 16: 1, 11: 1, 12: 1},
#  'Tong, YK': {11: 1, 5: 1},
#  'Lai, ST': {12: 1, 8: 1, 1: 1},
#  'Yu, WC': {13: 1, 1: 1},
#  'Tsang, Owen': {14: 1},
#  'Lo, YM Dennis': {15: 1, 6: 1, 10: 1, 8: 1},
#  'Plant, Ewan P': {0: 1},
#  'Pérez-Alvarado, Gabriela C': {1: 1},
#  'Jacobs, Jonathan L': {2: 1},
#  'Mukhopadhyay, Bani': {3: 1},
#  'Hennig, Mirko': {4: 1, 11: 1, 1: 1},
#  'Dinman, Jonathan D': {5: 1, 1: 1, 0: 1},
#  'Ecker, David J': {0: 1, 2: 1},
#  'Sampath, Rangarajan': {1: 2, 0: 3, 13: 1, 4: 2, 15: 1, 7: 2, 9: 1, 6: 1},
#  'Willett, Paul': {2: 1},
#  'Wyatt, Jacqueline R': {3: 1},
#  'Samant, Vivek': {4: 1, 14: 1},
#  'Massire, Christian': {5: 2, 2: 3, 3: 2, 12: 1, 1: 1, 0: 1, 4: 1},
#  'Hall, Thomas A': {6: 1},
#  'Hari, Kumar': {7: 1},
#  'McNeil, John A': {8: 1},
#  'Büchen-Osmond, Cornelia': {9: 1, 15: 1},
#  'Budowle, Bruce': {10: 1, 0: 1, 1: 1, 4: 1},
#  'Brody, Stuart': {0: 1},
#  'Potterat, John J': {1: 1},
#  'Chen, Chia-Nan': {0: 1},
#  'Lin, Coney P. C.': {1: 1},
#  'Huang, Kuo-Kuei': {2: 1, 3: 1, 4: 1},
#  'Chen, Wei-Cheng': {3: 1},
#  'Hsieh, Hsin-Pang': {4: 1},
#  'Liang, Po-Huang': {5: 2, 11: 1, 3: 7, 2: 1, 14: 1, 4: 2, 6: 3, 10: 1, 8: 3},
#  'Hsu, John T.-A.': {6: 1, 5: 2, 9: 1, 4: 1, 0: 1},
#  'Li, Wenhui': {0: 7,
#   5: 1,
#   19: 1,
#   4: 2,
#   2: 5,
#   12: 1,
#   9: 1,
#   6: 1,
#   18: 1,
#   1: 3,
#   7: 2,
#   10: 1,
#   15: 1},
#  'Zhang, Chengsheng': {1: 1, 2: 1, 7: 1, 0: 1, 13: 1},
#  'Sui, Jianhua': {2: 3, 4: 3, 0: 6, 3: 3, 18: 1, 13: 1, 1: 5, 11: 1, 5: 1},
#  'Kuhn, Jens H': {3: 1, 16: 1, 7: 1},
#  'Moore, Michael J': {4: 1},
#  'Luo, Shiwen': {5: 1},
#  'Wong, Swee-Kee': {6: 1, 1: 1},
#  'Huang, I-Chueh': {7: 2, 0: 2, 1: 3, 13: 1, 3: 1, 2: 3, 12: 1, 4: 2, 6: 1},
#  'Xu, Keming': {8: 1},
#  'Vasilieva, Natalya': {9: 1, 2: 1, 3: 1, 7: 1},
#  'Murakami, Akikazu': {10: 1, 3: 1, 11: 1, 2: 2, 4: 1},
#  'He, Yaqing': {11: 1, 3: 1, 2: 1},
#  'Marasco, Wayne A': {12: 1, 3: 1, 0: 1, 4: 1, 16: 1, 1: 1, 2: 1},
#  'Guan, Yi': {13: 2,
#   9: 4,
#   7: 3,
#   4: 3,
#   3: 5,
#   1: 2,
#   23: 1,
#   8: 6,
#   5: 8,
#   6: 4,
#   15: 2,
#   2: 2,
#   10: 2,
#   28: 2,
#   0: 3,
#   12: 2,
#   14: 1,
#   11: 1},
#  'Choe, Hyeryun': {14: 1,
#   8: 1,
#   3: 1,
#   16: 1,
#   11: 4,
#   2: 1,
#   10: 1,
#   5: 3,
#   1: 1,
#   7: 1,
#   9: 1,
#   4: 1,
#   0: 1,
#   6: 1},
#  'Farzan, Michael': {15: 1,
#   6: 8,
#   2: 5,
#   17: 2,
#   10: 2,
#   3: 8,
#   7: 2,
#   14: 1,
#   1: 2,
#   4: 5,
#   11: 1,
#   8: 3,
#   13: 2,
#   9: 1,
#   12: 2,
#   5: 3},
#  'Staple, David W': {0: 1},
#  'Butcher, Samuel E': {1: 1, 4: 1},
#  'Tang, Liang': {0: 1, 9: 1, 12: 1},
#  'Marion, William R': {1: 1},
#  'Cingolani, Gino': {2: 2, 1: 2},
#  'Prevelige, Peter E': {3: 1},
#  'Johnson, John E': {4: 1, 1: 1},
#  'Shegogue, Daniel': {0: 1},
#  'Zheng, W Jim': {1: 1, 3: 1},
#  'Gardner, Shea N': {0: 3, 1: 1, 3: 1},
#  'Wagner, Mark C': {1: 1},
#  'Londhe, Vedang A': {0: 1},
#  'Belperio, John A': {1: 1},
#  'Keane, Michael P': {2: 1},
#  'Burdick, Marie D': {3: 1},
#  'Xue, Ying Ying': {4: 1},
#  'Strieter, Robert M': {5: 1},
#  'Wang, Chun-Hua': {0: 1, 4: 1},
#  'Liu, Chien-Ying': {1: 1},
#  'Wan, Yung-Liang': {2: 2, 0: 1},
#  'Chou, Chun-Liang': {3: 1},
#  'Huang, Kuo-Hsiung': {4: 1},
#  'Lin, Horng-Chyuan': {5: 1},
#  'Lin, Shu-Min': {6: 1},
#  'Lin, Tzou-Yien': {7: 1, 8: 1, 4: 1, 5: 2, 3: 2, 1: 1},
#  'Chung, Kian Fan': {8: 1, 6: 1, 2287: 1},
#  'Kuo, Han-Pin': {9: 1, 3: 1},
#  'Zhang, Guang Lan': {0: 3, 5: 1},
#  'Srinivasan, Kellathur N.': {1: 1},
#  'Veeramani, Anitha': {2: 1},
#  'August, J. Thomas': {3: 1, 5: 1, 10: 1, 9: 2},
#  'Brusic, Vladimir': {4: 1, 7: 3, 8: 2, 1: 1},
#  'Massin, Matthieu': {1: 1},
#  'Devic, Caroline': {3: 1},
#  'Dumee, Philippe': {4: 1},
#  'Valaitis, Ruta K': {0: 1},
#  'Akhtar-Danesh, Noori': {1: 1},
#  'Kealey, Cathy M': {2: 1},
#  'Brunetti, Glenn M': {3: 1},
#  'Thomas, Helen': {4: 1},
#  'Nagy, P D': {0: 5},
#  'Zhang, C': {1: 1, 0: 1},
#  'Simon, A E': {2: 1, 1: 3},
#  'Nagy, Peter D.': {0: 5, 4: 1, 3: 5, 5: 1, 1: 7, 2: 2, 6: 2},
#  'Pogany, Judit': {1: 8, 2: 1, 0: 1},
#  'Simon, Anne E.': {2: 2, 1: 3, 4: 2, 3: 1, 0: 1},
#  'Dara, Saqib I': {0: 1},
#  'Ashton, Rendell W': {1: 1},
#  'Farmer, J Christopher': {2: 1},
#  'Livingston, Andrew D': {0: 1},
#  'Campbell, Colin J': {1: 1},
#  'Wagner, Edward K': {2: 1},
#  'Ghazal, Peter': {3: 1, 18: 1, 10: 1, 12: 1},
#  'Hrobowski, Yancey M': {0: 1},
#  'Michael, Scott F': {2: 1},
#  'Wearing, Helen J': {0: 1},
#  'Rohani, Pejman': {1: 2, 3: 1, 2: 1, 6: 1, 9: 1},
#  'Keeling, Matt J': {2: 1, 1: 1},
#  'Su, Mei-Chi': {0: 1, 1: 1},
#  'Chang, Chung-Te': {1: 1},
#  'Chu, Chiu-Hui': {2: 1},
#  'Tsai, Ching-Hsiu': {3: 2, 4: 3, 2: 2, 5: 2},
#  'Chang, Kung-Yao': {4: 2, 1: 3, 3: 1, 7: 1, 2: 2},
#  'Cao, Youfang': {0: 1},
#  'Wang, Lianjie': {1: 1},
#  'Xu, Kexue': {2: 1},
#  'Kou, Chunhai': {3: 1},
#  'Zhang, Yulei': {4: 1, 0: 1},
#  'Wei, Guifang': {5: 1},
#  'He, Junjian': {6: 1},
#  'Wang, Yunfang': {7: 1},
#  'Zhao, Liping': {8: 1, 4: 1},
#  'Tan, Timothy HP': {0: 1},
#  'Barkham, Timothy': {1: 2, 3: 1, 12: 1},
#  'Fielding, Burtram C': {2: 1, 8: 1, 1: 1, 0: 1},
#  'Chou, Chih-Fong': {3: 4, 4: 2, 8: 1, 6: 1, 0: 3},
#  'Shen, Shuo': {4: 5, 0: 2, 3: 4, 2: 3, 1: 4},
#  'Lim, Seng Gee': {5: 5, 1: 3, 7: 2, 14: 1, 11: 1, 6: 1, 8: 1, 2: 1, 3: 1},
#  'Hong, Wanjin': {6: 6,
#   1: 1,
#   0: 1,
#   2: 3,
#   8: 2,
#   9: 2,
#   11: 1,
#   15: 1,
#   12: 1,
#   7: 1,
#   4: 1},
#  'McLellan, Andrew S': {0: 1},
#  'Zimmermann, Wolfgang': {1: 2, 4: 1, 0: 1, 7: 2, 15: 1},
#  'Moore, Tom': {2: 1},
#  'Sure, Klaus': {1: 1, 8: 1, 2: 1},
#  'Ihorst, Gabriele': {2: 1, 9: 1, 4: 1, 1: 1},
#  'Stang, Alexander': {3: 1, 0: 2},
#  'Petersen, Gudula': {6: 1, 3: 1},
#  'Forster, Johannes': {7: 1, 1: 2, 4: 3, 5: 1, 6: 1},
#  'Überla, Klaus': {9: 1, 10: 1, 6: 1, 3: 2, 7: 2, 2: 1},
#  'Yuan, Xiaoling': {0: 5},
#  'Shan, Yajun': {1: 1, 2: 4},
#  'Zhao, Zhenhu': {2: 1, 4: 1, 6: 2},
#  'Chen, Jiapei': {3: 1, 9: 1, 7: 1, 8: 1},
#  'Cong, Yuwen': {4: 1, 7: 1, 10: 1, 8: 1, 9: 1},
#  'Cooper, Edwin L.': {0: 1, 6: 1},
#  'Yang, Haitao': {0: 3,
#   3: 2,
#   10: 1,
#   9: 1,
#   8: 2,
#   4: 3,
#   13: 1,
#   2: 2,
#   21: 1,
#   5: 2,
#   1: 3,
#   12: 1,
#   11: 1},
#  'Xie, Weiqing': {1: 3},
#  'Xue, Xiaoyu': {2: 2, 1: 2, 0: 2},
#  'Yang, Kailin': {3: 4, 0: 1, 5: 1},
#  'Ma, Jing': {4: 2, 6: 1, 18: 1},
#  'Liang, Wenxue': {5: 2},
#  'Zhao, Qi': {6: 3, 2: 3, 3: 3, 7: 2, 4: 5, 0: 3, 1: 2, 5: 1, 12: 1, 9: 1},
#  'Zhou, Zhe': {7: 3, 5: 1},
#  'Pei, Duanqing': {8: 2, 22: 1, 4: 1},
#  'Yuen, Kwok Yung': {11: 3, 15: 1, 3: 2, 7: 1, 5: 1, 4: 2, 0: 1},
#  'Wong, Luet': {12: 2},
#  'Gao, Guangxia': {13: 2, 8: 1},
#  'Chen, Saijuan': {14: 2, 1: 1},
#  'Chen, Zhu': {15: 2, 10: 1, 0: 2, 1: 1, 2: 1},
#  'Ma, Dawei': {16: 2, 0: 1},
#  'Bartlam, Mark': {17: 2,
#   3: 1,
#   9: 2,
#   4: 1,
#   0: 3,
#   5: 3,
#   7: 2,
#   12: 2,
#   8: 2,
#   2: 1,
#   1: 1,
#   6: 1},
#  'Rao, Zihe': {18: 2,
#   3: 3,
#   9: 6,
#   6: 8,
#   10: 3,
#   4: 2,
#   7: 3,
#   8: 5,
#   17: 1,
#   5: 3,
#   2: 4,
#   27: 1,
#   0: 1,
#   14: 1,
#   13: 1},
#  'Coil, David A': {0: 1},
#  'Miller, A Dusty': {1: 1},
#  'Kierzek, Elzbieta': {0: 2, 1: 1},
#  'Ciesielska, Anna': {1: 1, 2: 2},
#  'Pasternak, Karol': {2: 1},
#  'Mathews, David H.': {3: 1, 1: 1, 5: 1, 4: 1},
#  'Turner, Douglas H.': {4: 1, 3: 1, 2: 1, 6: 1},
#  'Kierzek, Ryszard': {5: 1, 4: 1},
#  'Zayas, Gustavo': {0: 3},
#  'Dimitry, John': {1: 1},
#  'Zayas, Ana': {2: 1},
#  "O'Brien, Darryl": {3: 1},
#  'King, Malcolm': {4: 1, 6: 2, 2: 1, 5: 1},
#  'Huynen, Maud MTE': {0: 1},
#  'Martens, Pim': {1: 1},
#  'Hilderink, Henk BM': {2: 1},
#  'Wilson, Nick': {0: 3, 1: 2, 2: 1, 4: 1},
#  'Baker, Michael': {1: 2, 5: 1},
#  'Crampton, Peter': {2: 1},
#  'Mansoor, Osman': {3: 1, 2: 1},
#  'Ellermann-Eriksen, Svend': {0: 1},
#  'Des Jarlais, Don C': {0: 1},
#  'Johnston, Patrick': {1: 1},
#  'Friedmann, Patricia': {2: 1},
#  'Kling, Ryan': {3: 1},
#  'Liu, Wei': {4: 5,
#   1: 5,
#   7: 5,
#   0: 17,
#   9: 2,
#   8: 3,
#   6: 5,
#   2: 5,
#   5: 4,
#   3: 6,
#   14: 1,
#   1249: 1,
#   17: 1,
#   13: 1},
#  'Ngu, Doan': {5: 1},
#  'Chen, Yi': {6: 1, 5: 2, 7: 1},
#  'Hoang, Tran V': {7: 1},
#  'Donghua, Meng': {8: 1},
#  'Van, Ly K': {9: 1},
#  'Tung, Nguyen D': {10: 1},
#  'Binh, Kieu T': {11: 1},
#  'Hammett, Theodore M': {12: 1},
#  'Vincent, Martin J': {0: 1},
#  'Bergeron, Eric': {1: 1, 0: 1},
#  'Benjannet, Suzanne': {2: 1},
#  'Erickson, Bobbie R': {3: 1},
#  'Rollin, Pierre E': {4: 1},
#  'Seidah, Nabil G': {6: 1},
#  'Nichol, Stuart T': {7: 1, 11: 1},
#  'Chakraborti, Samitabh': {0: 1, 1: 2, 2: 1},
#  'Prabakaran, Ponraj': {1: 3, 0: 5, 5: 2, 14: 1, 3: 1, 9: 1, 7: 1, 4: 2},
#  'Xiao, Xiaodong': {2: 2, 0: 8, 5: 1, 12: 1, 1: 1},
#  'Dimitrov, Dimiter S': {3: 1, 9: 1, 0: 2, 4: 2, 2: 1},
#  'Fischer, Kael F': {1: 1},
#  'Chiu, Charles Y': {2: 1, 6: 1, 0: 1},
#  'Kistler, Amy L': {3: 1, 0: 1},
#  'Beck, Shoshannah': {4: 1},
#  'Patz, Jonathan A.': {0: 1, 5: 1},
#  'Daszak, Peter': {1: 6,
#   13: 3,
#   2: 8,
#   4: 5,
#   17: 1,
#   12: 4,
#   15: 1,
#   19: 2,
#   6: 5,
#   9: 7,
#   3: 5,
#   14: 3,
#   8: 4,
#   7: 3,
#   5: 7,
#   11: 1,
#   21: 1,
#   10: 1,
#   0: 4,
#   30: 1,
#   16: 1,
#   40: 1,
#   18: 1},
#  'Tabor, Gary M.': {2: 1, 10: 1},
#  'Aguirre, A. Alonso': {3: 1, 1: 1, 0: 1, 11: 1},
#  'Pearl, Mary': {4: 1},
#  'Epstein, Jon': {5: 1},
#  'Wolfe, Nathan D.': {6: 1, 7: 2, 0: 2, 8: 1},
#  'Kilpatrick, A. Marm': {7: 2, 3: 3, 2: 1, 4: 1, 1: 1, 0: 1},
#  'Foufopoulos, Johannes': {8: 1},
#  'Molyneux, David': {9: 1},
#  'Bradley, David J.': {10: 1},
#  'Lai, P.C.': {0: 1},
#  'Wong, C.M.': {1: 1},
#  'Hedley, A.J.': {2: 1},
#  'Lo, S.V.': {3: 1},
#  'Leung, P.Y.': {4: 1},
#  'Kong, J.': {5: 1},
#  'Leung, G.M.': {6: 1, 5: 1, 0: 1},
#  'Azizi, Ali': {0: 2},
#  'Aucoin, Susan': {1: 1},
#  'Tadesse, Helina': {2: 1},
#  'Frost, Rita': {3: 1},
#  'Ghorbani, Masoud': {4: 1, 2: 1},
#  'Soare, Catalina': {5: 1},
#  'Naas, Turaya': {6: 1},
#  'Diaz-Mitoma, Francisco': {7: 1, 4: 1},
#  'Barnett, Daniel J.': {0: 2},
#  'Balicer, Ran D.': {1: 1, 0: 2},
#  'Blodgett, David': {2: 1},
#  'Fews, Ayanna L.': {3: 1},
#  'Parker, Cindy L.': {4: 1},
#  'Links, Jonathan M.': {5: 1, 3: 1},
#  'Sallie, Richard': {0: 1},
#  'Flego, Michela': {0: 3},
#  'Di Bonito, Paola': {1: 1, 5: 1, 8: 1, 4: 1},
#  'Ascione, Alessandro': {2: 1, 1: 1, 4: 1},
#  'Zamboni, Silvia': {3: 1},
#  'Carattoli, Alessandra': {4: 1, 0: 1},
#  'Grasso, Felicia': {5: 1, 2: 1},
#  'Cassone, Antonio': {6: 2, 8: 1, 4: 2, 2: 2},
#  'Cianfriglia, Maurizio': {7: 1, 2: 1},
#  'Lee, Yun-Shien': {0: 2, 1: 2},
#  'Chen, Chun-Houh': {1: 1, 2: 1, 3: 1},
#  'Chao, Angel': {2: 1, 1: 1, 0: 1},
#  'Chen, En-Shih': {3: 1},
#  'Wei, Min-Li': {4: 1},
#  'Chen, Lung-Kun': {5: 1},
#  'Yang, Kuender D': {6: 1, 2: 1},
#  'Lin, Meng-Chih': {7: 1, 6: 1, 8: 1},
#  'Wang, Yi-Hsi': {8: 1, 0: 1},
#  'Liu, Jien-Wei': {9: 2, 2: 1, 6: 1, 4: 2, 15: 1},
#  'Eng, Hock-Liew': {10: 1, 2: 2, 4: 1, 5: 1},
#  'Chiang, Ping-Cherng': {11: 1, 3: 1},
#  'Wu, Ting-Shu': {12: 1},
#  'Tsao, Kuo-Chein': {13: 1},
#  'Huang, Chung-Guei': {14: 1, 1: 2, 0: 1, 3: 1, 6: 1},
#  'Tien, Yin-Jing': {15: 1, 0: 1},
#  'Wang, Tzu-Hao': {16: 1, 0: 1, 1: 1},
#  'Wang, Hsing-Shih': {17: 1},
#  'Lee, Ying-Shiung': {18: 1},
#  "O'Neill, Jennifer K": {0: 1},
#  'Richards, Simon W': {1: 1},
#  'Ricketts, David M': {2: 1},
#  'Patterson, Marc H': {3: 1},
#  'Gardner, Shea N.': {0: 5},
#  'Lam, Marisa W.': {1: 2, 3: 1},
#  'Smith, Jason R.': {2: 1, 4: 1},
#  'Torres, Clinton L.': {3: 2},
#  'Slezak, Tom R.': {4: 2, 5: 1},
#  'Hawryluck, Laura': {0: 2, 4: 1, 3: 1, 1: 3},
#  'Hargrove, Jenny': {0: 1},
#  'Nguyen, H Bryant': {1: 1},
#  'Rubinson, Lewis': {0: 4, 9: 1, 5: 1, 8: 1, 3: 2, 4: 2, 2: 1},
#  "O'Toole, Tara": {1: 1, 6: 1},
#  'Kao, Hsin-Kuo': {0: 1, 3: 1},
#  'Wang, Jia-Horng': {1: 1, 7: 1, 4: 1, 3: 1},
#  'Sung, Chun-Sung': {2: 1, 1: 1},
#  'Huang, Ying-Che': {3: 1, 4: 2},
#  'Lien, Te-Cheng': {4: 1, 0: 1, 1: 1},
#  'Earnest, Arul': {0: 1, 2: 2, 8: 1, 3: 1, 1: 1, 6: 2},
#  'Chen, Mark I': {1: 1, 2: 1},
#  'Ng, Donald': {2: 1},
#  'Sin, Leo Yee': {3: 1},
#  'Cheung, Jo LK': {2: 1, 6: 1},
#  'Jin, Yongjie': {3: 1, 1: 1},
#  'Whiteford, Nava': {0: 1},
#  'Haslam, Niall': {1: 1, 22: 1},
#  'Weber, Gerald': {2: 1},
#  'Prügel-Bennett, Adam': {3: 1},
#  'Essex, Jonathan W.': {4: 1},
#  'Roach, Peter L.': {5: 1},
#  'Bradley, Mark': {6: 1},
#  'Neylon, Cameron': {7: 1},
#  'Sathiamurthy, Muthuraman': {0: 1},
#  'Peters, Bjoern': {1: 2, 3: 3, 9: 1, 0: 1, 5: 2, 2: 1, 4: 2},
#  'Bui, Huynh-Hoa': {2: 1},
#  'Sidney, John': {3: 3, 0: 3, 12: 1, 8: 1, 4: 2, 10: 1, 1: 2},
#  'Mokili, John': {4: 1},
#  'Wilson, Stephen S': {5: 1},
#  'Fleri, Ward': {6: 1},
#  'McGuinness, Deborah L': {7: 1},
#  'Bourne, Philip E': {8: 1},
#  'Sette, Alessandro': {9: 1,
#   4: 1,
#   5: 4,
#   2: 3,
#   11: 2,
#   10: 1,
#   1: 1,
#   6: 2,
#   13: 1,
#   3: 1},
#  'Drake, John M': {0: 1},
#  'Rouby, Jean-Jacques': {0: 1},
#  'Lu, Qin': {1: 1},
#  'Cooper, Andrew B': {0: 1},
#  'Joglekar, Amit S': {1: 1},
#  'Gibson, Jennifer': {2: 1},
#  'Swota, Alissa H': {3: 1},
#  'Sawicki, Stanley G': {0: 2},
#  'Sawicki, Dorothea L': {1: 2},
#  'Younker, Diane': {2: 2},
#  'Meyer, Yvonne': {3: 2},
#  'Thiel, Volker': {4: 8,
#   8: 4,
#   6: 6,
#   10: 7,
#   12: 1,
#   20: 1,
#   11: 1,
#   13: 4,
#   24: 1,
#   17: 1,
#   5: 4,
#   0: 7,
#   16: 1,
#   14: 1,
#   2: 3,
#   3: 10,
#   7: 3,
#   18: 1,
#   1: 4,
#   15: 1,
#   9: 1},
#  'Stokes, Helen': {5: 2, 1: 1},
#  'Siddell, Stuart G': {6: 2, 10: 1, 5: 1, 4: 1},
#  'Pang, Tikki': {0: 4, 1: 1},
#  'Guindon, G. Emmanuel': {1: 1},
#  'Gannon, Frank': {0: 1},
#  'Breitbart, Mya': {1: 3, 9: 1, 4: 1},
#  'Run, Jin-Quan': {3: 1},
#  'Soh, Shirlena Wee Ling': {5: 1},
#  'Rohwer, Forest': {8: 1, 1: 2},
#  'Olsvik, Pål A': {0: 2},
#  'Lie, Kai K': {1: 1, 2: 1},
#  'Jordal, Ann-Elise O': {2: 1},
#  'Nilsen, Tom O': {3: 1},
#  'Hordvik, Ivar': {4: 1},
#  'Goossens, Karen': {0: 1},
#  'Van Poucke, Mario': {1: 2},
#  'Van Soom, Ann': {2: 1},
#  'Vandesompele, Jo': {3: 1, 7: 1},
#  'Van Zeveren, Alex': {4: 1},
#  'Peelman, Luc J': {5: 1},
#  'Wilson, Kumanan': {0: 6, 4: 1, 2: 1, 1: 3},
#  'McDougall, Christopher': {1: 1, 2: 1},
#  'Upshur, Ross': {2: 1, 1: 2, 0: 1, 4: 1},
#  'Chan, MCW': {0: 1},
#  'Cheung, CY': {1: 2, 3: 1},
#  'Chui, WH': {2: 1, 4: 1},
#  'Tsao, SW': {3: 1},
#  'Nicholls, JM': {4: 1, 3: 1, 5: 1, 2: 1},
#  'Chan, YO': {5: 1},
#  'Chan, RWY': {6: 1},
#  'Long, HT': {7: 1},
#  'Poon, LLM': {8: 1, 0: 2, 10: 1, 3: 2, 2: 1, 5: 1},
#  'Guan, Y': {9: 3, 8: 1, 1: 3, 12: 1, 11: 1, 15: 2, 3: 2, 5: 1, 0: 1, 10: 1},
#  'Peiris, JSM': {10: 1, 9: 1, 0: 4, 14: 1, 4: 1, 7: 1, 1: 1},
#  'Barreiro, Luis B': {0: 1},
#  'Neyrolles, Olivier': {1: 2, 2: 2, 7: 1},
#  'Babb, Chantal L': {2: 1},
#  'Tailleux, Ludovic': {3: 1},
#  'Quach, Hélène': {4: 1, 1: 1},
#  'McElreavey, Ken': {5: 1},
#  'van Helden, Paul D.': {6: 1, 3: 1},
#  'Hoal, Eileen G': {7: 1, 2: 1},
#  'Gicquel, Brigitte': {8: 1, 4: 3, 6: 1},
#  'Quintana-Murci, Lluis': {9: 1},
#  'Nicholls, John M': {0: 3, 8: 2, 11: 1},
#  'Butany, Jagdish': {1: 1, 5: 2, 7: 1, 4: 1, 8: 1, 11: 1},
#  'Poon, Leo L. M': {2: 2},
#  'Chan, Kwok H': {3: 1, 11: 1},
#  'Beh, Swan Lip': {4: 1},
#  'Poutanen, Susan': {5: 1},
#  'Peiris, J. S. Malik': {6: 5,
#   11: 3,
#   5: 7,
#   14: 1,
#   9: 2,
#   1: 2,
#   7: 8,
#   8: 4,
#   3: 2,
#   4: 2,
#   0: 2,
#   10: 1,
#   2: 3,
#   13: 3},
#  'Wong, Maria': {7: 1},
#  'Warfield, Kelly L': {0: 1},
#  'Swenson, Dana L': {1: 1},
#  'Olinger, Gene G': {2: 1, 24: 1},
#  'Nichols, Donald K': {3: 1},
#  'Pratt, William D': {4: 1, 16: 1},
#  'Blouch, Robert': {5: 1, 9: 1},
#  'Stein, David A': {6: 1},
#  'Aman, M. Javad': {7: 1, 16: 2, 0: 1, 5: 1, 15: 1, 30: 1},
#  'Iversen, Patrick L': {8: 1},
#  'Bavari, Sina': {9: 1,
#   14: 3,
#   8: 2,
#   5: 1,
#   2: 3,
#   10: 3,
#   4: 3,
#   11: 2,
#   61: 1,
#   7: 3,
#   19: 1,
#   3: 2,
#   1: 1,
#   16: 1,
#   6: 1,
#   27: 2,
#   15: 1},
#  'Mizgerd, Joseph P': {0: 1, 10: 1},
#  'Breithaupt, Holger': {0: 1},
#  'Novotny, Thomas E': {0: 2},
#  'Mordini, Emilio': {1: 1, 0: 1},
#  'Chadwick, Ruth': {2: 1},
#  'Pedersen, J. Martin': {3: 1},
#  'Fabbri, Fabrizio': {4: 1},
#  'Lie, Reidar': {5: 1},
#  'Thanachaiboot, Natapong': {6: 1},
#  'Mossialos, Elias': {7: 1},
#  'Permanand, Govin': {8: 1, 6: 1},
#  'Inoue, Manami': {0: 1, 10: 1},
#  'Iwasaki, Motoki': {1: 1},
#  'Otani, Tetsuya': {2: 1},
#  'Sasazuki, Shizuka': {3: 1},
#  'Tsugane, Shoichiro': {4: 1},
#  'Guo, Feng-Biao': {0: 2, 4: 1},
#  'Zhang, Chun-Ting': {1: 2, 4: 2, 3: 1},
#  'Pride, David T': {0: 1},
#  'Wassenaar, Trudy M': {1: 1},
#  'Ghose, Chandrabali': {2: 1},
#  'Blaser, Martin J': {3: 1},
#  'Mori, Yasuyoshi': {0: 3},
#  'Hirano, Tsuyoshi': {1: 1},
#  'Notomi, Tsugunori': {2: 2, 6: 1, 5: 3, 8: 1, 7: 1, 1: 1},
#  'Lui, Wing-bong': {3: 1},
#  'Chan, Anthony TC': {4: 1},
#  'Lim, Wilina': {5: 1, 10: 1, 13: 1, 4: 5, 3: 1, 2: 2, 7: 2, 9: 1},
#  'Dennis Lo, YM': {6: 1, 10: 1},
#  'Gronvall, Gigi Kwik': {0: 2, 1: 1},
#  'Waldhorn, Richard E': {1: 1},
#  'Henderson, D. A': {2: 1},
#  'Wang, Xiaoxing': {0: 2, 1: 1},
#  'Wong, Sek-Man': {1: 1, 4: 1, 0: 1, 2: 2, 3: 1},
#  'Liu, D. X.': {2: 3, 0: 1, 1: 1},
#  'Meerts, Peter': {0: 1},
#  'Misinzo, Gerald': {1: 1},
#  'Lefebvre, David': {2: 1, 8: 1},
#  'Nielsen, Jens': {3: 2, 4: 1, 12: 1, 7: 1},
#  'Bøtner, Anette': {4: 2, 14: 1, 7: 2, 3: 1, 1: 1, 11: 1},
#  'Kristensen, Charlotte S': {5: 1},
#  'Nauwynck, Hans J': {6: 2, 3: 1},
#  'Gelardi, Matteo': {0: 1, 1: 1},
#  'Tomaiuolo, Marilena': {1: 1},
#  'Cassano, Michele': {2: 2},
#  'Besozzi, Gaspare': {3: 1},
#  'Fiorella, Maria Luisa': {4: 1},
#  'Calvario, Agata': {5: 1},
#  'Castellano, Maria Antonia': {6: 1},
#  'Cassano, Pasquale': {7: 1},
#  'Grigoriadis, Nikolaos': {0: 1},
#  'Hadjigeorgiou, Georgios M': {1: 1},
#  'Koehn, Peter H': {0: 1},
#  'Gabig-Ciminska, Magdalena': {0: 1},
#  'Barr, Ian': {1: 1, 2: 1, 13: 1, 5: 1, 7: 1},
#  'Nguyen, Tung': {2: 1, 1: 1},
#  'Noor, Suriani Mohd': {3: 1},
#  'Tan, Rosemary Sok-Pin': {4: 1},
#  'Agathe, Lora V': {5: 1},
#  'Gupta, Sanjay': {6: 1, 8: 1},
#  'Khalil, Hassuzana': {7: 1},
#  'To, Thanh Long': {8: 1},
#  'Hassan, Sharifah Syed': {9: 1},
#  'Rolland, Elizabeth': {0: 1},
#  'Moore, Kieran M': {1: 1},
#  'Robinson, Victoria A': {2: 1, 0: 1},
#  'McGuinness, Don': {3: 1},
#  'Demma, LJ': {0: 1},
#  'Vanderford, TH': {1: 1},
#  'Logsdon, JM': {2: 1},
#  'Feinberg, MB': {3: 1},
#  'Staprans, SI': {4: 1},
#  'Haagmans, Bart L': {0: 4,
#   6: 1,
#   2: 4,
#   16: 1,
#   7: 1,
#   5: 2,
#   21: 1,
#   3: 2,
#   4: 1,
#   1: 2,
#   11: 1},
#  'Osterhaus, Albert D. M. E': {1: 2},
#  'Lawler, James V': {0: 1},
#  'Endy, Timothy P': {1: 1},
#  'Hensley, Lisa E': {2: 1, 22: 1, 28: 1, 10: 1},
#  'Garrison, Aura': {3: 1},
#  'Fritz, Elizabeth A': {4: 1},
#  'Lesar, May': {5: 1},
#  'Baric, Ralph S': {6: 2, 4: 1, 2: 2, 11: 1, 1: 4, 8: 1, 18: 1},
#  'Kulesh, David A': {7: 1},
#  'Norwood, David A': {8: 1, 10: 1},
#  'Wasieloski, Leonard P': {9: 1},
#  'Ulrich, Melanie P': {10: 1},
#  'Slezak, Tom R': {11: 1, 3: 2},
#  'Vitalis, Elizabeth': {12: 1, 3: 1},
#  'Huggins, John W': {13: 1},
#  'Jahrling, Peter B': {14: 1, 13: 1, 5: 1, 30: 1, 3: 1},
#  'Paragas, Jason': {15: 1, 6: 1, 2: 1, 11: 1, 10: 1, 5: 2, 0: 1},
#  'Johnson, Christopher J': {0: 1},
#  'Phillips, Kristen E': {1: 1},
#  'Schramm, Peter T': {2: 1},
#  'McKenzie, Debbie': {3: 1},
#  'Aiken, Judd M': {4: 1},
#  'Pedersen, Joel A': {5: 1},
#  'Spiegel, Martin': {0: 4, 2: 3, 1: 2, 3: 1},
#  'Weber, Friedemann': {1: 5,
#   4: 2,
#   19: 1,
#   3: 3,
#   13: 1,
#   5: 2,
#   7: 5,
#   0: 4,
#   6: 4,
#   2: 3,
#   9: 1,
#   8: 2},
#  'Oliveira, Sérgio C': {4: 1},
#  'Cooper, Ben S': {0: 1, 2: 1},
#  'Pitman, Richard J': {1: 1},
#  'Edmunds, W. John': {2: 2, 13: 1, 1: 2, 12: 1, 5: 1, 11: 1},
#  'Gay, Nigel J': {3: 1},
#  'LaPelle, Nancy R': {0: 1},
#  'Luckmann, Roger': {1: 1},
#  'Simpson, E Hatheway': {2: 1},
#  'Martin, Elaine R': {3: 1},
#  'Ruderman, Carly': {0: 1},
#  'Tracy, C Shawn': {1: 1, 0: 1},
#  'Bensimon, Cécile M': {2: 1},
#  'Shaul, Randi Zlotnik': {5: 1, 8: 1, 3: 1},
#  'Ferraz, Rosa María': {0: 1},
#  'Vera, Andrea': {1: 1},
#  'Arís, Anna': {2: 1},
#  'Villaverde, Antonio': {3: 1},
#  'Sullivan, Nancy J': {0: 1, 4: 1, 1: 1},
#  'Geisbert, Thomas W': {1: 4, 6: 1, 0: 1},
#  'Geisbert, Joan B': {2: 1, 3: 2},
#  'Shedlock, Devon J': {3: 1, 2: 1},
#  'Xu, Ling': {4: 3, 1: 2, 3: 1, 21: 1, 0: 1, 6: 1},
#  'Lamoreaux, Laurie': {5: 1, 9: 1},
#  'Custers, Jerome H. H. V': {6: 1},
#  'Popernack, Paul M': {7: 1},
#  'Yang, Zhi-Yong': {8: 1, 3: 1, 0: 2},
#  'Pau, Maria G': {9: 1},
#  'Roederer, Mario': {10: 1, 9: 2, 5: 1, 26: 1, 2: 1, 12: 1},
#  'Koup, Richard A': {11: 1, 12: 2},
#  'Goudsmit, Jaap': {12: 1, 15: 2, 9: 1, 6: 1, 1: 1, 10: 1, 11: 1, 4: 1},
#  'Nabel, Gary J': {14: 2, 0: 1, 2: 1},
#  'Chong, Wai Po': {0: 1, 2: 1, 4: 1, 1: 1},
#  'Ip, WK Eddie': {1: 2},
#  'Tso, Gloria Hoi Wan': {2: 1},
#  'Ng, Man Wai': {3: 2, 0: 1},
#  'Wong, Wilfred Hing Sang': {4: 1, 6: 1},
#  'Law, Helen Ka Wai': {5: 1, 4: 1},
#  'Yung, Raymond WH': {6: 1, 9: 1, 5: 1},
#  'Chow, Eudora Y': {7: 1, 10: 1},
#  'Au, KL': {8: 1},
#  'Chan, Eric YT': {9: 1, 12: 1},
#  'Peiris, JS Malik': {11: 1, 14: 1, 4: 3, 9: 1, 1: 1, 10: 1},
#  'Lau, Yu Lung': {12: 2, 16: 1, 5: 3, 11: 1, 7: 1, 8: 1, 0: 1},
#  'van Ooij, Mark J. M.': {0: 1},
#  'Polacek, Charlotta': {1: 1},
#  'Glaudemans, Dirk H. R. F.': {2: 1},
#  'Kuijpers, Judith': {3: 1, 2: 1},
#  'van Kuppeveld, Frank J. M.': {4: 2,
#   5: 5,
#   9: 2,
#   10: 3,
#   2: 3,
#   16: 1,
#   8: 2,
#   15: 2,
#   6: 6,
#   7: 4,
#   14: 1,
#   3: 1,
#   19: 1},
#  'Andino, Raul': {5: 2, 3: 1, 2: 1, 9: 1, 0: 2, 1: 5},
#  'Agol, Vadim I.': {6: 1, 0: 5},
#  'Melchers, Willem J. G.': {7: 1, 6: 1},
#  'Ravindranath, Mepur H.': {0: 1},
#  'Saravanan, Thiruverkadu S.': {1: 1},
#  'Monteclaro, Clarence C.': {2: 1},
#  'Presser, Naftali': {3: 1},
#  'Ye, Xing': {4: 1},
#  'Selvan, Senthamil R.': {5: 1},
#  'Brosman, Stanley': {6: 1},
#  'Martín, Verónica': {0: 1, 2: 2},
#  'Perales, Celia': {1: 2, 2: 1, 0: 1, 9: 1, 3: 1},
#  'Abia, David': {2: 1},
#  'Ortíz, Angel R': {3: 1},
#  'Domingo, Esteban': {4: 3, 6: 1, 0: 19, 2: 2, 1: 4, 11: 1, 3: 1},
#  'Briones, Carlos': {5: 1, 3: 1, 0: 1},
#  'Franciosi, Luigi G': {0: 1},
#  'Page, Clive P': {1: 1},
#  'Celli, Bartolome R': {2: 1},
#  'Cazzola, Mario': {3: 1, 4: 1},
#  'Walker, Michael J': {4: 1},
#  'Danhof, Meindert': {5: 1},
#  'Rabe, Klaus F': {6: 1},
#  'Pasqua, Oscar E Della': {7: 1},
#  'Chew, Janet Seok Wei': {1: 1},
#  'Loh, Jin Phang': {2: 2, 3: 3, 1: 1},
#  'Chua, Robert CS': {3: 1},
#  'Beer, Christiane': {0: 3},
#  'Pedersen, Lene': {1: 2, 3: 1},
#  'ter Meulen, Jan': {0: 2, 1: 1, 3: 1},
#  'van den Brink, Edward N': {1: 1, 2: 1},
#  'Marissen, Wilfred E': {3: 1},
#  'Leung, Cynthia S. W': {4: 1},
#  'Cox, Freek': {5: 1, 2: 1},
#  'Cheung, Chung Y': {6: 1, 1: 2},
#  'Bakker, Arjen Q': {7: 1},
#  'Bogaards, Johannes A': {8: 1},
#  'van Deventer, Els': {9: 1},
#  'Preiser, Wolfgang': {10: 1, 2: 1, 8: 2, 1: 2, 12: 1, 4: 8, 0: 2, 3: 1},
#  'Doerr, Hans Wilhelm': {11: 1, 5: 2, 1: 2, 7: 3, 3: 1, 13: 1, 2: 2, 4: 2},
#  'Chow, Vincent T': {12: 1, 13: 1},
#  'de Kruif, John': {13: 1, 14: 1, 7: 1},
#  'Peiris, Joseph S. M': {14: 1},
#  'Bogaert, Lies': {0: 1},
#  'De Baere, Cindy': {2: 1},
#  'Peelman, Luc': {3: 1},
#  'Gasthuys, Frank': {4: 1},
#  'Martens, Ann': {5: 1},
#  'Singam, Rajeswari': {0: 1},
#  'Jena, Prasanna K': {1: 1},
#  'Behera, Sumita': {2: 1},
#  'Hellermann, Gary R': {3: 1},
#  'Lockey, Richard F': {4: 1},
#  'Ledford, Dennis': {5: 1},
#  'Mohapatra, Shyam S': {6: 1, 4: 1},
#  'Zhang, Ruifang': {0: 1},
#  'Eggleston, Karen': {1: 1, 0: 1},
#  'Rotimi, Vincent': {2: 1},
#  'Zeckhauser, Richard J': {3: 1},
#  'Gushulak, Brian D': {0: 1, 1: 1},
#  'MacPherson, Douglas W': {1: 1, 0: 1},
#  'Liu, Wen': {0: 1, 3: 1},
#  'Meng, Xiangshan': {1: 1},
#  'Xu, Qiqi': {2: 1},
#  'Flower, Darren R': {3: 1, 0: 1},
#  'Li, Tongbin': {4: 1},
#  'Dykxhoorn, Derek M': {0: 1},
#  'Lieberman, Judy': {1: 2, 3: 1, 0: 1},
#  'Pan, Yi-Shin': {0: 1},
#  'Lee, Yung-Lin': {2: 1},
#  'Lee, Wei-Chen': {3: 1},
#  'Hsieh, Sen-Yung': {4: 1},
#  'Chou, Cheng-Chung': {0: 1},
#  'Lee, Te-Tsui': {1: 1},
#  'Hsiao, Hsiang-Yun': {3: 1},
#  'Lin, Yi-Ling': {4: 1, 6: 1, 7: 1, 2: 1, 11: 1, 3: 2, 5: 1},
#  'Ho, Mei-Shang': {5: 2, 4: 2, 6: 4, 3: 2, 0: 4, 10: 1, 7: 1},
#  'Yang, Pan-Chyr': {6: 2, 8: 4, 1: 1, 11: 1, 7: 2, 24: 1, 5: 1, 10: 1, 9: 1},
#  'Peck, Konan': {7: 1, 4: 1, 6: 1},
#  'Braga-Neto, Ulisses M': {0: 1},
#  'Marques, Ernesto T. A': {1: 1},
#  'Eichler, Robert': {0: 1},
#  ...}

# %%
write_json_file(file_path=DATA_INTERIM + "author_publication_distribution.json", 
                data=author_publication_distribution)

# author_publication_distribution = read_json_file(file_path=DATA_INTERIM + "author_publication_distribution.json")

# %%
## Top authors by publications
authors_publications = {x: y for x, y in sorted(author_publication_distribution.items(), 
                                                key=lambda item: sum(item[1].values()),
                                               reverse=True)}

# %%
authors_publications
# Out:
# {'Perlman, Stanley': {'8': 11,
#   '3': 20,
#   '0': 16,
#   '2': 30,
#   '5': 12,
#   '4': 11,
#   '1': 29,
#   '7': 7,
#   '6': 8,
#   '12': 2,
#   '11': 7,
#   '13': 4,
#   '9': 5,
#   '15': 2,
#   '26': 1,
#   '25': 1,
#   '10': 1,
#   '18': 1,
#   '16': 1,
#   '17': 1,
#   '21': 1},
#  'Drosten, Christian': {'5': 14,
#   '4': 13,
#   '11': 14,
#   '1': 6,
#   '2': 7,
#   '7': 9,
#   '9': 9,
#   '3': 14,
#   '8': 12,
#   '10': 3,
#   '26': 1,
#   '0': 7,
#   '33': 1,
#   '18': 3,
#   '20': 2,
#   '36': 1,
#   '6': 10,
#   '16': 6,
#   '12': 4,
#   '13': 5,
#   '17': 7,
#   '14': 3,
#   '19': 2,
#   '15': 5,
#   '27': 2,
#   '30': 1,
#   '21': 1,
#   '23': 2,
#   '22': 1},
#  'Yuen, Kwok-Yung': {'16': 5,
#   '4': 15,
#   '9': 16,
#   '3': 9,
#   '5': 8,
#   '7': 11,
#   '10': 14,
#   '8': 11,
#   '1': 3,
#   '11': 9,
#   '13': 12,
#   '2': 2,
#   '12': 12,
#   '14': 7,
#   '24': 3,
#   '6': 5,
#   '17': 5,
#   '21': 1,
#   '26': 1,
#   '15': 5,
#   '25': 1,
#   '18': 1,
#   '19': 2,
#   '23': 1,
#   '0': 1,
#   '27': 1,
#   '20': 1,
#   '29': 1},
#  'Baric, Ralph S.': {'3': 21,
#   '5': 17,
#   '6': 9,
#   '10': 8,
#   '8': 11,
#   '15': 3,
#   '13': 3,
#   '14': 3,
#   '7': 6,
#   '2': 13,
#   '21': 2,
#   '20': 2,
#   '1': 11,
#   '18': 3,
#   '25': 2,
#   '12': 4,
#   '0': 8,
#   '11': 5,
#   '9': 5,
#   '19': 1,
#   '4': 9,
#   '22': 3,
#   '17': 2,
#   '27': 1},
#  'Jiang, Shibo': {'5': 8,
#   '9': 9,
#   '4': 16,
#   '14': 4,
#   '10': 13,
#   '0': 15,
#   '8': 11,
#   '2': 4,
#   '1': 6,
#   '6': 21,
#   '18': 1,
#   '11': 6,
#   '3': 9,
#   '12': 3,
#   '7': 14,
#   '16': 2,
#   '13': 2,
#   '17': 1,
#   '20': 1,
#   '22': 1},
#  'Enjuanes, Luis': {'9': 8,
#   '6': 14,
#   '5': 14,
#   '3': 22,
#   '4': 28,
#   '7': 13,
#   '10': 3,
#   '16': 1,
#   '14': 1,
#   '15': 1,
#   '2': 9,
#   '12': 2,
#   '1': 4,
#   '0': 7,
#   '8': 7},
#  'Snijder, Eric J.': {'3': 20,
#   '5': 12,
#   '4': 18,
#   '2': 11,
#   '6': 14,
#   '11': 3,
#   '9': 5,
#   '7': 4,
#   '10': 4,
#   '14': 2,
#   '12': 3,
#   '1': 11,
#   '0': 5,
#   '8': 3},
#  'Weiss, Susan R.': {'1': 14,
#   '3': 15,
#   '5': 9,
#   '7': 8,
#   '9': 5,
#   '22': 1,
#   '2': 15,
#   '6': 7,
#   '8': 3,
#   '4': 21,
#   '0': 5,
#   '13': 2,
#   '12': 1},
#  'Wang, Lin-Fa': {'8': 9,
#   '11': 4,
#   '6': 8,
#   '12': 5,
#   '15': 2,
#   '2': 6,
#   '3': 6,
#   '4': 7,
#   '5': 6,
#   '9': 4,
#   '0': 6,
#   '13': 2,
#   '7': 9,
#   '14': 4,
#   '1': 5,
#   '20': 1,
#   '17': 6,
#   '10': 5,
#   '16': 2,
#   '24': 1,
#   '21': 1,
#   '41': 1},
#  'Li, Yan': {'0': 9,
#   '2': 9,
#   '4': 6,
#   '10': 4,
#   '1': 13,
#   '3': 11,
#   '6': 10,
#   '9': 2,
#   '13': 2,
#   '8': 5,
#   '5': 7,
#   '7': 6,
#   '22': 1,
#   '11': 2,
#   '14': 3,
#   '21': 1,
#   '24': 1,
#   '19': 1,
#   '15': 1,
#   '16': 1},
#  'Du, Lanying': {'0': 24,
#   '2': 18,
#   '4': 6,
#   '1': 9,
#   '8': 10,
#   '7': 7,
#   '14': 1,
#   '3': 2,
#   '9': 3,
#   '13': 1,
#   '6': 3,
#   '12': 1,
#   '16': 1,
#   '5': 5,
#   '15': 1,
#   '10': 2},
#  'Gao, George F.': {'8': 12,
#   '6': 6,
#   '14': 2,
#   '13': 3,
#   '10': 6,
#   '7': 6,
#   '11': 7,
#   '40': 2,
#   '12': 5,
#   '4': 10,
#   '16': 2,
#   '22': 1,
#   '21': 1,
#   '9': 7,
#   '3': 4,
#   '5': 4,
#   '18': 2,
#   '2': 2,
#   '39': 1,
#   '20': 1,
#   '17': 1,
#   '0': 2,
#   '27': 1,
#   '1': 3,
#   '34': 1,
#   '19': 1},
#  'Memish, Ziad A.': {'0': 17,
#   '19': 1,
#   '7': 2,
#   '6': 5,
#   '13': 2,
#   '2': 15,
#   '18': 1,
#   '1': 17,
#   '11': 1,
#   '3': 9,
#   '12': 3,
#   '4': 6,
#   '5': 4,
#   '16': 1,
#   '14': 2,
#   '9': 1,
#   '17': 1,
#   '27': 1,
#   '10': 1},
#  'Saif, Linda J.': {'8': 5,
#   '5': 11,
#   '7': 9,
#   '13': 1,
#   '6': 6,
#   '3': 15,
#   '1': 7,
#   '2': 8,
#   '9': 3,
#   '4': 9,
#   '0': 8,
#   '11': 1},
#  'Decaro, Nicola': {'0': 44,
#   '1': 5,
#   '10': 4,
#   '8': 5,
#   '9': 3,
#   '7': 5,
#   '17': 1,
#   '4': 3,
#   '5': 2,
#   '2': 5,
#   '6': 3},
#  'Wang, Wei': {'0': 9,
#   '1': 15,
#   '2': 13,
#   '4': 8,
#   '6': 8,
#   '3': 9,
#   '5': 5,
#   '7': 2,
#   '10': 2,
#   '18': 1,
#   '30': 1,
#   '13': 1,
#   '9': 2,
#   '12': 1,
#   '11': 1,
#   '8': 1},
#  'Pöhlmann, Stefan': {'10': 7,
#   '3': 5,
#   '11': 4,
#   '14': 3,
#   '24': 1,
#   '8': 6,
#   '2': 5,
#   '7': 9,
#   '6': 9,
#   '12': 4,
#   '4': 5,
#   '5': 8,
#   '17': 1,
#   '9': 5,
#   '0': 2,
#   '1': 3,
#   '13': 2},
#  'Buonavoglia, Canio': {'11': 5,
#   '7': 16,
#   '6': 8,
#   '0': 1,
#   '9': 12,
#   '8': 9,
#   '10': 6,
#   '5': 2,
#   '16': 1,
#   '4': 1,
#   '12': 3,
#   '3': 2,
#   '1': 5,
#   '2': 4,
#   '13': 2},
#  'Daszak, Peter': {'1': 6,
#   '13': 3,
#   '2': 8,
#   '4': 5,
#   '17': 1,
#   '12': 4,
#   '15': 1,
#   '19': 2,
#   '6': 5,
#   '9': 7,
#   '3': 5,
#   '14': 3,
#   '8': 4,
#   '7': 3,
#   '5': 7,
#   '11': 1,
#   '21': 1,
#   '10': 1,
#   '0': 4,
#   '30': 1,
#   '16': 1,
#   '40': 1,
#   '18': 1},
#  'Chan, Kwok-Hung': {'3': 12,
#   '5': 4,
#   '6': 10,
#   '8': 10,
#   '4': 3,
#   '11': 6,
#   '12': 5,
#   '1': 7,
#   '10': 5,
#   '13': 1,
#   '7': 3,
#   '9': 3,
#   '22': 1,
#   '14': 1,
#   '26': 1,
#   '18': 1,
#   '0': 1},
#  'Woo, Patrick C. Y.': {'2': 6,
#   '0': 23,
#   '7': 8,
#   '4': 4,
#   '6': 1,
#   '1': 10,
#   '9': 5,
#   '16': 1,
#   '3': 3,
#   '13': 1,
#   '11': 2,
#   '14': 3,
#   '18': 1,
#   '19': 1,
#   '12': 2,
#   '10': 1,
#   '8': 1},
#  'Stohlman, Stephen A.': {'1': 24,
#   '4': 7,
#   '8': 1,
#   '2': 13,
#   '3': 8,
#   '6': 5,
#   '0': 5,
#   '7': 5,
#   '5': 5},
#  'Denison, Mark R.': {'11': 1,
#   '15': 1,
#   '4': 15,
#   '3': 9,
#   '1': 8,
#   '17': 2,
#   '23': 1,
#   '7': 3,
#   '5': 3,
#   '16': 1,
#   '10': 2,
#   '2': 9,
#   '26': 1,
#   '8': 2,
#   '0': 5,
#   '22': 1,
#   '9': 1,
#   '21': 2,
#   '6': 4,
#   '13': 2},
#  'Lau, Susanna K. P.': {'1': 27,
#   '8': 3,
#   '2': 4,
#   '3': 2,
#   '5': 3,
#   '0': 27,
#   '10': 2,
#   '13': 1,
#   '16': 1,
#   '4': 1,
#   '11': 1},
#  'Feldmann, Heinz': {'6': 11,
#   '11': 7,
#   '21': 1,
#   '15': 1,
#   '14': 1,
#   '9': 4,
#   '10': 6,
#   '2': 5,
#   '5': 5,
#   '8': 3,
#   '3': 4,
#   '13': 3,
#   '16': 1,
#   '12': 3,
#   '7': 7,
#   '4': 4,
#   '1': 3,
#   '28': 1,
#   '24': 1,
#   '0': 1},
#  'Holmes, Kathryn V.': {'8': 3,
#   '6': 9,
#   '21': 1,
#   '3': 8,
#   '1': 7,
#   '2': 9,
#   '9': 2,
#   '22': 1,
#   '0': 6,
#   '5': 7,
#   '4': 8,
#   '13': 3,
#   '7': 4,
#   '10': 3},
#  'Thiel, Volker': {'4': 8,
#   '8': 4,
#   '6': 6,
#   '10': 7,
#   '12': 1,
#   '20': 1,
#   '11': 1,
#   '13': 4,
#   '24': 1,
#   '17': 1,
#   '5': 4,
#   '0': 7,
#   '16': 1,
#   '14': 1,
#   '2': 3,
#   '3': 10,
#   '7': 3,
#   '18': 1,
#   '1': 4,
#   '15': 1,
#   '9': 1},
#  'Zumla, Alimuddin': {'0': 23,
#   '13': 2,
#   '9': 2,
#   '1': 12,
#   '17': 1,
#   '3': 4,
#   '12': 3,
#   '2': 3,
#   '30': 1,
#   '5': 5,
#   '4': 4,
#   '6': 5,
#   '8': 1,
#   '10': 1,
#   '19': 1,
#   '20': 1,
#   '7': 1},
#  'Martella, Vito': {'3': 6,
#   '6': 9,
#   '7': 8,
#   '2': 6,
#   '0': 5,
#   '8': 7,
#   '1': 10,
#   '4': 5,
#   '11': 2,
#   '14': 1,
#   '9': 3,
#   '5': 5,
#   '12': 1,
#   '10': 1},
#  'Makino, Shinji': {'5': 7,
#   '4': 7,
#   '8': 3,
#   '1': 8,
#   '2': 13,
#   '20': 1,
#   '0': 6,
#   '6': 4,
#   '3': 12,
#   '7': 3,
#   '26': 1,
#   '12': 1,
#   '16': 1,
#   '9': 1},
#  'Lane, Thomas E.': {'3': 13,
#   '1': 14,
#   '4': 13,
#   '8': 2,
#   '5': 6,
#   '7': 2,
#   '2': 7,
#   '9': 3,
#   '6': 3,
#   '0': 4},
#  'Haagmans, Bart L.': {'0': 6,
#   '10': 2,
#   '5': 2,
#   '8': 9,
#   '6': 5,
#   '7': 4,
#   '17': 1,
#   '9': 6,
#   '15': 3,
#   '19': 1,
#   '2': 7,
#   '12': 3,
#   '4': 4,
#   '16': 1,
#   '11': 2,
#   '3': 3,
#   '14': 1,
#   '1': 3,
#   '23': 1,
#   '13': 1},
#  'Zhang, Wei': {'3': 8,
#   '2': 9,
#   '0': 14,
#   '1': 7,
#   '6': 3,
#   '13': 1,
#   '4': 8,
#   '17': 1,
#   '5': 6,
#   '7': 3,
#   '8': 3,
#   '10': 1},
#  'Subbarao, Kanta': {'12': 3,
#   '5': 6,
#   '9': 6,
#   '24': 1,
#   '1': 11,
#   '10': 8,
#   '25': 2,
#   '21': 1,
#   '2': 3,
#   '3': 3,
#   '6': 4,
#   '7': 5,
#   '14': 3,
#   '11': 1,
#   '19': 1,
#   '0': 2,
#   '8': 2,
#   '4': 1},
#  'Gorbalenya, Alexander E.': {'4': 9,
#   '1': 8,
#   '13': 2,
#   '8': 3,
#   '6': 7,
#   '15': 1,
#   '0': 9,
#   '17': 1,
#   '9': 2,
#   '3': 6,
#   '12': 1,
#   '2': 9,
#   '5': 3,
#   '7': 2},
#  'Rottier, Peter J. M.': {'6': 11,
#   '4': 19,
#   '2': 10,
#   '5': 4,
#   '7': 5,
#   '9': 3,
#   '12': 1,
#   '3': 7,
#   '1': 2,
#   '0': 1},
#  'Baker, Susan C.': {'2': 8,
#   '9': 3,
#   '7': 6,
#   '6': 3,
#   '3': 14,
#   '4': 7,
#   '1': 8,
#   '0': 1,
#   '5': 6,
#   '12': 1,
#   '8': 2,
#   '11': 2,
#   '10': 2},
#  'Cowling, Benjamin J.': {'0': 9,
#   '2': 9,
#   '1': 13,
#   '13': 3,
#   '8': 1,
#   '7': 4,
#   '27': 1,
#   '5': 3,
#   '14': 1,
#   '3': 5,
#   '4': 2,
#   '6': 5,
#   '20': 1,
#   '9': 2,
#   '10': 1,
#   '18': 1,
#   '41': 1},
#  'Tan, Wenjie': {'8': 7,
#   '12': 1,
#   '7': 9,
#   '10': 5,
#   '4': 4,
#   '3': 2,
#   '6': 8,
#   '14': 1,
#   '13': 5,
#   '2': 2,
#   '11': 5,
#   '9': 1,
#   '5': 7,
#   '17': 2,
#   '16': 1,
#   '34': 2},
#  'Liu, Wei': {'4': 5,
#   '1': 5,
#   '7': 5,
#   '0': 17,
#   '9': 2,
#   '8': 3,
#   '6': 5,
#   '2': 5,
#   '5': 4,
#   '3': 6,
#   '14': 1,
#   '1249': 1,
#   '17': 1,
#   '13': 1},
#  'Nishiura, Hiroshi': {'0': 28,
#   '6': 3,
#   '4': 3,
#   '2': 8,
#   '5': 4,
#   '1': 9,
#   '3': 1,
#   '20': 1,
#   '10': 1,
#   '11': 1,
#   '8': 2},
#  'Zhou, Yusen': {'2': 4,
#   '11': 8,
#   '10': 6,
#   '12': 2,
#   '7': 8,
#   '9': 6,
#   '8': 2,
#   '13': 2,
#   '22': 1,
#   '17': 1,
#   '0': 2,
#   '6': 5,
#   '3': 2,
#   '1': 5,
#   '5': 4,
#   '18': 1,
#   '4': 2},
#  'Peiris, Malik': {'1': 9,
#   '6': 5,
#   '3': 2,
#   '11': 2,
#   '9': 2,
#   '5': 7,
#   '7': 3,
#   '17': 1,
#   '14': 2,
#   '13': 1,
#   '8': 5,
#   '10': 6,
#   '16': 1,
#   '12': 1,
#   '29': 1,
#   '22': 1,
#   '33': 1,
#   '4': 5,
#   '15': 2,
#   '2': 2,
#   '18': 1,
#   '19': 1},
#  'Bergmann, Cornelia C.': {'6': 4,
#   '5': 5,
#   '1': 16,
#   '3': 11,
#   '2': 9,
#   '4': 9,
#   '20': 1,
#   '0': 3,
#   '7': 1,
#   '8': 1},
#  'Li, Fang': {'4': 4,
#   '7': 9,
#   '19': 1,
#   '12': 1,
#   '8': 5,
#   '5': 7,
#   '9': 4,
#   '15': 1,
#   '0': 9,
#   '3': 4,
#   '11': 1,
#   '6': 4,
#   '1': 4,
#   '2': 4,
#   '10': 2},
#  'Al-Tawfiq, Jaffar A.': {'9': 1,
#   '1': 15,
#   '2': 5,
#   '0': 26,
#   '3': 5,
#   '6': 2,
#   '10': 1,
#   '12': 1,
#   '8': 2,
#   '4': 1,
#   '5': 1},
#  'Lu, Lu': {'8': 4,
#   '1': 7,
#   '0': 6,
#   '3': 9,
#   '9': 2,
#   '16': 1,
#   '5': 5,
#   '17': 1,
#   '11': 2,
#   '103': 1,
#   '6': 7,
#   '4': 2,
#   '12': 1,
#   '14': 1,
#   '15': 1,
#   '10': 2,
#   '7': 2,
#   '21': 1,
#   '2': 2},
#  'Ziebuhr, John': {'4': 8,
#   '9': 5,
#   '8': 4,
#   '5': 9,
#   '1': 2,
#   '21': 1,
#   '2': 7,
#   '7': 4,
#   '0': 6,
#   '17': 1,
#   '6': 3,
#   '3': 4,
#   '16': 1,
#   '11': 1},
#  'van der Hoek, Lia': {'3': 3,
#   '8': 6,
#   '0': 5,
#   '9': 4,
#   '4': 5,
#   '1': 6,
#   '19': 1,
#   '7': 6,
#   '12': 3,
#   '14': 3,
#   '6': 4,
#   '13': 1,
#   '10': 1,
#   '24': 1,
#   '5': 3,
#   '110': 1,
#   '2': 3},
#  'Canard, Bruno': {'8': 6,
#   '11': 4,
#   '6': 6,
#   '5': 9,
#   '14': 2,
#   '9': 6,
#   '12': 1,
#   '7': 2,
#   '4': 6,
#   '3': 7,
#   '2': 3,
#   '1': 2,
#   '10': 1,
#   '0': 1},
#  'García-Sastre, Adolfo': {'2': 5,
#   '1': 6,
#   '5': 12,
#   '10': 3,
#   '6': 3,
#   '11': 2,
#   '4': 5,
#   '9': 3,
#   '3': 8,
#   '0': 7,
#   '7': 1,
#   '17': 1},
#  'Wang, Li': {'2': 7,
#   '1': 11,
#   '0': 9,
#   '3': 12,
#   '34': 1,
#   '4': 5,
#   '14': 1,
#   '6': 2,
#   '5': 4,
#   '9': 2,
#   '7': 1,
#   '10': 1},
#  'Taguchi, Fumihiro': {'0': 11,
#   '1': 8,
#   '10': 2,
#   '5': 4,
#   '8': 2,
#   '2': 8,
#   '4': 6,
#   '6': 4,
#   '7': 4,
#   '3': 5,
#   '9': 1,
#   '11': 1},
#  'Balzarini, Jan': {'1': 7,
#   '7': 2,
#   '11': 4,
#   '0': 6,
#   '6': 6,
#   '2': 6,
#   '4': 5,
#   '3': 10,
#   '5': 5,
#   '17': 1,
#   '9': 1,
#   '8': 2},
#  'Müller, Marcel A.': {'6': 3,
#   '0': 4,
#   '7': 2,
#   '2': 6,
#   '4': 7,
#   '9': 6,
#   '1': 4,
#   '14': 4,
#   '11': 2,
#   '12': 1,
#   '8': 2,
#   '5': 5,
#   '15': 1,
#   '3': 3,
#   '18': 1,
#   '17': 1,
#   '10': 2},
#  'Morikawa, Shigeru': {'6': 5,
#   '7': 3,
#   '15': 1,
#   '9': 6,
#   '1': 2,
#   '3': 2,
#   '21': 1,
#   '4': 11,
#   '14': 2,
#   '32': 1,
#   '2': 4,
#   '13': 2,
#   '8': 4,
#   '48': 1,
#   '26': 1,
#   '5': 3,
#   '10': 1,
#   '0': 1,
#   '25': 1,
#   '23': 1},
#  'Guan, Yi': {'13': 2,
#   '9': 4,
#   '7': 3,
#   '4': 3,
#   '3': 5,
#   '1': 2,
#   '23': 1,
#   '8': 6,
#   '5': 8,
#   '6': 4,
#   '15': 2,
#   '2': 2,
#   '10': 2,
#   '28': 2,
#   '0': 3,
#   '12': 2,
#   '14': 1,
#   '11': 1},
#  'Gern, James E.': {'9': 2,
#   '2': 4,
#   '0': 9,
#   '4': 4,
#   '5': 4,
#   '8': 5,
#   '6': 2,
#   '16': 1,
#   '20': 1,
#   '13': 1,
#   '11': 1,
#   '15': 1,
#   '1': 9,
#   '7': 3,
#   '14': 2,
#   '3': 2,
#   '10': 2},
#  'Xiao, Shaobo': {'7': 11,
#   '9': 10,
#   '8': 12,
#   '5': 7,
#   '6': 5,
#   '3': 1,
#   '11': 1,
#   '2': 2,
#   '12': 1,
#   '10': 2,
#   '1': 1},
#  'Feng, Li': {'5': 9,
#   '6': 4,
#   '7': 12,
#   '12': 4,
#   '9': 4,
#   '8': 5,
#   '16': 1,
#   '13': 2,
#   '4': 1,
#   '11': 3,
#   '10': 4,
#   '2': 2,
#   '15': 1,
#   '1': 1},
#  'Zhao, Jincun': {'0': 13,
#   '1': 11,
#   '6': 1,
#   '3': 5,
#   '13': 1,
#   '4': 4,
#   '16': 1,
#   '5': 5,
#   '12': 2,
#   '11': 1,
#   '21': 1,
#   '2': 3,
#   '19': 1,
#   '20': 1,
#   '17': 1,
#   '8': 1},
#  'Zhang, Yan': {'2': 11,
#   '0': 4,
#   '3': 9,
#   '7': 5,
#   '4': 7,
#   '1': 8,
#   '5': 2,
#   '8': 2,
#   '2429': 1,
#   '6': 2,
#   '15': 1},
#  'Raoult, Didier': {'7': 5,
#   '3': 8,
#   '0': 8,
#   '6': 5,
#   '8': 5,
#   '11': 4,
#   '9': 1,
#   '12': 1,
#   '5': 2,
#   '2': 3,
#   '17': 2,
#   '28': 1,
#   '1': 2,
#   '10': 1,
#   '14': 1,
#   '4': 2,
#   '13': 1},
#  'Vabret, Astrid': {'3': 9,
#   '2': 3,
#   '10': 1,
#   '7': 3,
#   '13': 1,
#   '0': 7,
#   '9': 2,
#   '6': 7,
#   '4': 4,
#   '1': 9,
#   '8': 3,
#   '5': 2},
#  'Britton, Paul': {'4': 6,
#   '2': 13,
#   '5': 2,
#   '1': 6,
#   '7': 1,
#   '3': 14,
#   '6': 3,
#   '0': 5,
#   '8': 1},
#  'Holmes, Edward C.': {'32': 2,
#   '1': 11,
#   '7': 7,
#   '20': 1,
#   '2': 4,
#   '11': 2,
#   '12': 2,
#   '3': 4,
#   '4': 6,
#   '16': 1,
#   '8': 2,
#   '14': 2,
#   '6': 2,
#   '0': 1,
#   '5': 1,
#   '10': 2,
#   '17': 1},
#  'Zheng, Bo-Jian': {'5': 6,
#   '4': 4,
#   '10': 5,
#   '13': 5,
#   '6': 2,
#   '3': 2,
#   '7': 4,
#   '8': 2,
#   '11': 3,
#   '9': 6,
#   '21': 1,
#   '15': 2,
#   '14': 1,
#   '1': 3,
#   '0': 1,
#   '12': 4},
#  'Liu, Shengwang': {'5': 6,
#   '8': 7,
#   '7': 9,
#   '4': 4,
#   '1': 2,
#   '6': 6,
#   '13': 2,
#   '0': 5,
#   '11': 3,
#   '12': 1,
#   '9': 5,
#   '10': 1},
#  'Talbot, Pierre J.': {'6': 3,
#   '7': 2,
#   '2': 8,
#   '5': 6,
#   '8': 1,
#   '4': 7,
#   '1': 3,
#   '3': 14,
#   '0': 6,
#   '9': 1},
#  'Li, Wei': {'4': 8,
#   '0': 4,
#   '5': 4,
#   '2': 4,
#   '3': 9,
#   '10': 1,
#   '7': 1,
#   '1': 7,
#   '18': 1,
#   '21': 1,
#   '13': 1,
#   '9': 1,
#   '1196': 1,
#   '1197': 1,
#   '6': 3,
#   '22': 1,
#   '14': 1,
#   '8': 1},
#  'Gao, Feng': {'8': 6,
#   '9': 3,
#   '12': 2,
#   '6': 3,
#   '7': 3,
#   '0': 2,
#   '10': 7,
#   '11': 1,
#   '2': 7,
#   '3': 9,
#   '4': 2,
#   '5': 3,
#   '664': 1,
#   '1': 1},
#  'Hilgenfeld, Rolf': {'5': 9,
#   '1': 4,
#   '10': 3,
#   '9': 2,
#   '15': 2,
#   '6': 4,
#   '13': 3,
#   '4': 5,
#   '0': 4,
#   '8': 1,
#   '11': 2,
#   '7': 2,
#   '3': 1,
#   '2': 6,
#   '18': 1},
#  'Liu, Ding Xiang': {'4': 12,
#   '3': 7,
#   '5': 10,
#   '8': 1,
#   '2': 8,
#   '9': 1,
#   '1': 5,
#   '7': 2,
#   '10': 1,
#   '6': 1,
#   '0': 1},
#  'Wang, Jianwei': {'15': 1,
#   '5': 6,
#   '7': 4,
#   '10': 2,
#   '8': 6,
#   '11': 2,
#   '6': 3,
#   '35': 1,
#   '9': 5,
#   '24': 1,
#   '14': 2,
#   '22': 1,
#   '3': 2,
#   '16': 2,
#   '4': 2,
#   '13': 2,
#   '1': 1,
#   '33': 1,
#   '18': 1,
#   '17': 1,
#   '2': 2,
#   '27': 1},
#  'Katze, Michael G.': {'12': 3,
#   '16': 1,
#   '11': 4,
#   '6': 4,
#   '15': 2,
#   '5': 4,
#   '19': 2,
#   '3': 3,
#   '9': 2,
#   '22': 1,
#   '18': 1,
#   '4': 3,
#   '23': 1,
#   '13': 4,
#   '10': 1,
#   '8': 2,
#   '66': 1,
#   '0': 2,
#   '7': 2,
#   '14': 1,
#   '27': 1,
#   '2': 4},
#  'Sims, Amy C.': {'2': 15,
#   '4': 7,
#   '1': 13,
#   '6': 2,
#   '11': 1,
#   '17': 1,
#   '8': 3,
#   '5': 1,
#   '0': 5,
#   '3': 1},
#  'Fang, Liurong': {'1': 24,
#   '2': 5,
#   '7': 4,
#   '10': 2,
#   '8': 1,
#   '4': 3,
#   '9': 4,
#   '6': 3,
#   '5': 3},
#  'Tan, Yee-Joo': {'0': 7,
#   '7': 4,
#   '2': 8,
#   '3': 6,
#   '12': 1,
#   '5': 4,
#   '1': 5,
#   '4': 1,
#   '10': 2,
#   '2064': 1,
#   '8': 3,
#   '16': 1,
#   '13': 1,
#   '6': 3,
#   '9': 1},
#  'Farzan, Michael': {'15': 1,
#   '6': 8,
#   '2': 5,
#   '17': 2,
#   '10': 2,
#   '3': 8,
#   '7': 2,
#   '14': 1,
#   '1': 2,
#   '4': 5,
#   '11': 1,
#   '8': 3,
#   '13': 2,
#   '9': 1,
#   '12': 2,
#   '5': 3},
#  'Osterhaus, Albert D. M. E.': {'2': 2,
#   '9': 5,
#   '7': 4,
#   '3': 5,
#   '5': 8,
#   '1': 2,
#   '6': 6,
#   '15': 1,
#   '14': 1,
#   '8': 5,
#   '17': 1,
#   '11': 2,
#   '13': 4,
#   '10': 1,
#   '0': 1},
#  'Herrler, Georg': {'6': 3,
#   '5': 3,
#   '8': 2,
#   '21': 1,
#   '26': 1,
#   '10': 4,
#   '12': 1,
#   '3': 7,
#   '4': 11,
#   '9': 1,
#   '1': 7,
#   '11': 1,
#   '2': 3,
#   '16': 1,
#   '0': 1,
#   '7': 1},
#  'Sola, Isabel': {'1': 12,
#   '0': 6,
#   '2': 9,
#   '5': 3,
#   '6': 2,
#   '8': 1,
#   '13': 1,
#   '9': 1,
#   '3': 5,
#   '7': 1,
#   '4': 6,
#   '15': 1},
#  'Boeckh, Michael': {'0': 1,
#   '7': 7,
#   '1': 3,
#   '6': 6,
#   '8': 5,
#   '3': 3,
#   '10': 4,
#   '11': 1,
#   '5': 4,
#   '4': 4,
#   '29': 1,
#   '17': 1,
#   '2': 3,
#   '19': 1,
#   '14': 1,
#   '9': 2},
#  'de Haan, Cornelis A. M.': {'7': 7,
#   '5': 4,
#   '3': 4,
#   '8': 3,
#   '9': 2,
#   '4': 3,
#   '2': 4,
#   '11': 3,
#   '1': 4,
#   '12': 1,
#   '0': 9,
#   '6': 2},
#  'Elia, Gabriella': {'5': 6,
#   '2': 7,
#   '3': 6,
#   '6': 5,
#   '4': 7,
#   '9': 2,
#   '8': 2,
#   '7': 2,
#   '1': 5,
#   '0': 4},
#  'Buchmeier, Michael J.': {'10': 3,
#   '4': 6,
#   '3': 8,
#   '6': 4,
#   '5': 3,
#   '8': 2,
#   '9': 3,
#   '7': 2,
#   '11': 1,
#   '2': 3,
#   '1': 8,
#   '0': 2,
#   '14': 1},
#  'Yang, Yang': {'0': 9,
#   '1': 11,
#   '2': 8,
#   '4': 5,
#   '3': 3,
#   '5': 2,
#   '6': 2,
#   '8': 2,
#   '9': 1,
#   '15': 1,
#   '32': 1,
#   '10': 1},
#  'Peiris, J. S. Malik': {'6': 5,
#   '11': 3,
#   '5': 7,
#   '14': 1,
#   '9': 2,
#   '1': 2,
#   '7': 8,
#   '8': 4,
#   '3': 2,
#   '4': 2,
#   '0': 2,
#   '10': 1,
#   '2': 3,
#   '13': 3},
#  'Kuypers, Jane': {'2': 10,
#   '1': 8,
#   '6': 2,
#   '0': 5,
#   '3': 9,
#   '4': 4,
#   '5': 4,
#   '7': 2,
#   '9': 1},
#  'Zhang, Jing': {'6': 2,
#   '14': 2,
#   '2': 4,
#   '1': 4,
#   '10': 1,
#   '4': 5,
#   '7': 4,
#   '9': 4,
#   '0': 3,
#   '8': 3,
#   '3': 5,
#   '25': 1,
#   '5': 5,
#   '11': 1,
#   '16': 1},
#  'Whittaker, Gary R.': {'2': 9,
#   '3': 8,
#   '6': 2,
#   '1': 13,
#   '0': 3,
#   '4': 7,
#   '5': 2,
#   '8': 1},
#  'Lai, M M': {'1': 14, '4': 6, '0': 9, '3': 4, '2': 6, '6': 3, '5': 2, '7': 1},
#  'Rao, Zihe': {'18': 2,
#   '3': 3,
#   '9': 6,
#   '6': 8,
#   '10': 3,
#   '4': 2,
#   '7': 3,
#   '8': 5,
#   '17': 1,
#   '5': 3,
#   '2': 4,
#   '27': 1,
#   '0': 1,
#   '14': 1,
#   '13': 1},
#  'Drexler, Jan Felix': {'4': 6,
#   '5': 4,
#   '2': 5,
#   '0': 9,
#   '21': 1,
#   '7': 3,
#   '9': 1,
#   '6': 3,
#   '12': 1,
#   '20': 2,
#   '14': 1,
#   '15': 1,
#   '8': 2,
#   '3': 3,
#   '28': 1,
#   '18': 1},
#  'Fukushi, Shuetsu': {'6': 3,
#   '5': 5,
#   '0': 6,
#   '7': 2,
#   '22': 1,
#   '1': 11,
#   '2': 4,
#   '8': 1,
#   '3': 7,
#   '35': 1,
#   '4': 3},
#  'Gautret, Philippe': {'0': 11,
#   '1': 6,
#   '12': 2,
#   '11': 5,
#   '4': 3,
#   '14': 2,
#   '5': 1,
#   '2': 4,
#   '20': 1,
#   '3': 2,
#   '7': 1,
#   '13': 1,
#   '10': 2,
#   '6': 1,
#   '9': 1,
#   '8': 1},
#  'Chen, Yu': {'0': 10,
#   '1': 4,
#   '11': 2,
#   '16': 1,
#   '3': 4,
#   '2': 3,
#   '5': 3,
#   '6': 2,
#   '8': 3,
#   '10': 2,
#   '17': 2,
#   '13': 1,
#   '4': 3,
#   '12': 2,
#   '18': 1,
#   '7': 1},
#  'Memish, Ziad A': {'1': 8,
#   '7': 1,
#   '0': 11,
#   '2': 4,
#   '12': 1,
#   '18': 1,
#   '112': 1,
#   '5': 3,
#   '8': 2,
#   '3': 4,
#   '15': 1,
#   '4': 2,
#   '6': 2,
#   '16': 1,
#   '21': 1,
#   '124': 1},
#  'Mizutani, Tetsuya': {'1': 5,
#   '10': 2,
#   '8': 3,
#   '0': 10,
#   '12': 2,
#   '4': 3,
#   '23': 1,
#   '9': 2,
#   '21': 1,
#   '3': 4,
#   '17': 5,
#   '6': 1,
#   '22': 1,
#   '2': 1,
#   '5': 1,
#   '25': 1},
#  'Englund, Janet A.': {'3': 4,
#   '6': 6,
#   '4': 5,
#   '7': 5,
#   '5': 4,
#   '2': 3,
#   '9': 5,
#   '10': 1,
#   '1': 5,
#   '13': 1,
#   '8': 3,
#   '0': 1},
#  'Gerber, Susan I.': {'4': 2,
#   '15': 5,
#   '7': 3,
#   '5': 2,
#   '20': 1,
#   '16': 3,
#   '28': 1,
#   '19': 1,
#   '25': 1,
#   '11': 3,
#   '8': 1,
#   '14': 2,
#   '12': 2,
#   '9': 3,
#   '27': 2,
#   '1': 1,
#   '10': 2,
#   '3': 3,
#   '29': 1,
#   '26': 1,
#   '2': 1,
#   '18': 1,
#   '6': 1},
#  'Andrei, Graciela': {'9': 4,
#   '4': 7,
#   '2': 7,
#   '1': 11,
#   '3': 5,
#   '8': 2,
#   '11': 1,
#   '0': 1,
#   '5': 2,
#   '7': 2,
#   '6': 1},
#  'Pyrc, Krzysztof': {'0': 9,
#   '6': 3,
#   '4': 3,
#   '3': 5,
#   '14': 1,
#   '8': 2,
#   '7': 3,
#   '9': 5,
#   '5': 3,
#   '1': 5,
#   '2': 1,
#   '11': 1,
#   '10': 1},
#  'Lanzavecchia, Antonio': {'11': 2,
#   '5': 6,
#   '12': 3,
#   '25': 2,
#   '15': 4,
#   '8': 3,
#   '6': 1,
#   '13': 2,
#   '17': 2,
#   '20': 2,
#   '21': 1,
#   '0': 4,
#   '7': 1,
#   '4': 2,
#   '18': 2,
#   '1': 1,
#   '16': 2,
#   '9': 1,
#   '2': 1},
#  'Wang, Jing': {'4': 5,
#   '0': 7,
#   '1': 7,
#   '53': 1,
#   '3': 5,
#   '5': 4,
#   '2': 6,
#   '2233': 1,
#   '7': 1,
#   '1136': 1,
#   '11': 1,
#   '13': 1,
#   '6': 1,
#   '24': 1},
#  'Wiwanitkit, Viroj': {'0': 14, '1': 28},
#  'Chowell, Gerardo': {'0': 19,
#   '2': 8,
#   '8': 1,
#   '3': 3,
#   '1': 7,
#   '4': 1,
#   '5': 2,
#   '7': 1},
#  'Zhang, Xin': {'5': 6,
#   '20': 1,
#   '0': 7,
#   '4': 10,
#   '1': 4,
#   '6': 6,
#   '2': 1,
#   '3': 5,
#   '10': 1,
#   '8': 1},
#  'Chen, Huanchun': {'6': 9,
#   '8': 5,
#   '4': 5,
#   '9': 3,
#   '7': 11,
#   '5': 4,
#   '3': 2,
#   '11': 1,
#   '10': 1,
#   '0': 1},
#  'Berkhout, Ben': {'2': 7,
#   '7': 5,
#   '8': 2,
#   '3': 5,
#   '1': 6,
#   '4': 3,
#   '9': 1,
#   '5': 6,
#   '6': 1,
#   '0': 4,
#   '145': 1},
#  'Zhang, Yi': {'4': 9,
#   '2': 5,
#   '0': 7,
#   '7': 2,
#   '8': 1,
#   '9': 3,
#   '1': 8,
#   '3': 1,
#   '32': 1,
#   '5': 1,
#   '6': 2,
#   '16': 1},
#  'Anderson, Larry J.': {'14': 1,
#   '8': 2,
#   '4': 2,
#   '10': 4,
#   '15': 1,
#   '5': 4,
#   '1': 4,
#   '6': 6,
#   '3': 3,
#   '7': 5,
#   '0': 4,
#   '2': 2,
#   '23': 1,
#   '19': 1,
#   '26': 1},
#  'Ruuskanen, Olli': {'5': 6,
#   '7': 3,
#   '4': 10,
#   '6': 4,
#   '8': 2,
#   '12': 1,
#   '1': 3,
#   '11': 1,
#   '0': 3,
#   '2': 3,
#   '10': 3,
#   '3': 2},
#  'Saijo, Masayuki': {'7': 5,
#   '19': 1,
#   '3': 2,
#   '10': 1,
#   '31': 1,
#   '5': 4,
#   '9': 3,
#   '14': 1,
#   '1': 3,
#   '4': 3,
#   '13': 1,
#   '49': 1,
#   '2': 8,
#   '0': 3,
#   '8': 1,
#   '6': 2,
#   '12': 1},
#  'Shi, Zheng-Li': {'8': 3,
#   '11': 5,
#   '5': 3,
#   '15': 1,
#   '10': 3,
#   '26': 3,
#   '2': 6,
#   '7': 3,
#   '19': 2,
#   '6': 1,
#   '13': 1,
#   '0': 1,
#   '14': 1,
#   '9': 2,
#   '12': 1,
#   '3': 1,
#   '1': 1,
#   '28': 1,
#   '16': 1,
#   '42': 1},
#  'Masters, Paul S.': {'2': 11,
#   '0': 4,
#   '5': 3,
#   '1': 9,
#   '7': 1,
#   '3': 7,
#   '4': 4,
#   '12': 1,
#   '6': 1},
#  'Lipkin, W. Ian': {'0': 9,
#   '33': 2,
#   '23': 1,
#   '10': 2,
#   '13': 1,
#   '9': 2,
#   '7': 3,
#   '15': 3,
#   '12': 1,
#   '16': 1,
#   '20': 1,
#   '14': 2,
#   '19': 2,
#   '4': 2,
#   '6': 1,
#   '8': 2,
#   '2': 2,
#   '21': 1,
#   '11': 1,
#   '32': 1},
#  'Erdman, Dean D.': {'2': 6,
#   '5': 4,
#   '1': 4,
#   '8': 3,
#   '13': 2,
#   '6': 3,
#   '7': 2,
#   '3': 2,
#   '16': 1,
#   '11': 2,
#   '15': 1,
#   '9': 1,
#   '24': 1,
#   '10': 2,
#   '0': 1,
#   '17': 2,
#   '12': 1,
#   '23': 1,
#   '4': 1},
#  'Zhang, Li': {'2': 7,
#   '4': 4,
#   '3': 2,
#   '0': 6,
#   '5': 4,
#   '1': 5,
#   '15': 1,
#   '17': 1,
#   '6': 4,
#   '8': 1,
#   '2422': 1,
#   '1029': 1,
#   '41': 1,
#   '7': 1,
#   '13': 1},
#  'Yoo, Dongwan': {'4': 7, '5': 2, '3': 6, '2': 7, '6': 2, '1': 9, '0': 7},
#  'Neuman, Benjamin W.': {'0': 15,
#   '2': 4,
#   '9': 2,
#   '1': 5,
#   '3': 8,
#   '11': 1,
#   '6': 2,
#   '5': 1,
#   '4': 1,
#   '7': 1},
#  'Zhang, Jianqiang': {'8': 2,
#   '3': 5,
#   '13': 2,
#   '10': 2,
#   '12': 2,
#   '2': 4,
#   '7': 4,
#   '4': 3,
#   '9': 1,
#   '0': 8,
#   '14': 1,
#   '1': 3,
#   '6': 1,
#   '5': 1,
#   '11': 1},
#  'Ippolito, Giuseppe': {'3': 5,
#   '8': 4,
#   '10': 4,
#   '15': 2,
#   '9': 3,
#   '12': 1,
#   '32': 1,
#   '6': 1,
#   '2': 3,
#   '0': 2,
#   '4': 3,
#   '29': 1,
#   '13': 2,
#   '54': 1,
#   '5': 2,
#   '1': 1,
#   '16': 2,
#   '18': 1},
#  'Zhou, Peng': {'3': 10,
#   '0': 9,
#   '7': 3,
#   '2': 5,
#   '22': 2,
#   '18': 1,
#   '1': 2,
#   '4': 3,
#   '5': 1,
#   '6': 1,
#   '8': 1,
#   '10': 1},
#  'Dimitrov, Dimiter S.': {'11': 4,
#   '8': 3,
#   '6': 4,
#   '3': 7,
#   '0': 4,
#   '12': 1,
#   '2': 3,
#   '9': 2,
#   '10': 1,
#   '19': 1,
#   '7': 1,
#   '5': 2,
#   '13': 1,
#   '23': 2,
#   '1': 1,
#   '21': 1,
#   '15': 1},
#  'Zhao, Guangyu': {'0': 5,
#   '9': 2,
#   '1': 15,
#   '5': 3,
#   '3': 6,
#   '2': 3,
#   '4': 2,
#   '12': 1,
#   '10': 1,
#   '8': 1},
#  'Wang, Dang': {'5': 6,
#   '1': 6,
#   '7': 4,
#   '2': 5,
#   '3': 3,
#   '4': 6,
#   '0': 6,
#   '6': 2,
#   '8': 1},
#  'Snoeck, Robert': {'3': 14,
#   '4': 10,
#   '5': 5,
#   '7': 3,
#   '10': 2,
#   '8': 1,
#   '2': 2,
#   '9': 1,
#   '6': 1},
#  'Lee, Nelson': {'7': 3,
#   '5': 5,
#   '0': 11,
#   '11': 1,
#   '1': 10,
#   '8': 1,
#   '4': 2,
#   '3': 3,
#   '2': 1,
#   '6': 1},
#  'Jartti, Tuomas': {'5': 5,
#   '2': 1,
#   '0': 14,
#   '4': 1,
#   '1': 4,
#   '12': 1,
#   '16': 1,
#   '9': 3,
#   '11': 1,
#   '3': 1,
#   '8': 2,
#   '6': 2,
#   '7': 1,
#   '10': 1},
#  'Diamond, Michael S.': {'1': 5,
#   '10': 2,
#   '15': 1,
#   '13': 3,
#   '5': 5,
#   '6': 1,
#   '0': 2,
#   '4': 4,
#   '2': 3,
#   '3': 6,
#   '11': 2,
#   '23': 1,
#   '9': 1,
#   '7': 2},
#  'Shi, Zhengli': {'4': 3,
#   '12': 2,
#   '5': 4,
#   '3': 5,
#   '1': 3,
#   '8': 5,
#   '6': 5,
#   '13': 1,
#   '0': 3,
#   '10': 1,
#   '11': 1,
#   '7': 2,
#   '9': 1,
#   '2': 1,
#   '15': 1},
#  'Becker, Stephan': {'6': 5,
#   '4': 4,
#   '7': 2,
#   '2': 1,
#   '3': 2,
#   '5': 3,
#   '11': 4,
#   '37': 1,
#   '13': 3,
#   '8': 2,
#   '16': 1,
#   '1': 3,
#   '14': 1,
#   '9': 1,
#   '22': 1,
#   '25': 1,
#   '23': 1,
#   '10': 2},
#  'Kuhn, Jens H.': {'12': 1,
#   '2': 3,
#   '8': 5,
#   '3': 6,
#   '0': 4,
#   '6': 3,
#   '7': 3,
#   '13': 1,
#   '5': 3,
#   '9': 2,
#   '4': 3,
#   '15': 1,
#   '18': 2,
#   '10': 1},
#  'Delwart, Eric': {'9': 5,
#   '4': 3,
#   '11': 3,
#   '5': 10,
#   '10': 3,
#   '6': 4,
#   '0': 2,
#   '7': 3,
#   '16': 1,
#   '3': 1,
#   '2': 1,
#   '1': 1,
#   '13': 1},
#  'Kawaoka, Yoshihiro': {'13': 1,
#   '5': 2,
#   '3': 2,
#   '21': 1,
#   '16': 2,
#   '24': 2,
#   '20': 3,
#   '9': 3,
#   '63': 1,
#   '4': 7,
#   '18': 1,
#   '8': 1,
#   '11': 1,
#   '1': 1,
#   '6': 4,
#   '10': 2,
#   '26': 1,
#   '2': 1,
#   '7': 2},
#  'Wang, Jian': {'2': 3,
#   '19': 2,
#   '13': 3,
#   '3': 4,
#   '1': 3,
#   '0': 3,
#   '12': 3,
#   '26': 1,
#   '6': 1,
#   '5': 1,
#   '15': 2,
#   '10': 2,
#   '21': 2,
#   '18': 2,
#   '16': 2,
#   '54': 1,
#   '62': 1,
#   '7': 1,
#   '11': 1},
#  'Neyts, Johan': {'11': 1,
#   '9': 4,
#   '7': 3,
#   '1': 8,
#   '3': 5,
#   '10': 1,
#   '8': 2,
#   '14': 1,
#   '12': 1,
#   '6': 1,
#   '2': 4,
#   '4': 2,
#   '5': 3,
#   '15': 1,
#   '21': 1},
#  'Zhang, Yu': {'0': 5,
#   '3': 8,
#   '1': 4,
#   '6': 4,
#   '7': 2,
#   '2': 1,
#   '8': 3,
#   '4': 2,
#   '9': 2,
#   '5': 2,
#   '13': 1,
#   '12': 1,
#   '39': 1,
#   '24': 1,
#   '31': 1},
#  'Jin, Dong-Yan': {'3': 4,
#   '6': 3,
#   '4': 5,
#   '11': 4,
#   '9': 2,
#   '15': 1,
#   '18': 1,
#   '24': 1,
#   '14': 2,
#   '2': 4,
#   '22': 1,
#   '8': 2,
#   '7': 2,
#   '10': 2,
#   '5': 2,
#   '1': 1},
#  'Frieman, Matthew B.': {'0': 2,
#   '12': 1,
#   '3': 3,
#   '1': 8,
#   '5': 4,
#   '13': 1,
#   '6': 4,
#   '18': 1,
#   '7': 3,
#   '2': 2,
#   '14': 1,
#   '8': 3,
#   '9': 1,
#   '4': 2,
#   '10': 1},
#  'Chan, Paul K.S.': {'6': 5,
#   '2': 7,
#   '0': 6,
#   '4': 3,
#   '8': 4,
#   '13': 1,
#   '1': 3,
#   '5': 2,
#   '3': 3,
#   '7': 2,
#   '15': 1},
#  'Hiscox, Julian A.': {'8': 2,
#   '7': 4,
#   '2': 5,
#   '0': 5,
#   '4': 8,
#   '1': 3,
#   '3': 2,
#   '5': 4,
#   '6': 2,
#   '20': 1,
#   '9': 1},
#  'Dijkman, Ronald': {'0': 7,
#   '6': 4,
#   '10': 1,
#   '3': 3,
#   '1': 8,
#   '2': 2,
#   '9': 1,
#   '4': 7,
#   '13': 1,
#   '5': 2},
#  'Leung, Gabriel M.': {'12': 4,
#   '7': 4,
#   '3': 4,
#   '2': 2,
#   '0': 4,
#   '10': 2,
#   '6': 1,
#   '5': 5,
#   '25': 1,
#   '8': 1,
#   '9': 2,
#   '1': 1,
#   '4': 2,
#   '18': 1,
#   '26': 1,
#   '43': 1},
#  'Jahrling, Peter B.': {'12': 3,
#   '14': 3,
#   '3': 2,
#   '2': 1,
#   '7': 4,
#   '0': 2,
#   '10': 1,
#   '4': 3,
#   '20': 1,
#   '8': 2,
#   '17': 3,
#   '5': 3,
#   '21': 1,
#   '16': 1,
#   '9': 3,
#   '13': 1,
#   '15': 1,
#   '27': 1},
#  'Graham, Rachel L.': {'7': 3,
#   '0': 8,
#   '6': 7,
#   '5': 2,
#   '3': 3,
#   '1': 7,
#   '2': 4,
#   '4': 2},
#  'Han, Zongxi': {'1': 8,
#   '2': 8,
#   '3': 3,
#   '5': 4,
#   '0': 6,
#   '4': 4,
#   '6': 1,
#   '7': 1,
#   '8': 1},
#  'Zhao, Yan': {'7': 2,
#   '3': 4,
#   '1': 4,
#   '4': 5,
#   '5': 4,
#   '14': 1,
#   '0': 3,
#   '10': 3,
#   '18': 1,
#   '9': 1,
#   '6': 5,
#   '40': 1,
#   '8': 1,
#   '2': 1},
#  'Chen, Jing': {'0': 4,
#   '5': 4,
#   '8': 2,
#   '11': 3,
#   '3': 6,
#   '9': 1,
#   '7': 2,
#   '4': 2,
#   '10': 2,
#   '2': 3,
#   '1': 4,
#   '6': 1,
#   '19': 1,
#   '31': 1},
#  'Leibowitz, Julian L.': {'4': 7,
#   '2': 6,
#   '6': 3,
#   '0': 5,
#   '1': 10,
#   '3': 3,
#   '5': 2},
#  'Brierley, Ian': {'4': 7,
#   '2': 7,
#   '5': 6,
#   '1': 2,
#   '8': 1,
#   '7': 1,
#   '0': 8,
#   '11': 1,
#   '3': 2},
#  'Lai, Michael M.C.': {'3': 10,
#   '2': 9,
#   '0': 2,
#   '1': 3,
#   '5': 3,
#   '4': 7,
#   '7': 1},
#  'Riley, Steven': {'1': 5,
#   '5': 5,
#   '9': 4,
#   '6': 2,
#   '2': 3,
#   '50': 1,
#   '4': 5,
#   '3': 4,
#   '7': 1,
#   '12': 1,
#   '0': 1,
#   '11': 1,
#   '24': 1,
#   '14': 1},
#  'Baric, Ralph': {'14': 3,
#   '11': 1,
#   '7': 2,
#   '6': 4,
#   '3': 3,
#   '15': 2,
#   '64': 1,
#   '4': 4,
#   '8': 4,
#   '9': 2,
#   '10': 2,
#   '1': 2,
#   '5': 2,
#   '25': 1,
#   '2': 2},
#  'Peng, Guiqing': {'9': 4,
#   '1': 1,
#   '2': 5,
#   '10': 2,
#   '6': 4,
#   '8': 5,
#   '5': 4,
#   '3': 1,
#   '0': 3,
#   '7': 4,
#   '11': 1,
#   '4': 1},
#  'Liu, Li': {'5': 7,
#   '4': 3,
#   '1': 4,
#   '2': 5,
#   '11': 1,
#   '0': 6,
#   '3': 4,
#   '6': 2,
#   '7': 1,
#   '8': 1,
#   '10': 1},
#  'Wang, Yu': {'21': 2,
#   '5': 2,
#   '16': 1,
#   '11': 1,
#   '17': 1,
#   '3': 3,
#   '2': 6,
#   '10': 2,
#   '8': 2,
#   '4': 2,
#   '6': 1,
#   '1': 5,
#   '0': 5,
#   '2252': 1,
#   '25': 1},
#  'Hsueh, Po-Ren': {'0': 5,
#   '8': 3,
#   '10': 1,
#   '1': 6,
#   '3': 4,
#   '2': 4,
#   '5': 4,
#   '6': 2,
#   '4': 4,
#   '11': 1,
#   '7': 1},
#  'Munster, Vincent J.': {'3': 5,
#   '4': 1,
#   '11': 2,
#   '6': 3,
#   '12': 3,
#   '2': 2,
#   '17': 1,
#   '7': 3,
#   '0': 3,
#   '10': 2,
#   '14': 2,
#   '1': 3,
#   '23': 1,
#   '9': 1,
#   '13': 1,
#   '5': 1,
#   '8': 1},
#  'Koopmans, Marion': {'12': 3,
#   '15': 1,
#   '4': 5,
#   '14': 1,
#   '6': 4,
#   '16': 1,
#   '3': 1,
#   '18': 1,
#   '13': 2,
#   '22': 1,
#   '0': 8,
#   '5': 1,
#   '8': 1,
#   '17': 1,
#   '2': 1,
#   '29': 1,
#   '1': 1,
#   '7': 1},
#  'Wang, Jun': {'1': 5,
#   '32': 1,
#   '0': 3,
#   '4': 2,
#   '2': 5,
#   '3': 6,
#   '11': 1,
#   '9': 1,
#   '6': 1,
#   '43': 1,
#   '44': 1,
#   '15': 1,
#   '7': 1,
#   '17': 1,
#   '53': 1,
#   '12': 2,
#   '59': 1,
#   '13': 1},
#  'He, Yuxian': {'2': 4,
#   '1': 3,
#   '6': 3,
#   '5': 1,
#   '7': 4,
#   '0': 9,
#   '8': 3,
#   '4': 2,
#   '9': 2,
#   '3': 3},
#  'Tong, Suxiang': {'0': 4,
#   '5': 1,
#   '3': 1,
#   '6': 4,
#   '23': 1,
#   '8': 3,
#   '7': 2,
#   '18': 3,
#   '26': 1,
#   '21': 1,
#   '14': 1,
#   '12': 2,
#   '1': 2,
#   '19': 1,
#   '41': 1,
#   '9': 1,
#   '17': 1,
#   '31': 1,
#   '13': 1,
#   '16': 1,
#   '2': 1},
#  'Collins, Peter L.': {'11': 1,
#   '3': 9,
#   '7': 3,
#   '20': 1,
#   '6': 5,
#   '4': 9,
#   '0': 1,
#   '5': 2,
#   '10': 1,
#   '1': 1,
#   '14': 1},
#  'Yu, Hongjie': {'0': 3,
#   '6': 1,
#   '5': 1,
#   '1': 4,
#   '4': 1,
#   '10': 2,
#   '19': 5,
#   '21': 2,
#   '9': 1,
#   '13': 1,
#   '12': 3,
#   '24': 1,
#   '18': 1,
#   '2': 1,
#   '8': 1,
#   '15': 1,
#   '14': 1,
#   '17': 1,
#   '27': 1,
#   '23': 1,
#   '16': 1},
#  'Simmons, Graham': {'8': 2,
#   '2': 4,
#   '6': 2,
#   '21': 1,
#   '7': 2,
#   '23': 1,
#   '4': 3,
#   '17': 1,
#   '0': 6,
#   '5': 1,
#   '12': 2,
#   '1': 4,
#   '15': 1,
#   '9': 1,
#   '10': 2,
#   '3': 1},
#  'Zhou, Jie': {'3': 5,
#   '0': 6,
#   '10': 1,
#   '6': 2,
#   '2': 2,
#   '1': 7,
#   '9': 1,
#   '5': 3,
#   '18': 1,
#   '13': 1,
#   '12': 2,
#   '21': 1,
#   '4': 1,
#   '8': 1},
#  'Griffin, Diane E.': {'0': 5,
#   '2': 3,
#   '3': 2,
#   '5': 2,
#   '1': 16,
#   '4': 4,
#   '8': 2},
#  'Ren, Xiaofeng': {'0': 10,
#   '3': 3,
#   '11': 2,
#   '5': 5,
#   '4': 2,
#   '1': 4,
#   '8': 1,
#   '7': 2,
#   '9': 1,
#   '6': 1,
#   '10': 2,
#   '2': 1},
#  'Wu, Peng': {'2': 5,
#   '0': 6,
#   '4': 3,
#   '10': 2,
#   '8': 1,
#   '6': 2,
#   '7': 2,
#   '3': 2,
#   '1': 8,
#   '17': 1,
#   '11': 1,
#   '9': 1},
#  'Wang, Qian': {'4': 4,
#   '8': 1,
#   '2': 6,
#   '1': 4,
#   '3': 7,
#   '0': 2,
#   '5': 2,
#   '6': 3,
#   '16': 1,
#   '11': 1,
#   '7': 2,
#   '12': 1},
#  'de Groot, Raoul J.': {'4': 6,
#   '6': 4,
#   '9': 2,
#   '8': 2,
#   '0': 2,
#   '7': 1,
#   '5': 3,
#   '13': 1,
#   '12': 1,
#   '3': 6,
#   '11': 2,
#   '10': 1,
#   '14': 1,
#   '2': 1,
#   '19': 1},
#  'Kellam, Paul': {'13': 2,
#   '10': 4,
#   '28': 1,
#   '14': 1,
#   '11': 2,
#   '18': 1,
#   '5': 2,
#   '15': 3,
#   '4': 2,
#   '6': 5,
#   '33': 1,
#   '108': 1,
#   '8': 1,
#   '12': 2,
#   '2': 2,
#   '0': 2,
#   '3': 1,
#   '1': 1},
#  'Mesecar, Andrew D.': {'8': 2,
#   '2': 3,
#   '5': 4,
#   '4': 6,
#   '3': 6,
#   '11': 2,
#   '6': 2,
#   '1': 1,
#   '7': 2,
#   '0': 1,
#   '13': 2,
#   '12': 1,
#   '9': 2},
#  'Lee, Changhee': {'1': 15,
#   '3': 3,
#   '0': 6,
#   '6': 2,
#   '8': 1,
#   '2': 3,
#   '5': 1,
#   '10': 1,
#   '7': 1,
#   '9': 1},
#  'Chan, Jasper Fuk-Woo': {'2': 4,
#   '1': 5,
#   '0': 12,
#   '16': 2,
#   '13': 1,
#   '20': 2,
#   '9': 1,
#   '12': 1,
#   '7': 1,
#   '4': 1,
#   '10': 2,
#   '8': 1,
#   '25': 1},
#  'Weber, Friedemann': {'1': 5,
#   '4': 2,
#   '19': 1,
#   '3': 3,
#   '13': 1,
#   '5': 2,
#   '7': 5,
#   '0': 4,
#   '6': 4,
#   '2': 3,
#   '9': 1,
#   '8': 2},
#  'van Kuppeveld, Frank J. M.': {'4': 2,
#   '5': 5,
#   '9': 2,
#   '10': 3,
#   '2': 3,
#   '16': 1,
#   '8': 2,
#   '15': 2,
#   '6': 6,
#   '7': 4,
#   '14': 1,
#   '3': 1,
#   '19': 1},
#  'Yount, Boyd': {'3': 6, '4': 3, '1': 11, '58': 1, '2': 6, '0': 5, '5': 1},
#  'Liu, Jun': {'7': 2,
#   '3': 5,
#   '1': 5,
#   '4': 7,
#   '2': 2,
#   '26': 1,
#   '0': 5,
#   '8': 1,
#   '5': 1,
#   '6': 3,
#   '19': 1},
#  'Lu, Xiaoyan': {'1': 5,
#   '6': 2,
#   '2': 3,
#   '7': 3,
#   '10': 2,
#   '3': 5,
#   '5': 1,
#   '4': 3,
#   '20': 1,
#   '0': 3,
#   '106': 1,
#   '14': 1,
#   '36': 1,
#   '17': 1,
#   '34': 1},
#  'Wang, Yan': {'0': 6,
#   '1': 6,
#   '6': 2,
#   '3': 4,
#   '2': 4,
#   '11': 2,
#   '2247': 1,
#   '10': 1,
#   '8': 1,
#   '7': 1,
#   '16': 1,
#   '9': 2,
#   '4': 1,
#   '5': 1},
#  'Li, Li': {'2': 3,
#   '0': 9,
#   '5': 1,
#   '1': 8,
#   '4': 3,
#   '20': 1,
#   '3': 3,
#   '6': 3,
#   '8': 1,
#   '13': 1},
#  'Li, Hui': {'0': 7,
#   '2': 5,
#   '8': 2,
#   '7': 1,
#   '30': 1,
#   '4': 1,
#   '10': 1,
#   '45': 1,
#   '5': 2,
#   '6': 1,
#   '9': 1,
#   '33': 1,
#   '1': 5,
#   '36': 1,
#   '17': 1,
#   '12': 1,
#   '13': 1},
#  'Wang, Chen': {'0': 8,
#   '10': 1,
#   '6': 3,
#   '9': 2,
#   '8': 2,
#   '20': 1,
#   '15': 2,
#   '46': 1,
#   '4': 3,
#   '64': 1,
#   '2': 4,
#   '3': 2,
#   '7': 1,
#   '19': 1,
#   '14': 1},
#  'Corti, Davide': {'0': 6,
#   '4': 4,
#   '7': 3,
#   '3': 2,
#   '10': 3,
#   '19': 1,
#   '17': 1,
#   '1': 5,
#   '11': 2,
#   '6': 1,
#   '2': 1,
#   '16': 1,
#   '13': 1,
#   '5': 1,
#   '12': 1},
#  'Kuiken, Thijs': {'7': 3,
#   '8': 1,
#   '6': 6,
#   '32': 1,
#   '18': 1,
#   '9': 2,
#   '3': 2,
#   '2': 1,
#   '1': 5,
#   '0': 7,
#   '28': 1,
#   '11': 1,
#   '12': 1,
#   '22': 1},
#  'Wang, Ying': {'7': 1,
#   '4': 4,
#   '5': 3,
#   '19': 1,
#   '9': 2,
#   '16': 1,
#   '0': 6,
#   '1': 5,
#   '2': 3,
#   '6': 2,
#   '3': 2,
#   '2249': 1,
#   '25': 1,
#   '10': 1},
#  'Huang, Yong': {'1': 4,
#   '2': 4,
#   '5': 1,
#   '7': 3,
#   '0': 2,
#   '4': 2,
#   '9': 4,
#   '11': 1,
#   '8': 5,
#   '13': 1,
#   '6': 1,
#   '858': 1,
#   '3': 2,
#   '12': 1,
#   '32': 1},
#  'Wang, Qiuhong': {'1': 6,
#   '5': 5,
#   '2': 3,
#   '9': 4,
#   '8': 1,
#   '4': 5,
#   '7': 3,
#   '6': 1,
#   '10': 1,
#   '0': 2,
#   '3': 2},
#  'Chen, Qi': {'4': 4,
#   '1': 5,
#   '0': 7,
#   '5': 3,
#   '7': 2,
#   '12': 1,
#   '9': 2,
#   '2': 3,
#   '298': 1,
#   '3': 2,
#   '6': 1,
#   '10': 1,
#   '14': 1},
#  'Graham, Barney S.': {'0': 5,
#   '14': 2,
#   '11': 2,
#   '29': 1,
#   '7': 3,
#   '17': 1,
#   '2': 3,
#   '18': 1,
#   '15': 3,
#   '12': 1,
#   '4': 1,
#   '30': 1,
#   '25': 1,
#   '3': 1,
#   '10': 2,
#   '1': 1,
#   '8': 2,
#   '16': 1,
#   '6': 1},
#  'Almazán, Fernando': {'0': 9,
#   '4': 2,
#   '5': 4,
#   '3': 2,
#   '7': 1,
#   '8': 3,
#   '2': 6,
#   '1': 3,
#   '6': 3},
#  'Matsuyama, Shutoku': {'7': 2,
#   '1': 7,
#   '11': 2,
#   '3': 4,
#   '0': 8,
#   '4': 2,
#   '2': 5,
#   '9': 2,
#   '8': 1},
#  'Siddell, Stuart G.': {'3': 4,
#   '2': 6,
#   '8': 2,
#   '6': 2,
#   '4': 3,
#   '13': 1,
#   '9': 1,
#   '5': 6,
#   '1': 4,
#   '7': 1,
#   '0': 1,
#   '10': 1},
#  'Huang, Yi': {'0': 2,
#   '7': 3,
#   '8': 2,
#   '3': 9,
#   '1': 5,
#   '6': 3,
#   '4': 4,
#   '9': 1,
#   '5': 1,
#   '2': 2},
#  'Qi, Jianxun': {'5': 3,
#   '2': 7,
#   '6': 1,
#   '1': 6,
#   '4': 3,
#   '7': 2,
#   '8': 1,
#   '3': 5,
#   '19': 1,
#   '9': 1,
#   '13': 1,
#   '16': 1},
#  'DeDiego, Marta L.': {'8': 2,
#   '0': 7,
#   '1': 10,
#   '2': 2,
#   '3': 9,
#   '4': 1,
#   '5': 1},
#  'Hensley, Lisa E.': {'10': 1,
#   '7': 4,
#   '0': 1,
#   '3': 2,
#   '12': 1,
#   '4': 4,
#   '6': 4,
#   '11': 4,
#   '9': 1,
#   '21': 1,
#   '5': 2,
#   '16': 2,
#   '18': 1,
#   '1': 1,
#   '13': 1,
#   '8': 1,
#   '26': 1},
#  'Brouqui, Philippe': {'4': 5,
#   '6': 2,
#   '11': 4,
#   '5': 3,
#   '12': 1,
#   '8': 1,
#   '10': 1,
#   '3': 2,
#   '2': 4,
#   '1': 3,
#   '7': 1,
#   '16': 1,
#   '27': 1,
#   '9': 1,
#   '0': 1,
#   '15': 1},
#  'Mari, Viviana': {'1': 13,
#   '2': 5,
#   '7': 1,
#   '8': 1,
#   '4': 7,
#   '5': 1,
#   '3': 3,
#   '0': 1},
#  'Lipsitch, Marc': {'5': 2, '6': 1, '0': 14, '1': 4, '3': 4, '4': 2, '2': 5},
#  'Vuorinen, Tytti': {'3': 10,
#   '2': 9,
#   '4': 3,
#   '6': 2,
#   '11': 1,
#   '8': 3,
#   '1': 2,
#   '5': 2},
#  'Qin, Chuan': {'4': 1,
#   '7': 4,
#   '8': 2,
#   '9': 1,
#   '12': 1,
#   '21': 1,
#   '3': 3,
#   '24': 1,
#   '17': 1,
#   '15': 2,
#   '11': 3,
#   '14': 3,
#   '10': 3,
#   '5': 1,
#   '0': 2,
#   '2': 1,
#   '35': 1,
#   '6': 1},
#  'Lu, Shan': {'11': 1,
#   '1': 6,
#   '10': 3,
#   '0': 3,
#   '2': 2,
#   '6': 6,
#   '7': 2,
#   '3': 5,
#   '5': 1,
#   '8': 3},
#  'Chen, Honglin': {'2': 4,
#   '6': 4,
#   '3': 2,
#   '8': 4,
#   '5': 3,
#   '15': 2,
#   '14': 2,
#   '13': 2,
#   '18': 2,
#   '4': 2,
#   '10': 1,
#   '23': 1,
#   '9': 1,
#   '27': 1,
#   '1': 1},
#  'Chang, Kyeong-Ok': {'6': 3,
#   '4': 2,
#   '8': 2,
#   '0': 2,
#   '9': 3,
#   '7': 3,
#   '2': 5,
#   '5': 5,
#   '10': 3,
#   '12': 1,
#   '3': 2,
#   '1': 1},
#  'Shi, Hongyan': {'2': 11, '3': 6, '4': 4, '1': 6, '5': 3, '7': 1, '6': 1},
#  'Cao, Bin': {'9': 1,
#   '3': 5,
#   '4': 3,
#   '7': 4,
#   '5': 3,
#   '1': 4,
#   '13': 1,
#   '47': 1,
#   '0': 3,
#   '12': 1,
#   '8': 1,
#   '18': 2,
#   '28': 1,
#   '2': 2},
#  'Wang, Lili': {'6': 4,
#   '4': 5,
#   '5': 2,
#   '1': 5,
#   '3': 5,
#   '2': 4,
#   '0': 2,
#   '7': 3,
#   '12': 1,
#   '8': 1},
#  'Hohdatsu, Tsutomu': {'8': 3, '3': 8, '4': 6, '6': 3, '1': 4, '5': 4, '0': 4},
#  'Horzinek, Marian C.': {'0': 3,
#   '2': 8,
#   '1': 4,
#   '15': 6,
#   '3': 7,
#   '5': 2,
#   '4': 2},
#  'Parry, Jane': {'0': 32},
#  'Van Ranst, Marc': {'9': 2,
#   '8': 3,
#   '7': 8,
#   '35': 2,
#   '1': 1,
#   '4': 1,
#   '5': 7,
#   '6': 4,
#   '0': 1,
#   '3': 2},
#  'Bavari, Sina': {'9': 1,
#   '14': 3,
#   '8': 2,
#   '5': 1,
#   '2': 3,
#   '10': 3,
#   '4': 3,
#   '11': 2,
#   '61': 1,
#   '7': 3,
#   '19': 1,
#   '3': 2,
#   '1': 1,
#   '16': 1,
#   '6': 1,
#   '27': 2,
#   '15': 1},
#  'Domingo, Esteban': {'4': 3,
#   '6': 1,
#   '0': 19,
#   '2': 2,
#   '1': 4,
#   '11': 1,
#   '3': 1},
#  'Briese, Thomas': {'6': 2,
#   '0': 4,
#   '22': 1,
#   '8': 3,
#   '11': 2,
#   '3': 1,
#   '4': 1,
#   '1': 10,
#   '2': 2,
#   '16': 1,
#   '12': 1,
#   '7': 1,
#   '20': 1,
#   '28': 1},
#  'Jin, Qi': {'14': 1,
#   '9': 2,
#   '11': 3,
#   '3': 2,
#   '10': 3,
#   '13': 1,
#   '22': 1,
#   '24': 1,
#   '5': 1,
#   '7': 3,
#   '15': 2,
#   '12': 2,
#   '6': 2,
#   '8': 4,
#   '32': 1,
#   '16': 1,
#   '26': 1},
#  'Smits, Saskia L.': {'0': 11,
#   '1': 6,
#   '5': 1,
#   '6': 2,
#   '10': 1,
#   '7': 2,
#   '2': 3,
#   '4': 3,
#   '11': 1,
#   '9': 1},
#  'Hui, David S.': {'1': 2, '0': 19, '6': 4, '8': 1, '3': 2, '7': 1, '2': 2},
#  'Wang, Ming': {'0': 2,
#   '6': 2,
#   '15': 1,
#   '5': 4,
#   '7': 1,
#   '4': 6,
#   '2': 1,
#   '26': 1,
#   '1': 3,
#   '10': 1,
#   '9': 2,
#   '3': 4,
#   '8': 2,
#   '12': 1},
#  'Jung, Kwonil': {'0': 18, '2': 4, '1': 5, '6': 1, '4': 1, '3': 1, '7': 1},
#  'Chen, Jianfei': {'1': 6,
#   '0': 5,
#   '2': 8,
#   '5': 2,
#   '3': 5,
#   '4': 3,
#   '8': 1,
#   '6': 1},
#  'Bosch, Berend-Jan': {'12': 2,
#   '8': 3,
#   '14': 2,
#   '6': 3,
#   '10': 3,
#   '9': 3,
#   '2': 1,
#   '7': 3,
#   '4': 4,
#   '5': 4,
#   '16': 1,
#   '1': 1,
#   '18': 1},
#  'Zhang, Xuming': {'5': 1, '6': 1, '2': 8, '4': 1, '1': 11, '0': 6, '3': 3},
#  'De Clercq, Erik': {'6': 3,
#   '2': 2,
#   '0': 12,
#   '5': 2,
#   '17': 1,
#   '1': 4,
#   '9': 1,
#   '3': 2,
#   '4': 3,
#   '8': 1},
#  'Brian, David A.': {'2': 8, '1': 11, '3': 8, '5': 1, '4': 1, '6': 1, '0': 1},
#  'Zhang, Linqi': {'14': 3,
#   '9': 4,
#   '12': 3,
#   '10': 4,
#   '18': 1,
#   '6': 1,
#   '8': 2,
#   '2': 3,
#   '3': 2,
#   '0': 1,
#   '11': 1,
#   '24': 1,
#   '4': 1,
#   '1': 1,
#   '5': 2},
#  'Guo, Deyin': {'10': 6,
#   '13': 2,
#   '2': 5,
#   '11': 3,
#   '3': 2,
#   '4': 1,
#   '1': 2,
#   '5': 2,
#   '7': 1,
#   '14': 1,
#   '6': 2,
#   '8': 2,
#   '9': 1},
#  'Rambaut, Andrew': {'3': 2,
#   '1': 6,
#   '7': 1,
#   '17': 1,
#   '16': 1,
#   '2': 7,
#   '26': 1,
#   '104': 1,
#   '24': 1,
#   '4': 1,
#   '13': 2,
#   '8': 1,
#   '5': 2,
#   '20': 1,
#   '12': 1,
#   '19': 1},
#  'Hinton, David R.': {'2': 12, '1': 7, '4': 3, '3': 5, '6': 1, '5': 2},
#  'Williams, John V.': {'10': 3,
#   '0': 5,
#   '3': 2,
#   '1': 5,
#   '7': 3,
#   '8': 4,
#   '9': 1,
#   '2': 2,
#   '11': 2,
#   '6': 2,
#   '4': 1},
#  'Dermody, Terence S.': {'0': 1,
#   '5': 9,
#   '6': 3,
#   '2': 6,
#   '1': 5,
#   '7': 1,
#   '4': 2,
#   '3': 2,
#   '14': 1},
#  'Decroly, Etienne': {'6': 5,
#   '2': 3,
#   '8': 2,
#   '0': 4,
#   '13': 1,
#   '3': 3,
#   '1': 3,
#   '7': 1,
#   '5': 4,
#   '11': 2,
#   '4': 1,
#   '12': 1},
#  'Shi, Yi': {'6': 7,
#   '7': 2,
#   '12': 2,
#   '8': 2,
#   '2': 1,
#   '11': 1,
#   '13': 2,
#   '3': 2,
#   '0': 2,
#   '5': 2,
#   '16': 1,
#   '15': 1,
#   '1': 2,
#   '9': 1,
#   '10': 1,
#   '22': 1},
#  'Nagata, Noriyo': {'2': 5,
#   '3': 3,
#   '21': 1,
#   '10': 1,
#   '12': 2,
#   '6': 2,
#   '4': 1,
#   '40': 1,
#   '0': 4,
#   '13': 1,
#   '1': 3,
#   '9': 3,
#   '5': 2,
#   '7': 1},
#  'Osterhaus, Albert D.M.E.': {'5': 5,
#   '7': 9,
#   '6': 2,
#   '8': 2,
#   '4': 2,
#   '12': 1,
#   '2': 3,
#   '0': 1,
#   '1': 4,
#   '11': 1},
#  'Johnston, Sebastian L.': {'28': 1,
#   '14': 1,
#   '7': 1,
#   '1': 7,
#   '2': 6,
#   '3': 5,
#   '5': 4,
#   '10': 1,
#   '13': 2,
#   '15': 1,
#   '0': 1},
#  'The Lancet,': {'0': 30},
#  'Uyeki, Timothy M.': {'9': 1,
#   '3': 1,
#   '23': 1,
#   '8': 3,
#   '5': 1,
#   '28': 1,
#   '11': 2,
#   '0': 1,
#   '2': 5,
#   '7': 1,
#   '4': 1,
#   '10': 1,
#   '16': 1,
#   '21': 1,
#   '26': 1,
#   '12': 2,
#   '6': 2,
#   '55': 1,
#   '15': 1,
#   '22': 1},
#  'Tumpey, Terrence M.': {'4': 3,
#   '11': 2,
#   '9': 3,
#   '7': 3,
#   '2': 2,
#   '5': 5,
#   '6': 4,
#   '3': 3,
#   '12': 1,
#   '17': 1,
#   '10': 1,
#   '0': 1},
#  'Narayanan, Krishna': {'1': 9, '2': 3, '3': 4, '4': 4, '0': 8, '25': 1},
#  'Wang, Bin': {'3': 6,
#   '0': 5,
#   '1': 5,
#   '5': 3,
#   '4': 1,
#   '13': 1,
#   '6': 2,
#   '8': 1,
#   '10': 2,
#   '7': 2,
#   '9': 1},
#  'Booy, Robert': {'9': 4,
#   '11': 2,
#   '7': 2,
#   '3': 3,
#   '5': 2,
#   '17': 1,
#   '2': 3,
#   '6': 7,
#   '4': 2,
#   '8': 2,
#   '1': 1},
#  'Kaiser, Laurent': {'12': 2,
#   '8': 2,
#   '3': 1,
#   '1': 3,
#   '9': 3,
#   '21': 1,
#   '6': 1,
#   '0': 2,
#   '2': 3,
#   '5': 5,
#   '4': 1,
#   '11': 2,
#   '7': 2,
#   '19': 1},
#  'Shirato, Kazuya': {'3': 1, '0': 16, '2': 6, '1': 3, '8': 1, '5': 2},
#  'Silverman, Robert H.': {'4': 2,
#   '2': 4,
#   '5': 4,
#   '8': 5,
#   '17': 1,
#   '7': 2,
#   '12': 1,
#   '3': 4,
#   '6': 3,
#   '1': 1,
#   '0': 2},
#  'Rappuoli, Rino': {'2': 7,
#   '8': 1,
#   '1': 9,
#   '0': 6,
#   '7': 1,
#   '6': 1,
#   '12': 1,
#   '5': 1,
#   '9': 1,
#   '3': 1},
#  'Hayden, Frederick G.': {'5': 2,
#   '4': 2,
#   '10': 2,
#   '2': 7,
#   '26': 1,
#   '23': 1,
#   '0': 6,
#   '22': 1,
#   '28': 1,
#   '1': 4,
#   '61': 1,
#   '25': 1},
#  'Belák, Sándor': {'4': 4,
#   '2': 8,
#   '3': 3,
#   '10': 1,
#   '0': 3,
#   '1': 2,
#   '5': 4,
#   '7': 3,
#   '6': 1},
#  'Schols, Dominique': {'2': 13,
#   '1': 1,
#   '5': 2,
#   '3': 4,
#   '7': 2,
#   '4': 3,
#   '6': 2,
#   '8': 2},
#  'Corman, Victor Max': {'1': 7,
#   '2': 6,
#   '6': 2,
#   '5': 3,
#   '3': 2,
#   '8': 2,
#   '16': 1,
#   '24': 1,
#   '0': 4,
#   '4': 1},
#  'Zhang, Lei': {'0': 8,
#   '3': 2,
#   '7': 3,
#   '2': 3,
#   '8': 2,
#   '1': 2,
#   '5': 2,
#   '6': 3,
#   '16': 1,
#   '4': 1,
#   '9': 1,
#   '10': 1},
#  'de Wit, Emmie': {'1': 4,
#   '0': 9,
#   '5': 3,
#   '10': 1,
#   '9': 2,
#   '2': 4,
#   '11': 1,
#   '13': 1,
#   '6': 1,
#   '7': 1,
#   '8': 1,
#   '3': 1},
#  'Menachery, Vineet D.': {'1': 5,
#   '3': 3,
#   '0': 12,
#   '4': 2,
#   '7': 1,
#   '2': 3,
#   '5': 1,
#   '32': 1,
#   '14': 1},
#  'Yang, Qian': {'5': 4,
#   '4': 9,
#   '3': 10,
#   '2': 1,
#   '6': 2,
#   '2357': 1,
#   '0': 1,
#   '9': 1},
#  'Stohlman, S A': {'3': 7, '0': 6, '2': 4, '1': 7, '4': 1, '6': 2, '5': 2},
#  'Yuen, Kwok-yung': {'3': 1,
#   '9': 4,
#   '6': 1,
#   '11': 1,
#   '17': 1,
#   '10': 4,
#   '2': 2,
#   '13': 2,
#   '12': 2,
#   '14': 3,
#   '5': 1,
#   '8': 4,
#   '1': 2},
#  'Palacios, Gustavo': {'7': 2,
#   '17': 1,
#   '0': 3,
#   '4': 2,
#   '2': 3,
#   '1': 3,
#   '15': 4,
#   '22': 1,
#   '9': 4,
#   '8': 1,
#   '31': 1,
#   '12': 1,
#   '16': 1,
#   '28': 1},
#  'Zhu, Ying': {'13': 1,
#   '0': 5,
#   '8': 6,
#   '3': 3,
#   '4': 2,
#   '1': 1,
#   '2': 1,
#   '7': 2,
#   '9': 3,
#   '10': 2,
#   '5': 2},
#  'Yan, Jinghua': {'4': 1,
#   '7': 5,
#   '2': 1,
#   '14': 1,
#   '16': 3,
#   '12': 3,
#   '10': 2,
#   '6': 2,
#   '11': 2,
#   '9': 1,
#   '8': 2,
#   '13': 2,
#   '23': 1,
#   '5': 1,
#   '3': 1},
#  'Tang, Julian W.': {'0': 14,
#   '9': 1,
#   '2': 5,
#   '1': 4,
#   '3': 1,
#   '4': 1,
#   '5': 1,
#   '7': 1},
#  'Falsey, Ann R.': {'1': 2,
#   '0': 12,
#   '2': 6,
#   '4': 1,
#   '7': 2,
#   '10': 1,
#   '9': 1,
#   '5': 1,
#   '3': 1,
#   '6': 1},
#  'Xue, Chunyi': {'1': 5,
#   '5': 4,
#   '6': 7,
#   '9': 2,
#   '7': 1,
#   '8': 2,
#   '4': 3,
#   '3': 2,
#   '0': 1,
#   '2': 1},
#  'Tashiro, Masato': {'11': 2,
#   '14': 1,
#   '16': 1,
#   '7': 3,
#   '3': 2,
#   '8': 1,
#   '10': 3,
#   '2': 1,
#   '12': 2,
#   '27': 1,
#   '5': 5,
#   '9': 1,
#   '21': 1,
#   '6': 2,
#   '26': 1,
#   '24': 1},
#  'Li, Jing': {'3': 7,
#   '0': 6,
#   '7': 1,
#   '10': 2,
#   '1': 3,
#   '5': 1,
#   '6': 1,
#   '131': 1,
#   '308': 1,
#   '420': 1,
#   '601': 1,
#   '2286': 1,
#   '3570': 1,
#   '24': 1},
#  'Wang, Jie': {'3': 5,
#   '0': 4,
#   '5': 4,
#   '7': 3,
#   '2': 5,
#   '9': 1,
#   '4': 4,
#   '8': 1,
#   '1': 1},
#  'Kim, Yunjeong': {'2': 2, '0': 9, '1': 12, '3': 2, '7': 1, '6': 2},
#  'He, Qigai': {'7': 7,
#   '5': 2,
#   '8': 3,
#   '4': 1,
#   '6': 3,
#   '14': 1,
#   '1': 1,
#   '9': 1,
#   '3': 3,
#   '0': 3,
#   '2': 3},
#  'McCray, Paul B.': {'8': 2,
#   '3': 3,
#   '1': 3,
#   '12': 2,
#   '9': 3,
#   '7': 2,
#   '10': 2,
#   '6': 3,
#   '5': 3,
#   '4': 2,
#   '13': 1,
#   '0': 1,
#   '2': 1},
#  'Takano, Tomomi': {'7': 2, '0': 20, '2': 2, '1': 3, '3': 1},
#  'Spaan, W J': {'2': 10, '4': 6, '5': 3, '3': 5, '1': 2, '6': 2},
#  'Li, Wenhui': {'0': 7,
#   '5': 1,
#   '19': 1,
#   '4': 2,
#   '2': 5,
#   '12': 1,
#   '9': 1,
#   '6': 1,
#   '18': 1,
#   '1': 3,
#   '7': 2,
#   '10': 1,
#   '15': 1},
#  'Coutard, Bruno': {'4': 6,
#   '6': 4,
#   '1': 5,
#   '7': 2,
#   '5': 2,
#   '8': 1,
#   '2': 3,
#   '3': 2,
#   '9': 1,
#   '0': 1},
#  'Roberts, Anjeanette': {'0': 8, '7': 1, '1': 6, '3': 2, '2': 7, '5': 3},
#  'Liu, Yang': {'1': 5,
#   '5': 2,
#   '0': 9,
#   '2': 1,
#   '4': 2,
#   '6': 2,
#   '1256': 1,
#   '15': 1,
#   '3': 2,
#   '14': 1,
#   '20': 1},
#  'Casas, Inmaculada': {'8': 2,
#   '2': 2,
#   '7': 1,
#   '5': 4,
#   '6': 2,
#   '12': 1,
#   '4': 3,
#   '9': 1,
#   '29': 2,
#   '15': 1,
#   '18': 1,
#   '13': 2,
#   '3': 2,
#   '1': 2,
#   '0': 1},
#  'Hofmann-Lehmann, Regina': {'13': 1,
#   '11': 1,
#   '6': 5,
#   '8': 2,
#   '9': 5,
#   '7': 5,
#   '5': 1,
#   '38': 1,
#   '1': 2,
#   '3': 2,
#   '4': 1,
#   '0': 1},
#  'Lutz, Hans': {'14': 1,
#   '10': 5,
#   '7': 3,
#   '9': 4,
#   '6': 4,
#   '1': 1,
#   '11': 1,
#   '8': 2,
#   '4': 4,
#   '0': 1,
#   '5': 1},
#  'Liu, Ying': {'1': 3,
#   '2': 3,
#   '14': 1,
#   '0': 6,
#   '5': 2,
#   '3': 1,
#   '25': 1,
#   '8': 3,
#   '4': 5,
#   '17': 1,
#   '18': 1},
#  'Chen, Feng': {'8': 1,
#   '2': 6,
#   '3': 3,
#   '6': 3,
#   '1': 2,
#   '0': 5,
#   '15': 1,
#   '4': 3,
#   '7': 3},
#  'Parola, Philippe': {'7': 3,
#   '13': 2,
#   '0': 2,
#   '11': 1,
#   '10': 3,
#   '8': 2,
#   '12': 3,
#   '4': 2,
#   '2': 3,
#   '9': 3,
#   '3': 1,
#   '5': 1,
#   '1': 1},
#  'Cao, Yongchang': {'7': 5, '8': 5, '5': 6, '4': 4, '9': 4, '6': 3},
#  'Xia, Xianzhu': {'7': 1,
#   '14': 1,
#   '9': 4,
#   '11': 4,
#   '12': 2,
#   '28': 1,
#   '8': 1,
#   '18': 1,
#   '13': 2,
#   '16': 2,
#   '20': 2,
#   '17': 1,
#   '10': 1,
#   '6': 1,
#   '19': 1,
#   '3': 1,
#   '5': 1},
#  'Machamer, Carolyn E.': {'1': 15, '0': 4, '2': 7, '3': 1},
#  'Ren, Lili': {'3': 5,
#   '8': 4,
#   '0': 6,
#   '13': 1,
#   '4': 3,
#   '2': 4,
#   '5': 1,
#   '1': 1,
#   '7': 1,
#   '17': 1},
#  'Fang, Ying': {'0': 5,
#   '5': 4,
#   '14': 1,
#   '4': 4,
#   '7': 1,
#   '8': 1,
#   '2': 2,
#   '3': 4,
#   '9': 2,
#   '13': 1,
#   '1': 1,
#   '6': 1},
#  'Cho, Kyoung-Oh': {'15': 2,
#   '14': 2,
#   '13': 2,
#   '16': 2,
#   '11': 5,
#   '8': 2,
#   '10': 2,
#   '9': 2,
#   '7': 5,
#   '4': 1,
#   '12': 1,
#   '2': 1},
#  'Chu, Hin': {'2': 3,
#   '4': 3,
#   '1': 7,
#   '3': 4,
#   '12': 3,
#   '5': 1,
#   '0': 4,
#   '13': 1,
#   '11': 1},
#  'Wu, Ying': {'0': 2,
#   '4': 4,
#   '5': 3,
#   '27': 1,
#   '8': 3,
#   '15': 1,
#   '9': 3,
#   '7': 2,
#   '10': 1,
#   '1': 2,
#   '29': 1,
#   '6': 3,
#   '3': 1},
#  'Hasegawa, Hideki': {'9': 1,
#   '8': 3,
#   '44': 1,
#   '16': 1,
#   '2': 4,
#   '1': 3,
#   '31': 1,
#   '11': 2,
#   '5': 1,
#   '6': 4,
#   '3': 3,
#   '19': 1,
#   '4': 2},
#  'Yang, Xing-Lou': {'2': 5,
#   '1': 3,
#   '9': 3,
#   '6': 2,
#   '22': 1,
#   '7': 2,
#   '8': 2,
#   '3': 2,
#   '5': 3,
#   '11': 1,
#   '0': 2,
#   '4': 1},
#  'Wang, Hua': {'4': 3,
#   '5': 4,
#   '14': 2,
#   '9': 3,
#   '6': 1,
#   '8': 5,
#   '2': 3,
#   '10': 2,
#   '3': 1,
#   '0': 1,
#   '13': 1},
#  'Jiang, Hualiang': {'9': 4,
#   '7': 2,
#   '14': 2,
#   '5': 6,
#   '11': 2,
#   '4': 2,
#   '19': 1,
#   '8': 1,
#   '3': 1,
#   '22': 1,
#   '13': 2,
#   '10': 1,
#   '12': 1},
#  'Freymuth, François': {'6': 7,
#   '11': 1,
#   '8': 3,
#   '7': 5,
#   '5': 2,
#   '4': 2,
#   '0': 4,
#   '2': 1,
#   '10': 1},
#  'Chen, Zhiwei': {'13': 1,
#   '10': 2,
#   '5': 2,
#   '1': 2,
#   '6': 3,
#   '14': 1,
#   '9': 4,
#   '4': 3,
#   '12': 2,
#   '18': 1,
#   '0': 2,
#   '22': 1,
#   '7': 1,
#   '8': 1},
#  'Dinman, Jonathan D.': {'3': 5,
#   '2': 2,
#   '4': 4,
#   '0': 4,
#   '9': 2,
#   '1': 6,
#   '5': 2,
#   '7': 1},
#  'Torres, Jaume': {'0': 4,
#   '9': 2,
#   '3': 3,
#   '8': 2,
#   '1': 3,
#   '4': 4,
#   '2': 3,
#   '11': 1,
#   '6': 2,
#   '7': 1,
#   '5': 1},
#  'Nabel, Gary J.': {'7': 5,
#   '14': 2,
#   '12': 2,
#   '10': 1,
#   '8': 2,
#   '11': 2,
#   '6': 5,
#   '3': 2,
#   '18': 1,
#   '13': 1,
#   '1': 2,
#   '5': 1},
#  'Marasco, Wayne A.': {'8': 3,
#   '15': 1,
#   '18': 1,
#   '25': 1,
#   '7': 2,
#   '3': 1,
#   '6': 4,
#   '14': 1,
#   '16': 1,
#   '11': 1,
#   '9': 1,
#   '13': 2,
#   '5': 2,
#   '21': 1,
#   '2': 1,
#   '4': 1,
#   '28': 1,
#   '12': 1},
#  'Seale, Holly': {'0': 3, '3': 5, '4': 1, '1': 8, '2': 7, '5': 1, '7': 1},
#  'Firth, Andrew E.': {'1': 5,
#   '0': 5,
#   '2': 1,
#   '13': 1,
#   '3': 4,
#   '7': 1,
#   '9': 1,
#   '5': 3,
#   '6': 1,
#   '4': 1,
#   '10': 3},
#  'Rockx, Barry': {'0': 8,
#   '1': 4,
#   '4': 2,
#   '8': 5,
#   '6': 4,
#   '3': 1,
#   '5': 1,
#   '2': 1},
#  'Sung, Joseph J.Y.': {'9': 4,
#   '17': 1,
#   '6': 5,
#   '7': 3,
#   '1': 3,
#   '8': 3,
#   '3': 1,
#   '5': 1,
#   '16': 1,
#   '10': 1,
#   '2': 1,
#   '12': 1,
#   '4': 1},
#  'Zhou, Lei': {'5': 4,
#   '8': 2,
#   '2': 2,
#   '1': 4,
#   '3': 3,
#   '6': 3,
#   '4': 4,
#   '7': 3,
#   '0': 1},
#  'Chen, Gang': {'1': 4,
#   '0': 4,
#   '7': 1,
#   '2': 2,
#   '8': 2,
#   '10': 2,
#   '26': 1,
#   '24': 1,
#   '17': 2,
#   '12': 1,
#   '289': 1,
#   '4': 2,
#   '41': 1,
#   '6': 1,
#   '5': 1},
#  'Zhang, Jie': {'0': 4, '8': 2, '1': 13, '2': 2, '3': 1, '5': 2, '6': 2},
#  'Morita, Kouichi': {'4': 4,
#   '12': 3,
#   '6': 3,
#   '5': 3,
#   '9': 2,
#   '8': 3,
#   '11': 1,
#   '7': 3,
#   '3': 2,
#   '24': 1,
#   '10': 1},
#  'Yang, Peng': {'4': 4,
#   '1': 2,
#   '0': 4,
#   '6': 3,
#   '5': 3,
#   '9': 2,
#   '7': 1,
#   '3': 2,
#   '11': 1,
#   '16': 1,
#   '2': 2,
#   '8': 1},
#  'Marzi, Andrea': {'2': 5,
#   '0': 3,
#   '1': 7,
#   '3': 6,
#   '10': 1,
#   '8': 2,
#   '6': 1,
#   '4': 1},
#  'Xu, Wei': {'3': 4,
#   '0': 3,
#   '6': 5,
#   '4': 5,
#   '1': 3,
#   '5': 1,
#   '2': 3,
#   '10': 1,
#   '8': 1},
#  'Wang, Quanyi': {'11': 3,
#   '14': 1,
#   '8': 4,
#   '7': 3,
#   '3': 4,
#   '1': 2,
#   '28': 1,
#   '10': 1,
#   '15': 1,
#   '9': 4,
#   '2': 1,
#   '4': 1},
#  'Zaki, Sherif R.': {'6': 2,
#   '9': 2,
#   '17': 1,
#   '7': 4,
#   '4': 1,
#   '8': 2,
#   '10': 1,
#   '5': 1,
#   '27': 1,
#   '11': 2,
#   '0': 3,
#   '1': 1,
#   '3': 2,
#   '2': 1,
# ...
#   '5': 1,
#   '1': 2,
#   '7': 1,
#   '3': 2,
#   '9': 1,
#   '0': 7,
#   '6': 1},
#  'Ding, Chan': {'9': 2,
#   '8': 4,
#   '1': 1,
#   '5': 1,
#   '6': 1,
#   '2': 1,
#   '11': 1,
#   '12': 1,
#   '13': 1,
#   '496': 1,
#   '10': 2},
#  'Xu, Lei': {'5': 1, '2': 2, '3': 3, '1': 3, '4': 3, '0': 2, '7': 1, '19': 1},
#  'Ratia, Kiira': {'0': 4, '2': 4, '3': 3, '5': 1, '1': 3, '4': 1},
#  'Li, Fei': {'1': 3, '2': 3, '0': 7, '17': 1, '4': 1, '5': 1},
#  'Chou, Chi-Yuan': {'7': 3,
#   '5': 1,
#   '2': 2,
#   '6': 3,
#   '4': 1,
#   '0': 3,
#   '1': 2,
#   '3': 1},
#  'López, Susana': {'18': 1,
#   '10': 1,
#   '21': 1,
#   '2': 4,
#   '6': 1,
#   '9': 1,
#   '3': 5,
#   '8': 1,
#   '7': 1},
#  'Lin, Tsang Long': {'2': 8, '4': 2, '5': 2, '7': 1, '1': 1, '3': 1, '0': 1},
#  'Shi, Lei': {'2': 2, '4': 2, '1': 3, '3': 4, '6': 1, '5': 3, '0': 1},
#  'Liu, Jie': {'8': 1,
#   '4': 3,
#   '6': 2,
#   '13': 1,
#   '0': 1,
#   '11': 1,
#   '1': 3,
#   '3': 2,
#   '21': 1,
#   '2': 1},
#  'Fung, To Sing': {'4': 1, '0': 7, '5': 2, '2': 2, '1': 4},
#  'Murtaugh, Michael P.': {'6': 2,
#   '5': 2,
#   '1': 2,
#   '3': 1,
#   '2': 7,
#   '0': 1,
#   '10': 1},
#  'Chappell, James D.': {'5': 3,
#   '7': 2,
#   '10': 1,
#   '2': 1,
#   '13': 3,
#   '14': 2,
#   '4': 2,
#   '3': 1,
#   '0': 1},
#  'Fu, Zhen F.': {'9': 2,
#   '8': 4,
#   '7': 3,
#   '4': 2,
#   '5': 1,
#   '11': 1,
#   '6': 2,
#   '2': 1},
#  'Xiao, Gengfu': {'5': 4,
#   '6': 2,
#   '10': 1,
#   '1': 3,
#   '8': 2,
#   '3': 1,
#   '4': 1,
#   '9': 2},
#  'Collisson, Ellen W.': {'1': 4,
#   '5': 1,
#   '2': 3,
#   '3': 4,
#   '0': 1,
#   '4': 2,
#   '8': 1},
#  'Spaan, Willy J. M.': {'7': 1,
#   '4': 2,
#   '3': 3,
#   '2': 6,
#   '1': 2,
#   '5': 1,
#   '0': 1},
#  'Pewe, Lecia': {'4': 2, '0': 4, '1': 7, '2': 3},
#  'Horzinek, M.C.': {'1': 5, '2': 3, '5': 2, '7': 1, '3': 5},
#  'Lappin, Michael R.': {'1': 4, '2': 3, '0': 7, '3': 1, '4': 1},
#  'Ye, Young Min': {'274': 1,
#   '281': 1,
#   '290': 1,
#   '301': 1,
#   '332': 1,
#   '866': 1,
#   '873': 1,
#   '1114': 1,
#   '1164': 1,
#   '1213': 1,
#   '1250': 1,
#   '1297': 1,
#   '1476': 1,
#   '2689': 1,
#   '3480': 1,
#   '3511': 1},
#  'Cunha, Burke A.': {'0': 15, '2': 1},
#  'Murphy, Frederick A.': {'0': 4, '2': 12},
#  'Ooi, Eng Eong': {'9': 1,
#   '0': 1,
#   '8': 2,
#   '1': 1,
#   '2': 2,
#   '3': 4,
#   '5': 1,
#   '6': 2,
#   '16': 1},
#  'Ferron, François': {'6': 1, '3': 3, '2': 4, '0': 4, '1': 2, '5': 1},
#  'Wang, Zheng': {'2': 4,
#   '0': 1,
#   '12': 1,
#   '4': 3,
#   '5': 1,
#   '8': 1,
#   '1': 2,
#   '6': 1,
#   '3': 1},
#  'Donaldson, Eric': {'11': 2, '1': 3, '4': 2, '2': 5, '3': 1, '6': 2},
#  'Metzgar, David': {'10': 1,
#   '21': 1,
#   '0': 2,
#   '1': 4,
#   '5': 1,
#   '8': 1,
#   '12': 1,
#   '6': 3,
#   '3': 1},
#  'Colizza, Vittoria': {'0': 2,
#   '2': 2,
#   '8': 2,
#   '5': 2,
#   '4': 1,
#   '1': 2,
#   '6': 1,
#   '7': 1,
#   '11': 1,
#   '12': 1},
#  'Ghedin, Elodie': {'9': 3,
#   '6': 2,
#   '7': 3,
#   '2': 1,
#   '0': 1,
#   '3': 1,
#   '1': 2,
#   '5': 1,
#   '8': 1},
#  'Wallinga, Jacco': {'9': 1,
#   '7': 1,
#   '2': 5,
#   '20': 1,
#   '4': 1,
#   '1': 1,
#   '5': 1,
#   '3': 2,
#   '0': 2},
#  'Chen, Xin': {'11': 1,
#   '2': 2,
#   '0': 4,
#   '3': 1,
#   '13': 1,
#   '7': 3,
#   '4': 1,
#   '6': 1,
#   '8': 1},
#  'Ransohoff, Richard M.': {'2': 3,
#   '4': 4,
#   '8': 1,
#   '0': 1,
#   '11': 1,
#   '3': 1,
#   '5': 2,
#   '6': 1,
#   '1': 1},
#  'Zeng, Fanya': {'6': 1, '5': 6, '2': 3, '1': 1, '0': 2, '3': 1, '4': 1},
#  'Burton, Dennis R.': {'10': 1,
#   '9': 1,
#   '15': 1,
#   '4': 2,
#   '22': 1,
#   '17': 1,
#   '1': 2,
#   '19': 1,
#   '3': 1,
#   '0': 2,
#   '8': 2},
#  'Rupprecht, Charles E.': {'4': 2,
#   '11': 2,
#   '12': 1,
#   '9': 2,
#   '14': 1,
#   '8': 2,
#   '7': 1,
#   '3': 1,
#   '24': 1,
#   '31': 1,
#   '2': 1},
#  'Kamitani, Wataru': {'3': 3,
#   '0': 2,
#   '5': 3,
#   '4': 1,
#   '6': 3,
#   '1': 1,
#   '2': 1,
#   '8': 1},
#  'Tam, James P.': {'4': 2, '3': 3, '2': 6, '1': 2, '6': 2},
#  'Allander, Tobias': {'2': 3, '6': 1, '8': 3, '7': 1, '12': 1, '3': 4, '0': 2},
#  'Spiropoulou, Christina F.': {'7': 2,
#   '2': 2,
#   '16': 1,
#   '57': 1,
#   '10': 1,
#   '9': 1,
#   '6': 2,
#   '12': 1,
#   '5': 1,
#   '8': 1,
#   '0': 1,
#   '3': 1},
#  'Li, Gang': {'7': 2,
#   '1': 2,
#   '3': 3,
#   '0': 2,
#   '4': 3,
#   '6': 1,
#   '22': 1,
#   '30': 1},
#  'Korth, Marcus J.': {'9': 1,
#   '7': 1,
#   '5': 1,
#   '6': 1,
#   '1': 4,
#   '4': 2,
#   '13': 1,
#   '3': 2,
#   '0': 2},
#  'Weiss, Robin A.': {'9': 1,
#   '24': 1,
#   '5': 1,
#   '6': 2,
#   '0': 3,
#   '10': 2,
#   '7': 1,
#   '8': 1,
#   '4': 1,
#   '1': 1,
#   '2': 1},
#  'Beauchemin, Nicole': {'3': 4,
#   '23': 2,
#   '5': 3,
#   '13': 1,
#   '12': 1,
#   '8': 1,
#   '2': 1,
#   '20': 1,
#   '4': 1},
#  'Hashem, Anwar M.': {'0': 4, '1': 4, '2': 3, '9': 1, '7': 1, '11': 2},
#  'Rello, Jordi': {'3': 2,
#   '28': 1,
#   '2': 4,
#   '14': 1,
#   '11': 1,
#   '9': 1,
#   '1': 1,
#   '0': 2,
#   '5': 1,
#   '202': 1},
#  'van den Brand, Judith M. A.': {'2': 1,
#   '0': 4,
#   '5': 1,
#   '8': 2,
#   '11': 2,
#   '3': 2,
#   '1': 2,
#   '6': 1},
#  'Oppong, Samuel': {'1': 1,
#   '7': 3,
#   '10': 4,
#   '16': 1,
#   '11': 2,
#   '21': 1,
#   '14': 1,
#   '8': 1,
#   '12': 1},
#  'Cui, Jie': {'0': 4,
#   '2': 3,
#   '1': 1,
#   '3': 3,
#   '4': 1,
#   '5': 1,
#   '10': 1,
#   '15': 1},
#  'Schountz, Tony': {'0': 5,
#   '11': 1,
#   '5': 1,
#   '6': 2,
#   '10': 1,
#   '4': 1,
#   '2': 2,
#   '3': 1,
#   '1': 1},
#  'Campbell, Angela P.': {'0': 3,
#   '1': 4,
#   '2': 2,
#   '5': 2,
#   '3': 2,
#   '6': 1,
#   '4': 1},
#  'Rolain, Jean-Marc': {'2': 3,
#   '3': 3,
#   '6': 1,
#   '4': 1,
#   '15': 1,
#   '26': 1,
#   '1': 4,
#   '0': 1},
#  'Lina, Bruno': {'11': 2,
#   '9': 2,
#   '26': 2,
#   '8': 2,
#   '1': 2,
#   '4': 3,
#   '20': 1,
#   '6': 1},
#  'Guo, Li': {'1': 1,
#   '2': 3,
#   '0': 2,
#   '6': 2,
#   '58': 1,
#   '4': 2,
#   '10': 2,
#   '21': 1,
#   '5': 1},
#  'Zhu, Heng': {'4': 2,
#   '0': 3,
#   '3': 1,
#   '6': 1,
#   '12': 2,
#   '11': 1,
#   '2': 1,
#   '13': 1,
#   '8': 1,
#   '1': 1,
#   '22': 1},
#  'Olinger, Gene G.': {'13': 1,
#   '6': 4,
#   '21': 1,
#   '20': 1,
#   '10': 2,
#   '22': 1,
#   '4': 1,
#   '15': 1,
#   '14': 1,
#   '7': 1,
#   '24': 1},
#  'Basler, Christopher F.': {'3': 2,
#   '0': 1,
#   '7': 3,
#   '11': 1,
#   '4': 1,
#   '6': 2,
#   '2': 3,
#   '1': 2},
#  'Wang, Chao': {'5': 2, '9': 2, '7': 2, '1': 2, '0': 4, '2': 2, '6': 1},
#  'Ma, Jingyun': {'9': 1,
#   '7': 5,
#   '10': 1,
#   '6': 1,
#   '5': 3,
#   '11': 1,
#   '8': 2,
#   '12': 1},
#  'Lal, Sunil K.': {'9': 2,
#   '10': 2,
#   '4': 2,
#   '1': 3,
#   '2': 1,
#   '13': 1,
#   '7': 1,
#   '5': 1,
#   '12': 1,
#   '6': 1},
#  'Gao, George F': {'10': 1,
#   '12': 1,
#   '1': 2,
#   '20': 1,
#   '13': 1,
#   '25': 1,
#   '9': 1,
#   '6': 2,
#   '3': 3,
#   '30': 1,
#   '11': 1},
#  'Simonsen, Lone': {'4': 1, '5': 1, '1': 5, '0': 2, '2': 6},
#  'Zevenhoven-Dobbe, Jessika C.': {'1': 3,
#   '2': 6,
#   '4': 1,
#   '0': 1,
#   '3': 3,
#   '5': 1},
#  'Walker, Peter J.': {'3': 4,
#   '0': 2,
#   '21': 1,
#   '4': 1,
#   '11': 2,
#   '7': 1,
#   '9': 1,
#   '6': 1,
#   '1': 1,
#   '5': 1},
#  'Sun, Ying': {'12': 2,
#   '7': 1,
#   '5': 1,
#   '4': 3,
#   '0': 3,
#   '2': 2,
#   '8': 1,
#   '1': 1,
#   '3': 1},
#  'Kao, C. Cheng': {'9': 1, '7': 2, '3': 5, '2': 1, '4': 3, '6': 2, '8': 1},
#  'Kindrachuk, Jason': {'4': 4, '7': 1, '2': 3, '0': 4, '1': 2, '5': 1},
#  'Cunningham, Andrew A.': {'10': 1,
#   '18': 1,
#   '2': 2,
#   '1': 1,
#   '8': 1,
#   '4': 2,
#   '0': 2,
#   '9': 2,
#   '3': 1,
#   '5': 1,
#   '13': 1},
#  'Wu, Jianhong': {'3': 4,
#   '2': 3,
#   '5': 2,
#   '4': 1,
#   '6': 2,
#   '10': 1,
#   '8': 1,
#   '1': 1},
#  'Campolo, Marco': {'4': 2, '2': 3, '3': 6, '5': 2, '1': 2},
#  'Tempesta, Maria': {'7': 3, '8': 3, '6': 2, '5': 2, '10': 3, '12': 1, '3': 1},
#  'Sutter, Gerd': {'8': 2,
#   '6': 1,
#   '9': 1,
#   '7': 1,
#   '3': 2,
#   '5': 1,
#   '4': 2,
#   '10': 1,
#   '2': 2,
#   '22': 1,
#   '1': 1},
#  'Nokes, D. James': {'11': 3,
#   '10': 1,
#   '5': 4,
#   '6': 1,
#   '7': 3,
#   '12': 1,
#   '4': 1,
#   '8': 1},
#  'Wen, Jie': {'15': 2,
#   '10': 1,
#   '1': 3,
#   '13': 1,
#   '9': 2,
#   '8': 1,
#   '6': 1,
#   '5': 3,
#   '4': 1},
#  'Caffrey, Michael': {'2': 3,
#   '4': 2,
#   '5': 3,
#   '8': 1,
#   '6': 1,
#   '13': 1,
#   '3': 2,
#   '0': 1,
#   '7': 1},
#  'Christian, Michael D.': {'0': 7,
#   '2': 1,
#   '8': 1,
#   '1': 2,
#   '22': 1,
#   '5': 2,
#   '12': 1},
#  'Feikin, Daniel R.': {'3': 1,
#   '16': 1,
#   '6': 2,
#   '8': 3,
#   '24': 1,
#   '0': 2,
#   '21': 1,
#   '17': 1,
#   '12': 1,
#   '10': 1,
#   '9': 1},
#  'Chen, Yee-Chun': {'3': 5, '0': 4, '2': 1, '4': 2, '1': 1, '10': 1, '5': 1},
#  'Zhang, Zheng': {'1': 3,
#   '0': 3,
#   '21': 2,
#   '4': 1,
#   '5': 1,
#   '9': 1,
#   '3': 1,
#   '11': 1,
#   '8': 1,
#   '10': 1},
#  'Chang, Hui-Wen': {'0': 3, '1': 3, '9': 1, '3': 2, '8': 5, '4': 1},
#  'Morand, Serge': {'1': 5,
#   '9': 2,
#   '3': 1,
#   '6': 1,
#   '2': 1,
#   '4': 1,
#   '0': 3,
#   '5': 1},
#  'Li, Lin': {'3': 3, '4': 2, '6': 2, '5': 1, '1': 3, '2': 3, '0': 1},
#  'Xu, Lin': {'0': 5, '12': 1, '2': 4, '6': 2, '16': 1, '5': 1, '11': 1},
#  'Zhang, Jun': {'2': 1,
#   '1': 3,
#   '8': 1,
#   '13': 1,
#   '3': 3,
#   '5': 2,
#   '4': 1,
#   '0': 2,
#   '7': 1},
#  'Uversky, Vladimir N.': {'2': 4, '3': 9, '6': 1, '0': 1},
#  'Park, Jun-Gyu': {'2': 4, '0': 2, '5': 4, '4': 3, '1': 1, '3': 1},
#  'Park, Sang-Ik': {'13': 2,
#   '9': 2,
#   '7': 1,
#   '1': 4,
#   '8': 1,
#   '0': 3,
#   '10': 1,
#   '2': 1},
#  'Zhang, Ying': {'5': 1,
#   '0': 5,
#   '6': 2,
#   '4': 1,
#   '2': 3,
#   '12': 1,
#   '8': 1,
#   '7': 1},
#  'Kim, Woo Joo': {'14': 1,
#   '13': 1,
#   '7': 4,
#   '6': 2,
#   '10': 1,
#   '22': 1,
#   '1': 2,
#   '18': 1,
#   '5': 1,
#   '8': 1},
#  'Schnell, Matthias J.': {'9': 4,
#   '6': 2,
#   '11': 1,
#   '5': 2,
#   '4': 2,
#   '1': 1,
#   '3': 2,
#   '8': 1},
#  'Chen, Ling': {'13': 1,
#   '18': 1,
#   '17': 1,
#   '26': 1,
#   '25': 1,
#   '12': 1,
#   '9': 1,
#   '5': 1,
#   '19': 1,
#   '0': 2,
#   '10': 1,
#   '2': 1,
#   '14': 1,
#   '6': 1},
#  'Shi, Xuanling': {'1': 1,
#   '13': 1,
#   '9': 3,
#   '4': 3,
#   '5': 2,
#   '17': 1,
#   '20': 1,
#   '6': 1,
#   '2': 1,
#   '10': 1},
#  'Pietschmann, Thomas': {'7': 2,
#   '2': 2,
#   '23': 1,
#   '15': 1,
#   '10': 1,
#   '8': 1,
#   '13': 1,
#   '11': 1,
#   '17': 1,
#   '6': 1,
#   '4': 1,
#   '1': 1,
#   '12': 1},
#  'Ghosh, Arun K.': {'6': 3, '13': 1, '0': 7, '9': 2, '11': 1, '4': 1},
#  'Johnson, Michael E.': {'7': 3,
#   '10': 3,
#   '4': 1,
#   '12': 1,
#   '9': 1,
#   '2': 1,
#   '0': 1,
#   '5': 2,
#   '8': 2},
#  'Li, Xin': {'5': 2, '1': 5, '3': 2, '13': 1, '7': 1, '0': 3, '12': 1},
#  'Scagnolari, Carolina': {'0': 4,
#   '6': 3,
#   '4': 1,
#   '1': 3,
#   '5': 2,
#   '9': 1,
#   '3': 1},
#  'Antonelli, Guido': {'5': 2, '10': 3, '7': 2, '8': 2, '6': 3, '0': 2, '1': 1},
#  'Maeurer, Markus': {'13': 1,
#   '7': 3,
#   '8': 3,
#   '4': 3,
#   '3': 1,
#   '5': 1,
#   '2': 1,
#   '15': 1,
#   '12': 1},
#  'Wang, Yanqun': {'4': 1, '3': 1, '1': 3, '0': 7, '14': 1, '8': 1, '7': 1},
#  'Dhama, Kuldeep': {'5': 2,
#   '2': 1,
#   '10': 1,
#   '3': 2,
#   '7': 2,
#   '1': 1,
#   '0': 1,
#   '6': 3,
#   '19': 1,
#   '4': 1},
#  'Chen, Ying': {'7': 1,
#   '4': 1,
#   '8': 1,
#   '10': 1,
#   '1': 3,
#   '0': 3,
#   '5': 2,
#   '16': 1,
#   '12': 1,
#   '2': 1},
#  'Wang, Denong': {'0': 9, '16': 1, '1': 2, '3': 3},
#  'Funk, Sebastian': {'1': 4,
#   '6': 1,
#   '7': 2,
#   '0': 2,
#   '9': 2,
#   '2': 1,
#   '3': 1,
#   '21': 1,
#   '5': 1},
#  'Cheng, Vincent C. C.': {'13': 1,
#   '9': 2,
#   '7': 1,
#   '21': 1,
#   '10': 2,
#   '8': 1,
#   '5': 1,
#   '2': 1,
#   '6': 1,
#   '3': 1,
#   '0': 3},
#  'Huang, Fang': {'2': 5,
#   '8': 1,
#   '7': 3,
#   '21': 1,
#   '9': 1,
#   '4': 2,
#   '1': 1,
#   '6': 1},
#  'Kuba, Keiji': {'12': 1,
#   '6': 2,
#   '21': 1,
#   '0': 4,
#   '1': 4,
#   '14': 1,
#   '2': 1,
#   '10': 1},
#  'Ward, Andrew B.': {'14': 2,
#   '9': 3,
#   '0': 1,
#   '12': 1,
#   '18': 1,
#   '1': 2,
#   '2': 1,
#   '16': 1,
#   '25': 1,
#   '15': 1,
#   '31': 1},
#  'Modjarrad, Kayvon': {'3': 1,
#   '18': 1,
#   '5': 1,
#   '0': 6,
#   '10': 1,
#   '2': 3,
#   '19': 1,
#   '1': 1},
#  'Sun, Dongbo': {'13': 2,
#   '9': 1,
#   '2': 1,
#   '3': 4,
#   '0': 4,
#   '6': 1,
#   '12': 1,
#   '5': 1},
#  'Abedi, Glen R.': {'6': 2,
#   '3': 3,
#   '1': 4,
#   '5': 1,
#   '2': 2,
#   '8': 1,
#   '4': 1,
#   '0': 1},
#  'Zhang, Lin': {'1': 2,
#   '26': 1,
#   '2': 2,
#   '4': 1,
#   '2423': 1,
#   '2424': 1,
#   '3': 2,
#   '6': 1,
#   '17': 1,
#   '5': 1,
#   '10': 1,
#   '8': 1},
#  'Zhang, Gaiping': {'10': 3,
#   '5': 1,
#   '6': 4,
#   '12': 1,
#   '9': 2,
#   '8': 1,
#   '2': 1,
#   '3': 1,
#   '11': 1},
#  'Lazartigues, Eric': {'4': 1,
#   '7': 2,
#   '3': 3,
#   '2': 3,
#   '0': 1,
#   '5': 2,
#   '6': 1,
#   '1': 2},
#  'Ki, Chang-Seok': {'5': 3,
#   '0': 1,
#   '1': 2,
#   '4': 1,
#   '2': 1,
#   '10': 2,
#   '15': 1,
#   '7': 1,
#   '14': 1,
#   '8': 1,
#   '3': 1},
#  'Jain, Seema': {'12': 5,
#   '6': 1,
#   '14': 1,
#   '16': 1,
#   '11': 2,
#   '7': 1,
#   '29': 1,
#   '0': 2,
#   '10': 1},
#  'Zhao, Jing': {'4': 1,
#   '2': 4,
#   '3': 3,
#   '6': 1,
#   '0': 2,
#   '11': 1,
#   '1728': 1,
#   '1': 1,
#   '17': 1},
#  'Li, Yize': {'4': 3, '3': 1, '0': 4, '7': 1, '2': 2, '1': 3, '6': 1},
#  'Takeda, Makoto': {'7': 1,
#   '9': 3,
#   '13': 1,
#   '4': 3,
#   '3': 1,
#   '5': 1,
#   '6': 1,
#   '22': 1,
#   '16': 1,
#   '12': 1,
#   '17': 1},
#  'Zhang, Yang': {'3': 5, '0': 3, '4': 1, '1': 3, '5': 1, '15': 1, '2430': 1},
#  'Kim, Ji Hye': {'8': 1,
#   '271': 1,
#   '279': 1,
#   '288': 1,
#   '326': 1,
#   '382': 1,
#   '1110': 1,
#   '1209': 1,
#   '1251': 1,
#   '1300': 1,
#   '2136': 1,
#   '2137': 1,
#   '2378': 1,
#   '3478': 1,
#   '3509': 1},
#  'Jongkaewwattana, Anan': {'8': 1,
#   '2': 2,
#   '4': 3,
#   '3': 5,
#   '5': 1,
#   '1': 2,
#   '6': 1},
#  'Nan, Yuchen': {'0': 7,
#   '6': 1,
#   '7': 1,
#   '11': 1,
#   '5': 1,
#   '4': 1,
#   '1': 2,
#   '2': 1},
#  'Veesler, David': {'7': 3,
#   '8': 2,
#   '3': 1,
#   '5': 2,
#   '10': 1,
#   '12': 1,
#   '6': 2,
#   '9': 1,
#   '13': 1,
#   '1': 1},
#  'Liu, William J.': {'1': 1,
#   '22': 1,
#   '10': 1,
#   '0': 2,
#   '12': 1,
#   '11': 2,
#   '16': 1,
#   '3': 1,
#   '4': 1,
#   '14': 1,
#   '9': 1,
#   '8': 2},
#  'Lam, Carol S. F.': {'7': 3,
#   '12': 1,
#   '6': 1,
#   '4': 1,
#   '1': 1,
#   '3': 1,
#   '11': 1,
#   '2': 3,
#   '9': 1,
#   '13': 1,
#   '8': 1},
#  'Kim, Ha-Hyun': {'2': 2,
#   '1': 2,
#   '4': 2,
#   '13': 1,
#   '9': 1,
#   '0': 2,
#   '6': 2,
#   '3': 3},
#  'Papadopoulos, Nikolaos G.': {'14': 1,
#   '3': 1,
#   '2': 1,
#   '1': 4,
#   '17': 1,
#   '5': 2,
#   '11': 1,
#   '0': 3,
#   '6': 1},
#  'McIntosh, Kenneth': {'2': 1, '0': 13, '4': 1},
#  'Risco, Cristina': {'7': 1, '5': 4, '0': 3, '2': 4, '4': 1, '1': 1, '3': 1},
#  'Yu, Li': {'4': 2,
#   '3': 2,
#   '1': 4,
#   '2390': 1,
#   '15': 1,
#   '7': 2,
#   '8': 1,
#   '6': 2},
#  'Cyranoski, David': {'0': 14, '1': 1},
#  'Colson, Philippe': {'2': 4,
#   '5': 1,
#   '12': 1,
#   '19': 2,
#   '0': 4,
#   '1': 2,
#   '3': 1},
#  'Kuo, Lili': {'1': 5, '0': 9, '2': 1},
#  'Rebmann, Terri': {'0': 13, '1': 2},
#  'Bukreyev, Alexander': {'3': 1,
#   '7': 2,
#   '1': 2,
#   '5': 4,
#   '0': 4,
#   '28': 1,
#   '8': 1},
#  'Kang, Hye-Ryun': {'757': 1,
#   '909': 1,
#   '1099': 1,
#   '2110': 1,
#   '2458': 1,
#   '2473': 1,
#   '2515': 1,
#   '2617': 1,
#   '2642': 1,
#   '2754': 1,
#   '2793': 1,
#   '2794': 1,
#   '3045': 1,
#   '3254': 1,
#   '3255': 1},
#  'MacKenzie, Debora': {'0': 14, '1': 1},
#  'Gerardo Chowell': {'0': 2, '1': 3, '2': 4, '3': 2, '6': 2, '4': 2},
#  'Saif, L J': {'1': 5, '3': 3, '4': 3, '5': 1, '0': 1, '2': 2},
#  'Dea, S': {'0': 8, '2': 3, '3': 3, '5': 1},
#  'Zhang, Tao': {'7': 2, '0': 4, '3': 2, '10': 2, '2': 1, '5': 1, '4': 2},
#  'Lim, Wilina': {'5': 1,
#   '10': 1,
#   '13': 1,
#   '4': 5,
#   '3': 1,
#   '2': 2,
#   '7': 2,
#   '9': 1},
#  'Doerr, Hans Wilhelm': {'11': 1,
#   '5': 2,
#   '1': 2,
#   '7': 3,
#   '3': 1,
#   '13': 1,
#   '2': 2,
#   '4': 2},
#  'Yang, Pan-Chyr': {'6': 2,
#   '8': 4,
#   '1': 1,
#   '11': 1,
#   '7': 2,
#   '24': 1,
#   '5': 1,
#   '10': 1,
#   '9': 1},
#  'Fontanet, Arnaud': {'4': 1,
#   '8': 3,
#   '1': 2,
#   '2': 3,
#   '53': 1,
#   '10': 1,
#   '0': 2,
#   '15': 1},
#  'Yang, Hong': {'9': 1,
#   '6': 2,
#   '5': 2,
#   '15': 1,
#   '12': 2,
#   '8': 1,
#   '7': 1,
#   '1': 1,
#   '2': 1,
#   '3': 1,
#   '4': 1},
#  'Cao, Wuchun': {'13': 1,
#   '7': 2,
#   '8': 2,
#   '5': 1,
#   '15': 1,
#   '12': 1,
#   '19': 1,
#   '55': 1,
#   '10': 1,
#   '11': 1,
#   '0': 1,
#   '3': 1},
#  'Fang, Shouguo': {'1': 5, '2': 3, '3': 1, '0': 3, '5': 1, '4': 1},
#  'Yazdanpanah, Yazdan': {'11': 2,
#   '4': 1,
#   '12': 2,
#   '7': 2,
#   '2': 2,
#   '22': 1,
#   '8': 1,
#   '1': 1,
#   '6': 1,
#   '0': 1},
#  'He, Fuchu': {'15': 1,
#   '11': 2,
#   '14': 1,
#   '22': 1,
#   '16': 1,
#   '8': 2,
#   '9': 1,
#   '35': 1,
#   '10': 1,
#   '13': 1,
#   '12': 2},
#  'Welsh, Raymond M.': {'5': 3, '3': 3, '0': 2, '2': 2, '6': 2, '8': 2},
#  'van Hemert, Martijn J.': {'0': 1,
#   '5': 1,
#   '7': 4,
#   '2': 1,
#   '16': 1,
#   '3': 1,
#   '1': 1,
#   '9': 1,
#   '8': 1,
#   '6': 1,
#   '10': 1},
#  'Chan, Kwok Hung': {'4': 2, '5': 3, '3': 3, '1': 4, '0': 1, '2': 1},
#  'Kong, Wing-Pui': {'6': 1,
#   '1': 2,
#   '5': 3,
#   '28': 1,
#   '4': 2,
#   '27': 1,
#   '2': 1,
#   '20': 1,
#   '10': 1,
#   '8': 1},
#  'Verheije, Monique H.': {'0': 3,
#   '1': 4,
#   '6': 1,
#   '13': 1,
#   '5': 2,
#   '8': 1,
#   '2': 2},
#  'van der Meer, Yvonne': {'4': 2,
#   '7': 1,
#   '2': 5,
#   '1': 2,
#   '3': 1,
#   '5': 1,
#   '0': 2},
#  'Timen, Aura': {'0': 3,
#   '10': 1,
#   '14': 1,
#   '4': 1,
#   '3': 1,
#   '12': 1,
#   '18': 1,
#   '5': 2,
#   '6': 1,
#   '13': 1,
#   '1': 1},
#  'Pfefferle, Susanne': {'10': 2,
#   '1': 2,
#   '0': 4,
#   '8': 1,
#   '5': 1,
#   '2': 2,
#   '3': 2},
#  ...}

# %%
# %run ./0.1-gks-matplotlib-plots.ipynb

# %%
FIGURE = PARENT + "/reports/figures"

total_figures = 100
for author, pos_publication in authors_publications.items():
    p = create_bar_plot(value_dictionary=pos_publication, title=author, figsize=(15, 6), 
                        save=True, save_folder=FIGURE)
    
    if total_figures =< 0:
        break
    else:
        total_figures -= 1

# %% [markdown]
# ### Analysis of Author Titles and Abstracts

# %%
len(authors_publications)
# Out:
# 201209

# %%
author_titles = dict()

top_number_authors = 100

for author in authors_publications.keys():
    _df = df[df.authors.str.contains(author)==True]
    _df.to_csv(DATA_INTERIM + "meta_data_{}.csv".format(author), index=False)
    
    if top_number_authors <= 0:
        break
    else:
        top_number_authors -= 1
